# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/\
GibbsDuhemSimulations/InitialConfigurations/IceIh/water.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 18:00:57    -4179.602444*       0.2890
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/\
GibbsDuhemSimulations/InitialConfigurations/IceV/iceV.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 18:01:02    -4834.065126*       2.3135
# BFGSLineSearch:    1[  2] 18:01:04    -4851.531667*       1.0293
# BFGSLineSearch:    2[  3] 18:01:05    -4860.725898*       2.6266
# BFGSLineSearch:    3[  5] 18:01:07    -4864.430067*       0.7583
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq, n_steps_pr, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq, n_steps_pr)
        os.system('export CUDA_VISIBLE_DEVICES=0; nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq, n_steps_pr)
        os.system('export CUDA_VISIBLE_DEVICES=0; nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
path = '../cc_int/ice_ih-liq/ice_ih'
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ih-v/ih'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ih-v/v'

T = 273.882; P = 3478; T_step = -3
n_steps_eq = 2*10**4; n_steps_pr = 2*10**5
barostat_ph1 = 'aniso'; barostat_ph2 = 'tri'

skip = 100
n_pnts = 40

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq, n_steps_pr, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_273.882_P_3478 has been executed and will be used
# Simulations_ph2_T_273.882_P_3478 has been executed and will be used
# Simulations_ph1_T_272.382_P_3493.1881384187586 has been executed and will be used
# Simulations_ph2_T_272.382_P_3493.1881384187586 has been executed and will be used
# Simulations_ph1_T_272.382_P_3492.5240185091902 has been executed and will be used
# Simulations_ph2_T_272.382_P_3492.5240185091902 has been executed and will be used
# Simulations_ph1_T_270.882_P_3507.855494083387 has been executed and will be used
# Simulations_ph2_T_270.882_P_3507.855494083387 has been executed and will be used
# Simulations_ph1_T_270.882_P_3507.5383760892146 has been executed and will be used
# Simulations_ph2_T_270.882_P_3507.5383760892146 has been executed and will be used
# Simulations_ph1_T_269.382_P_3519.1042279633025 has been executed and will be used
# Simulations_ph2_T_269.382_P_3519.1042279633025 has been executed and will be used
# Simulations_ph1_T_269.382_P_3521.146914658683 has been executed and will be used
# Simulations_ph2_T_269.382_P_3521.146914658683 has been executed and will be used
# Simulations_ph1_T_267.882_P_3534.7263623424933 has been executed and will be used
# Simulations_ph2_T_267.882_P_3534.7263623424933 has been executed and will be used
# Simulations_ph1_T_267.882_P_3533.7889921524766 has been executed and will be used
# Simulations_ph2_T_267.882_P_3533.7889921524766 has been executed and will be used
# Simulations_ph1_T_266.382_P_3548.498571552653 has been executed and will be used
# Simulations_ph2_T_266.382_P_3548.498571552653 has been executed and will be used
# Simulations_ph1_T_266.382_P_3548.62829584265 has been executed and will be used
# Simulations_ph2_T_266.382_P_3548.62829584265 has been executed and will be used
# Simulations_ph1_T_264.882_P_3559.082847785406 has been executed and will be used
# Simulations_ph2_T_264.882_P_3559.082847785406 has been executed and will be used
# Simulations_ph1_T_264.882_P_3561.8459400702377 has been executed and will be used
# Simulations_ph2_T_264.882_P_3561.8459400702377 has been executed and will be used
# Simulations_ph1_T_263.382_P_3576.3388545598946 has been executed and will be used
# Simulations_ph2_T_263.382_P_3576.3388545598946 has been executed and will be used
# Simulations_ph1_T_263.382_P_3575.7894716296005 has been executed and will be used
# Simulations_ph2_T_263.382_P_3575.7894716296005 has been executed and will be used
# Simulations_ph1_T_261.882_P_3590.958479037311 has been executed and will be used
# Simulations_ph2_T_261.882_P_3590.958479037311 has been executed and will be used
# Simulations_ph1_T_261.882_P_3590.280984565302 has been executed and will be used
# Simulations_ph2_T_261.882_P_3590.280984565302 has been executed and will be used
# Simulations_ph1_T_260.382_P_3605.1170927723356 has been executed and will be used
# Simulations_ph2_T_260.382_P_3605.1170927723356 has been executed and will be used
# Simulations_ph1_T_260.382_P_3604.4254474507493 has been executed and will be used
# Simulations_ph2_T_260.382_P_3604.4254474507493 has been executed and will be used
# Simulations_ph1_T_258.882_P_3617.6383066833305 has been executed and will be used
# Simulations_ph2_T_258.882_P_3617.6383066833305 has been executed and will be used
# Simulations_ph1_T_258.882_P_3617.845053993074 has been executed and will be used
# Simulations_ph2_T_258.882_P_3617.845053993074 has been executed and will be used
# Simulations_ph1_T_257.382_P_3631.7449557810464 has been executed and will be used
# Simulations_ph2_T_257.382_P_3631.7449557810464 has been executed and will be used
# Simulations_ph1_T_257.382_P_3632.3356120223116 has been executed and will be used
# Simulations_ph2_T_257.382_P_3632.3356120223116 has been executed and will be used
# Simulations_ph1_T_255.882_P_3646.065258651031 has been executed and will be used
# Simulations_ph2_T_255.882_P_3646.065258651031 has been executed and will be used
# Simulations_ph1_T_255.882_P_3646.4893680003124 has been executed and will be used
# Simulations_ph2_T_255.882_P_3646.4893680003124 has been executed and will be used
# Simulations_ph1_T_254.382_P_3659.925965201861 has been executed and will be used
# Simulations_ph2_T_254.382_P_3659.925965201861 has been executed and will be used
# Simulations_ph1_T_254.382_P_3659.252046158106 has been executed and will be used
# Simulations_ph2_T_254.382_P_3659.252046158106 has been executed and will be used
# Simulations_ph1_T_252.882_P_3671.6299123683275 has been executed and will be used
# Simulations_ph2_T_252.882_P_3671.6299123683275 has been executed and will be used
# Simulations_ph1_T_252.882_P_3672.241078662077 has been executed and will be used
# Simulations_ph2_T_252.882_P_3672.241078662077 has been executed and will be used
# Simulations_ph1_T_251.382_P_3686.1119771934727 has been executed and will be used
# Simulations_ph2_T_251.382_P_3686.1119771934727 has been executed and will be used
# Simulations_ph1_T_251.382_P_3686.7592615332123 has been executed and will be used
# Simulations_ph2_T_251.382_P_3686.7592615332123 has been executed and will be used
# Simulations_ph1_T_249.882_P_3697.187779261747 has been executed and will be used
# Simulations_ph2_T_249.882_P_3697.187779261747 has been executed and will be used
# Simulations_ph1_T_249.882_P_3699.516413848155 has been executed and will be used
# Simulations_ph2_T_249.882_P_3699.516413848155 has been executed and will be used
# Simulations_ph1_T_248.382_P_3713.876316340829 has been executed and will be used
# Simulations_ph2_T_248.382_P_3713.876316340829 has been executed and will be used
# Simulations_ph1_T_248.382_P_3713.8736728287836 has been executed and will be used
# Simulations_ph2_T_248.382_P_3713.8736728287836 has been executed and will be used
# Simulations_ph1_T_246.882_P_3725.0727980824654 has been executed and will be used
# Simulations_ph2_T_246.882_P_3725.0727980824654 has been executed and will be used
# Simulations_ph1_T_246.882_P_3726.933236440044 has been executed and will be used
# Simulations_ph2_T_246.882_P_3726.933236440044 has been executed and will be used
# Simulations_ph1_T_245.382_P_3741.8215308191566 has been executed and will be used
# Simulations_ph2_T_245.382_P_3741.8215308191566 has been executed and will be used
# Simulations_ph1_T_245.382_P_3739.9621654371376 has been executed and will be used
# Simulations_ph2_T_245.382_P_3739.9621654371376 has been executed and will be used
# Simulations_ph1_T_243.882_P_3753.208329861795 has been executed and will be used
# Simulations_ph2_T_243.882_P_3753.208329861795 has been executed and will be used
# Simulations_ph1_T_243.882_P_3753.2795394800605 has been executed and will be used
# Simulations_ph2_T_243.882_P_3753.2795394800605 has been executed and will be used
# Simulations_ph1_T_242.382_P_3766.4810169331795 has been executed and will be used
# Simulations_ph2_T_242.382_P_3766.4810169331795 has been executed and will be used
# Simulations_ph1_T_242.382_P_3765.943180644522 has been executed and will be used
# Simulations_ph2_T_242.382_P_3765.943180644522 has been executed and will be used
# Simulations_ph1_T_240.882_P_3781.105391554862 has been executed and will be used
# Simulations_ph2_T_240.882_P_3781.105391554862 has been executed and will be used
# Simulations_ph1_T_240.882_P_3779.46106780395 has been executed and will be used
# Simulations_ph2_T_240.882_P_3779.46106780395 has been executed and will be used
# Simulations_ph1_T_239.382_P_3791.3912917026496 has been executed and will be used
# Simulations_ph2_T_239.382_P_3791.3912917026496 has been executed and will be used
# Simulations_ph1_T_239.382_P_3793.341459078648 has been executed and will be used
# Simulations_ph2_T_239.382_P_3793.341459078648 has been executed and will be used
# Simulations_ph1_T_237.882_P_3803.3341336774643 has been executed and will be used
# Simulations_ph2_T_237.882_P_3803.3341336774643 has been executed and will be used
# Simulations_ph1_T_237.882_P_3805.1123554442233 has been executed and will be used
# Simulations_ph2_T_237.882_P_3805.1123554442233 has been executed and will be used
# Simulations_ph1_T_236.382_P_3819.4066207787773 has been executed and will be used
# Simulations_ph2_T_236.382_P_3819.4066207787773 has been executed and will be used
# Simulations_ph1_T_236.382_P_3816.242051547468 has been executed and will be used
# Simulations_ph2_T_236.382_P_3816.242051547468 has been executed and will be used
# Simulations_ph1_T_234.882_P_3831.3359004226063 has been executed and will be used
# Simulations_ph2_T_234.882_P_3831.3359004226063 has been executed and will be used
# Simulations_ph1_T_234.882_P_3830.6073436481015 has been executed and will be used
# Simulations_ph2_T_234.882_P_3830.6073436481015 has been executed and will be used
# Simulations_ph1_T_233.382_P_3844.5189565735222 has been executed and will be used
# Simulations_ph2_T_233.382_P_3844.5189565735222 has been executed and will be used
# Simulations_ph1_T_233.382_P_3842.6015797126715 has been executed and will be used
# Simulations_ph2_T_233.382_P_3842.6015797126715 has been executed and will be used
# Simulations_ph1_T_231.882_P_3853.61289561511 has been executed and will be used
# Simulations_ph2_T_231.882_P_3853.61289561511 has been executed and will be used
# Simulations_ph1_T_231.882_P_3855.1386633513407 has been executed and will be used
# Simulations_ph2_T_231.882_P_3855.1386633513407 has been executed and will be used
# Simulations_ph1_T_230.382_P_3867.1398079018677 has been executed and will be used
# Simulations_ph2_T_230.382_P_3867.1398079018677 has been executed and will be used
# Simulations_ph1_T_230.382_P_3867.152065574604 has been executed and will be used
# Simulations_ph2_T_230.382_P_3867.152065574604 has been executed and will be used
# Simulations_ph1_T_228.882_P_3875.0903222222037 has been executed and will be used
# Simulations_ph2_T_228.882_P_3875.0903222222037 has been executed and will be used
# Simulations_ph1_T_228.882_P_3878.203079085584 has been executed and will be used
# Simulations_ph2_T_228.882_P_3878.203079085584 has been executed and will be used
# Simulations_ph1_T_227.382_P_3888.9537190699134 has been executed and will be used
# Simulations_ph2_T_227.382_P_3888.9537190699134 has been executed and will be used
# Simulations_ph1_T_227.382_P_3891.5349987512577 has been executed and will be used
# Simulations_ph2_T_227.382_P_3891.5349987512577 has been executed and will be used
# Simulations_ph1_T_225.882_P_3903.1497021814225 has been executed and will be used
# Simulations_ph2_T_225.882_P_3903.1497021814225 has been executed and will be used
# Simulations_ph1_T_225.882_P_3902.8346774601405 has been executed and will be used
# Simulations_ph2_T_225.882_P_3902.8346774601405 has been executed and will be used
# Simulations_ph1_T_224.382_P_3918.1234848839867 has been executed and will be used
# Simulations_ph2_T_224.382_P_3918.1234848839867 has been executed and will be used
# Simulations_ph1_T_224.382_P_3914.583109398952 has been executed and will be used
# Simulations_ph2_T_224.382_P_3914.583109398952 has been executed and will be used
# Simulations_ph1_T_222.882_P_3926.8641741611914 has been executed and will be used
# Simulations_ph2_T_222.882_P_3926.8641741611914 has been executed and will be used
# Simulations_ph1_T_222.882_P_3927.577148369901 has been executed and will be used
# Simulations_ph2_T_222.882_P_3927.577148369901 has been executed and will be used
# Simulations_ph1_T_221.382_P_3940.6022507693347 has been executed and will be used
# Simulations_ph2_T_221.382_P_3940.6022507693347 has been executed and will be used
# Simulations_ph1_T_221.382_P_3941.799058134234 has been executed and will be used
# Simulations_ph2_T_221.382_P_3941.799058134234 has been executed and will be used
# Simulations_ph1_T_219.882_P_3953.58569366169 has been executed and will be used
# Simulations_ph2_T_219.882_P_3953.58569366169 has been executed and will be used
# Simulations_ph1_T_219.882_P_3953.5155305975 has been executed and will be used
# Simulations_ph2_T_219.882_P_3953.5155305975 has been executed and will be used
# Simulations_ph1_T_218.382_P_3965.0649604110376 has been executed and will be used
# Simulations_ph2_T_218.382_P_3965.0649604110376 has been executed and will be used
# Simulations_ph1_T_218.382_P_3965.71182880442 has been executed and will be used
# Simulations_ph2_T_218.382_P_3965.71182880442 has been executed and will be used
# Simulations_ph1_T_216.882_P_3977.484529632699 has been executed and will be used
# Simulations_ph2_T_216.882_P_3977.484529632699 has been executed and will be used
# Simulations_ph1_T_216.882_P_3977.65371074237 has been executed and will be used
# Simulations_ph2_T_216.882_P_3977.65371074237 has been executed and will be used
# Simulations_ph1_T_215.382_P_3990.3142442539415 has been executed and will be used
# Simulations_ph2_T_215.382_P_3990.3142442539415 has been executed and will be used
# Simulations_ph1_T_215.382_P_3989.955839606825 has been executed and will be used
# Simulations_ph2_T_215.382_P_3989.955839606825 has been executed and will be used
# Simulations_ph1_T_213.882_P_4003.49359798664 has been executed and will be used
# Simulations_ph2_T_213.882_P_4003.49359798664 has been executed and will be used
# Simulations_ph1_T_213.882_P_4002.986791639158 has been done
# Simulations_ph2_T_213.882_P_4002.986791639158 has been done
# Simulations_ph1_T_212.382_P_4015.098072585449 has been done
# Simulations_ph2_T_212.382_P_4015.098072585449 has been done
# Simulations_ph1_T_212.382_P_4014.5265925435297 has been done
# Simulations_ph2_T_212.382_P_4014.5265925435297 has been done
# Simulations_ph1_T_210.882_P_4027.2639724237683 has been done
# Simulations_ph2_T_210.882_P_4027.2639724237683 has been done
# Simulations_ph1_T_210.882_P_4026.06174529164 has been done
# Simulations_ph2_T_210.882_P_4026.06174529164 has been done
# Simulations_ph1_T_209.382_P_4036.413943127374 has been done
# Simulations_ph2_T_209.382_P_4036.413943127374 has been done
# Simulations_ph1_T_209.382_P_4039.303264343218 has been done
# Simulations_ph2_T_209.382_P_4039.303264343218 has been done
# Simulations_ph1_T_207.882_P_4049.4202589277866 has been done
# Simulations_ph2_T_207.882_P_4049.4202589277866 has been done
# Simulations_ph1_T_207.882_P_4050.326151805522 has been done
# Simulations_ph2_T_207.882_P_4050.326151805522 has been done
# Simulations_ph1_T_206.382_P_4063.720492676789 has been done
# Simulations_ph2_T_206.382_P_4063.720492676789 has been done
# Simulations_ph1_T_206.382_P_4059.980365784795 has been done
# Simulations_ph2_T_206.382_P_4059.980365784795 has been done
# Simulations_ph1_T_204.882_P_4071.575955052419 has been done
# Simulations_ph2_T_204.882_P_4071.575955052419 has been done
# Simulations_ph1_T_204.882_P_4072.320663702856 has been done
# Simulations_ph2_T_204.882_P_4072.320663702856 has been done
# Simulations_ph1_T_203.382_P_4083.270847499654 has been done
# Simulations_ph2_T_203.382_P_4083.270847499654 has been done
# Simulations_ph1_T_203.382_P_4083.5626601405947 has been done
# Simulations_ph2_T_203.382_P_4083.5626601405947 has been done
# Simulations_ph1_T_201.882_P_4094.935701077501 has been done
# Simulations_ph2_T_201.882_P_4094.935701077501 has been done
# Simulations_ph1_T_201.882_P_4094.6448775443064 has been done
# Simulations_ph2_T_201.882_P_4094.6448775443064 has been done
# Simulations_ph1_T_200.382_P_4105.758629913439 has been done
# Simulations_ph2_T_200.382_P_4105.758629913439 has been done
# Simulations_ph1_T_200.382_P_4106.016074829366 has been done
# Simulations_ph2_T_200.382_P_4106.016074829366 has been done
# Simulations_ph1_T_198.882_P_4117.503873618331 has been done
# Simulations_ph2_T_198.882_P_4117.503873618331 has been done
# Simulations_ph1_T_198.882_P_4117.111030571844 has been done
# Simulations_ph2_T_198.882_P_4117.111030571844 has been done
# Simulations_ph1_T_197.382_P_4126.343537490887 has been done
# Simulations_ph2_T_197.382_P_4126.343537490887 has been done
# Simulations_ph1_T_197.382_P_4130.209228358885 has been done
# Simulations_ph2_T_197.382_P_4130.209228358885 has been done
# Simulations_ph1_T_195.882_P_4140.085945601675 has been done
# Simulations_ph2_T_195.882_P_4140.085945601675 has been done
# Simulations_ph1_T_195.882_P_4140.433476073094 has been done
# Simulations_ph2_T_195.882_P_4140.433476073094 has been done
# Simulations_ph1_T_194.382_P_4153.592383642612 has been done
# Simulations_ph2_T_194.382_P_4153.592383642612 has been done
# Simulations_ph1_T_194.382_P_4151.520113755993 has been done
# Simulations_ph2_T_194.382_P_4151.520113755993 has been done
# Simulations_ph1_T_192.882_P_4163.572191896544 has been done
# Simulations_ph2_T_192.882_P_4163.572191896544 has been done
# Simulations_ph1_T_192.882_P_4163.416616446678 has been done
# Simulations_ph2_T_192.882_P_4163.416616446678 has been done
# Simulations_ph1_T_191.382_P_4174.676090383771 has been done
# Simulations_ph2_T_191.382_P_4174.676090383771 has been done
# Simulations_ph1_T_191.382_P_4172.477779977037 has been done
# Simulations_ph2_T_191.382_P_4172.477779977037 has been done
# Simulations_ph1_T_189.882_P_4184.696365007965 has been done
# Simulations_ph2_T_189.882_P_4184.696365007965 has been done
# Simulations_ph1_T_189.882_P_4184.258940286934 has been done
# Simulations_ph2_T_189.882_P_4184.258940286934 has been done
# Simulations_ph1_T_188.382_P_4194.533463937987 has been done
# Simulations_ph2_T_188.382_P_4194.533463937987 has been done
# Simulations_ph1_T_188.382_P_4196.6376871689545 has been done
# Simulations_ph2_T_188.382_P_4196.6376871689545 has been done
# Simulations_ph1_T_186.882_P_4206.839209775365 has been done
# Simulations_ph2_T_186.882_P_4206.839209775365 has been done
# Simulations_ph1_T_186.882_P_4207.61334263148 has been done
# Simulations_ph2_T_186.882_P_4207.61334263148 has been done
# Simulations_ph1_T_185.382_P_4220.240373590412 has been done
# Simulations_ph2_T_185.382_P_4220.240373590412 has been done
# Simulations_ph1_T_185.382_P_4219.445371628537 has been done
# Simulations_ph2_T_185.382_P_4219.445371628537 has been done
# Simulations_ph1_T_183.882_P_4231.50186262602 has been done
# Simulations_ph2_T_183.882_P_4231.50186262602 has been done
# Simulations_ph1_T_183.882_P_4231.278139333718 has been done
# Simulations_ph2_T_183.882_P_4231.278139333718 has been done
# Simulations_ph1_T_182.382_P_4243.459749308099 has been done
# Simulations_ph2_T_182.382_P_4243.459749308099 has been done
# Simulations_ph1_T_182.382_P_4241.518926875808 has been done
# Simulations_ph2_T_182.382_P_4241.518926875808 has been done
# Simulations_ph1_T_180.882_P_4252.272918211939 has been done
# Simulations_ph2_T_180.882_P_4252.272918211939 has been done
# Simulations_ph1_T_180.882_P_4252.760213734123 has been done
# Simulations_ph2_T_180.882_P_4252.760213734123 has been done
# Simulations_ph1_T_179.382_P_4261.4576961152225 has been done
# Simulations_ph2_T_179.382_P_4261.4576961152225 has been done
# Simulations_ph1_T_179.382_P_4263.530247290432 has been done
# Simulations_ph2_T_179.382_P_4263.530247290432 has been done
# Simulations_ph1_T_177.882_P_4276.123894299226 has been done
# Simulations_ph2_T_177.882_P_4276.123894299226 has been done
# Simulations_ph1_T_177.882_P_4273.887785945233 has been done
# Simulations_ph2_T_177.882_P_4273.887785945233 has been done
# Simulations_ph1_T_176.382_P_4286.321199542816 has been done
# Simulations_ph2_T_176.382_P_4286.321199542816 has been done
# Simulations_ph1_T_176.382_P_4285.4537830491045 has been done
# Simulations_ph2_T_176.382_P_4285.4537830491045 has been done
# Simulations_ph1_T_174.882_P_4300.536476165906 has been done
# Simulations_ph2_T_174.882_P_4300.536476165906 has been done
# Simulations_ph1_T_174.882_P_4298.388874894419 has been done
# Simulations_ph2_T_174.882_P_4298.388874894419 has been done
# Simulations_ph1_T_173.382_P_4308.843820374907 has been done
# Simulations_ph2_T_173.382_P_4308.843820374907 has been done
# Simulations_ph1_T_173.382_P_4308.442165234532 has been done
# Simulations_ph2_T_173.382_P_4308.442165234532 has been done
# Simulations_ph1_T_171.882_P_4321.002777050405 has been done
# Simulations_ph2_T_171.882_P_4321.002777050405 has been done
# Simulations_ph1_T_171.882_P_4319.5840421883695 has been done
# Simulations_ph2_T_171.882_P_4319.5840421883695 has been done
# Simulations_ph1_T_170.382_P_4331.474956153585 has been done
# Simulations_ph2_T_170.382_P_4331.474956153585 has been done
# Simulations_ph1_T_170.382_P_4330.80501127453 has been done
# Simulations_ph2_T_170.382_P_4330.80501127453 has been done
# Simulations_ph1_T_168.882_P_4343.689970675336 has been done
# Simulations_ph2_T_168.882_P_4343.689970675336 has been done
# Simulations_ph1_T_168.882_P_4343.0691665810355 has been done
# Simulations_ph2_T_168.882_P_4343.0691665810355 has been done
# Simulations_ph1_T_167.382_P_4354.222116148191 has been done
# Simulations_ph2_T_167.382_P_4354.222116148191 has been done
# Simulations_ph1_T_167.382_P_4353.544136116878 has been done
# Simulations_ph2_T_167.382_P_4353.544136116878 has been done
# Simulations_ph1_T_165.882_P_4364.741085758161 has been done
# Simulations_ph2_T_165.882_P_4364.741085758161 has been done
# Simulations_ph1_T_165.882_P_4365.008668030562 has been done
# Simulations_ph2_T_165.882_P_4365.008668030562 has been done
# Simulations_ph1_T_164.382_P_4375.398682092808 has been done
# Simulations_ph2_T_164.382_P_4375.398682092808 has been done
# Simulations_ph1_T_164.382_P_4375.674634925978 has been done
# Simulations_ph2_T_164.382_P_4375.674634925978 has been done
# Simulations_ph1_T_162.882_P_4385.505544731747 has been done
# Simulations_ph2_T_162.882_P_4385.505544731747 has been done
# Simulations_ph1_T_162.882_P_4385.781481143233 has been done
# Simulations_ph2_T_162.882_P_4385.781481143233 has been done
# Simulations_ph1_T_161.382_P_4396.690714098953 has been done
# Simulations_ph2_T_161.382_P_4396.690714098953 has been done
# Simulations_ph1_T_161.382_P_4394.913832277033 has been done
# Simulations_ph2_T_161.382_P_4394.913832277033 has been done
# Simulations_ph1_T_159.882_P_4405.941805638695 has been done
# Simulations_ph2_T_159.882_P_4405.941805638695 has been done
# Simulations_ph1_T_159.882_P_4405.385775437484 has been done
# Simulations_ph2_T_159.882_P_4405.385775437484 has been done
# Simulations_ph1_T_158.382_P_4415.821611699634 has been done
# Simulations_ph2_T_158.382_P_4415.821611699634 has been done
# Simulations_ph1_T_158.382_P_4415.950670783552 has been done
# Simulations_ph2_T_158.382_P_4415.950670783552 has been done
# Simulations_ph1_T_156.882_P_4426.331015702991 has been done
# Simulations_ph2_T_156.882_P_4426.331015702991 has been done
# Simulations_ph1_T_156.882_P_4426.569934078565 has been done
# Simulations_ph2_T_156.882_P_4426.569934078565 has been done
# Simulations_ph1_T_155.382_P_4436.689364885498 has been done
# Simulations_ph2_T_155.382_P_4436.689364885498 has been done
# Simulations_ph1_T_155.382_P_4435.124871674647 has been done
# Simulations_ph2_T_155.382_P_4435.124871674647 has been done
# Simulations_ph1_T_153.882_P_4446.923587263965 has been done
# Simulations_ph2_T_153.882_P_4446.923587263965 has been done

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ih_liq.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ih-v/ih_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:], alpha=alpha, c='C0', label='Ice-Ih')
    ax[i,0].axhline(log.Volume[skip:].mean(), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.TotEng[skip:], alpha=alpha, c='C0')
    ax[i,2].axhline(log.TotEng[skip:].mean(), ls='--', color='C0', lw=2)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ih-v/v_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:], alpha=alpha, c='C3', label='Liq')
    ax[i,0].axhline(log.Volume[skip:].mean(), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.TotEng[skip:], alpha=alpha, c='C3')
    ax[i,2].axhline(log.TotEng[skip:].mean(), ls='--', color='C3', lw=2)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('E [eV]')
ax[0,0].legend()

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_ih_liq = int(P_1_interp(T_triple_ih_liq)*1e4)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.882, 3478)

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ih_v.dat',[T_lst,np.array(P_lst)*1e-4])
