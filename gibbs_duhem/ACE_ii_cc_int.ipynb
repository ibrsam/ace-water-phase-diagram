# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram\
/GibbsDuhemSimulations/IceII_Liquid/Initial/IceII/iceII.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 11:15:50    -6238.596941*       2.4495
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 11:15:53    -6260.026631*       0.6158
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations\
/IceII_Liquid/Initial/Liquid/water.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 11:16:31    -4122.585231*       2.2666
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 11:16:32    -4134.262964*       0.8274
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('export CUDA_VISIBLE_DEVICES=1;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('export CUDA_VISIBLE_DEVICES=1;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-liq/ii'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-liq/liq'


T = 272.486; P = 5000; T_step = -3
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**6
barostat_ph1 = 'tri'; barostat_ph2 = 'aniso'

skip = 100
n_pnts = 20

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_272.486_P_5000 has been executed and will be used
# Simulations_ph2_T_272.486_P_5000 has been executed and will be used
# Simulations_ph1_T_270.986_P_4242.407753739914 has been executed and will be used
# Simulations_ph2_T_270.986_P_4242.407753739914 has been executed and will be used
# Simulations_ph1_T_270.986_P_4410.557471990476 has been executed and will be used
# Simulations_ph2_T_270.986_P_4410.557471990476 has been executed and will be used
# Simulations_ph1_T_269.486_P_3782.4389807841308 has been executed and will be used
# Simulations_ph2_T_269.486_P_3782.4389807841308 has been executed and will be used
# Simulations_ph1_T_269.486_P_3785.146159191213 has been executed and will be used
# Simulations_ph2_T_269.486_P_3785.146159191213 has been executed and will be used
# Simulations_ph1_T_267.986_P_3289.5110574243854 has been executed and will be used
# Simulations_ph2_T_267.986_P_3289.5110574243854 has been executed and will be used
# Simulations_ph1_T_267.986_P_3377.8436863004044 has been executed and will be used
# Simulations_ph2_T_267.986_P_3377.8436863004044 has been executed and will be used
# Simulations_ph1_T_266.486_P_2936.3321981200315 has been executed and will be used
# Simulations_ph2_T_266.486_P_2936.3321981200315 has been executed and will be used
# Simulations_ph1_T_266.486_P_2943.341400515138 has been executed and will be used
# Simulations_ph2_T_266.486_P_2943.341400515138 has been executed and will be used
# Simulations_ph1_T_264.986_P_2565.6753216969305 has been executed and will be used
# Simulations_ph2_T_264.986_P_2565.6753216969305 has been executed and will be used
# Simulations_ph1_T_264.986_P_2617.6555561429877 has been executed and will be used
# Simulations_ph2_T_264.986_P_2617.6555561429877 has been executed and will be used
# Simulations_ph1_T_263.486_P_2265.1289275258955 has been executed and will be used
# Simulations_ph2_T_263.486_P_2265.1289275258955 has been executed and will be used
# Simulations_ph1_T_263.486_P_2286.1362509605055 has been executed and will be used
# Simulations_ph2_T_263.486_P_2286.1362509605055 has been executed and will be used
# Simulations_ph1_T_261.986_P_2007.8537883987917 has been executed and will be used
# Simulations_ph2_T_261.986_P_2007.8537883987917 has been executed and will be used
# Simulations_ph1_T_261.986_P_2048.0463552381234 has been executed and will be used
# Simulations_ph2_T_261.986_P_2048.0463552381234 has been executed and will be used
# Simulations_ph1_T_260.486_P_1780.8842581046774 has been executed and will be used
# Simulations_ph2_T_260.486_P_1780.8842581046774 has been executed and will be used
# Simulations_ph1_T_260.486_P_1792.4159161619375 has been executed and will be used
# Simulations_ph2_T_260.486_P_1792.4159161619375 has been executed and will be used
# Simulations_ph1_T_258.986_P_1580.3893134634754 has been executed and will be used
# Simulations_ph2_T_258.986_P_1580.3893134634754 has been executed and will be used
# Simulations_ph1_T_258.986_P_1598.3168140709477 has been executed and will be used
# Simulations_ph2_T_258.986_P_1598.3168140709477 has been executed and will be used
# Simulations_ph1_T_257.486_P_1418.5258982394394 has been executed and will be used
# Simulations_ph2_T_257.486_P_1418.5258982394394 has been executed and will be used
# Simulations_ph1_T_257.486_P_1410.5911137066382 has been executed and will be used
# Simulations_ph2_T_257.486_P_1410.5911137066382 has been executed and will be used
# Simulations_ph1_T_255.986_P_1233.345048901789 has been executed and will be used
# Simulations_ph2_T_255.986_P_1233.345048901789 has been executed and will be used
# Simulations_ph1_T_255.986_P_1252.5176200709589 has been executed and will be used
# Simulations_ph2_T_255.986_P_1252.5176200709589 has been executed and will be used
# Simulations_ph1_T_254.486_P_1143.5741044483443 has been executed and will be used
# Simulations_ph2_T_254.486_P_1143.5741044483443 has been executed and will be used
# Simulations_ph1_T_254.486_P_1112.3312135269932 has been executed and will be used
# Simulations_ph2_T_254.486_P_1112.3312135269932 has been executed and will be used
# Simulations_ph1_T_252.986_P_1014.4162549078869 has been executed and will be used
# Simulations_ph2_T_252.986_P_1014.4162549078869 has been executed and will be used
# Simulations_ph1_T_252.986_P_1029.45298663488 has been executed and will be used
# Simulations_ph2_T_252.986_P_1029.45298663488 has been executed and will be used
# Simulations_ph1_T_251.486_P_930.2615686725942 has been executed and will be used
# Simulations_ph2_T_251.486_P_930.2615686725942 has been executed and will be used
# Simulations_ph1_T_251.486_P_941.5625343890988 has been executed and will be used
# Simulations_ph2_T_251.486_P_941.5625343890988 has been executed and will be used
# Simulations_ph1_T_249.986_P_860.411097592665 has been executed and will be used
# Simulations_ph2_T_249.986_P_860.411097592665 has been executed and will be used
# Simulations_ph1_T_249.986_P_867.7428790439048 has been executed and will be used
# Simulations_ph2_T_249.986_P_867.7428790439048 has been executed and will be used
# Simulations_ph1_T_248.486_P_816.7408988659995 has been executed and will be used
# Simulations_ph2_T_248.486_P_816.7408988659995 has been executed and will be used
# Simulations_ph1_T_248.486_P_798.058044263161 has been executed and will be used
# Simulations_ph2_T_248.486_P_798.058044263161 has been executed and will be used
# Simulations_ph1_T_246.986_P_745.809192454203 has been executed and will be used
# Simulations_ph2_T_246.986_P_745.809192454203 has been executed and will be used
# Simulations_ph1_T_246.986_P_736.1773927137075 has been executed and will be used
# Simulations_ph2_T_246.986_P_736.1773927137075 has been executed and will be used
# Simulations_ph1_T_245.486_P_703.3139684541643 has been executed and will be used
# Simulations_ph2_T_245.486_P_703.3139684541643 has been executed and will be used
# Simulations_ph1_T_245.486_P_689.6501846370213 has been executed and will be used
# Simulations_ph2_T_245.486_P_689.6501846370213 has been executed and will be used
# Simulations_ph1_T_243.986_P_633.4763624584209 has been executed and will be used
# Simulations_ph2_T_243.986_P_633.4763624584209 has been executed and will be used
# Simulations_ph1_T_243.986_P_633.4150131526599 has been executed and will be used
# Simulations_ph2_T_243.986_P_633.4150131526599 has been executed and will be used
# Simulations_ph1_T_242.486_P_580.5229161287358 has been executed and will be used
# Simulations_ph2_T_242.486_P_580.5229161287358 has been executed and will be used
# Simulations_ph1_T_242.486_P_578.7078770111717 has been executed and will be used
# Simulations_ph2_T_242.486_P_578.7078770111717 has been executed and will be used
# Simulations_ph1_T_240.986_P_537.3778870775734 has been executed and will be used
# Simulations_ph2_T_240.986_P_537.3778870775734 has been executed and will be used
# Simulations_ph1_T_240.986_P_530.0114236549433 has been executed and will be used
# Simulations_ph2_T_240.986_P_530.0114236549433 has been executed and will be used
# Simulations_ph1_T_239.486_P_478.2525972909084 has been executed and will be used
# Simulations_ph2_T_239.486_P_478.2525972909084 has been executed and will be used
# Simulations_ph1_T_239.486_P_482.3659083758871 has been executed and will be used
# Simulations_ph2_T_239.486_P_482.3659083758871 has been executed and will be used
# Simulations_ph1_T_237.986_P_430.14573719850324 has been executed and will be used
# Simulations_ph2_T_237.986_P_430.14573719850324 has been executed and will be used
# Simulations_ph1_T_237.986_P_435.3399260775965 has been executed and will be used
# Simulations_ph2_T_237.986_P_435.3399260775965 has been executed and will be used
# Simulations_ph1_T_236.486_P_380.07838538704266 has been executed and will be used
# Simulations_ph2_T_236.486_P_380.07838538704266 has been executed and will be used
# Simulations_ph1_T_236.486_P_383.93687925361087 has been executed and will be used
# Simulations_ph2_T_236.486_P_383.93687925361087 has been executed and will be used
# Simulations_ph1_T_234.986_P_329.9594593059991 has been executed and will be used
# Simulations_ph2_T_234.986_P_329.9594593059991 has been executed and will be used
# Simulations_ph1_T_234.986_P_339.6782159283531 has been executed and will be used
# Simulations_ph2_T_234.986_P_339.6782159283531 has been executed and will be used
# Simulations_ph1_T_233.486_P_292.3594361409445 has been executed and will be used
# Simulations_ph2_T_233.486_P_292.3594361409445 has been executed and will be used
# Simulations_ph1_T_233.486_P_290.7451312038205 has been executed and will be used
# Simulations_ph2_T_233.486_P_290.7451312038205 has been executed and will be used
# Simulations_ph1_T_231.986_P_245.1316852323106 has been executed and will be used
# Simulations_ph2_T_231.986_P_245.1316852323106 has been executed and will be used
# Simulations_ph1_T_231.986_P_249.78245911874217 has been executed and will be used
# Simulations_ph2_T_231.986_P_249.78245911874217 has been executed and will be used
# Simulations_ph1_T_230.486_P_212.02881958888867 has been executed and will be used
# Simulations_ph2_T_230.486_P_212.02881958888867 has been executed and will be used
# Simulations_ph1_T_230.486_P_206.79012688373288 has been executed and will be used
# Simulations_ph2_T_230.486_P_206.79012688373288 has been executed and will be used
# Simulations_ph1_T_228.986_P_155.58687264288417 has been executed and will be used
# Simulations_ph2_T_228.986_P_155.58687264288417 has been executed and will be used
# Simulations_ph1_T_228.986_P_165.63740214362633 has been executed and will be used
# Simulations_ph2_T_228.986_P_165.63740214362633 has been executed and will be used
# Simulations_ph1_T_227.486_P_113.29960161245046 has been executed and will be used
# Simulations_ph2_T_227.486_P_113.29960161245046 has been executed and will be used
# Simulations_ph1_T_227.486_P_116.24998530436696 has been executed and will be used
# Simulations_ph2_T_227.486_P_116.24998530436696 has been executed and will be used
# Simulations_ph1_T_225.986_P_73.54676064645062 has been executed and will be used
# Simulations_ph2_T_225.986_P_73.54676064645062 has been executed and will be used
# Simulations_ph1_T_225.986_P_68.48498258786492 has been executed and will be used
# Simulations_ph2_T_225.986_P_68.48498258786492 has been executed and will be used
# Simulations_ph1_T_224.486_P_28.989707554321285 has been executed and will be used
# Simulations_ph2_T_224.486_P_28.989707554321285 has been executed and will be used
# Simulations_ph1_T_224.486_P_27.857382629568477 has been executed and will be used
# Simulations_ph2_T_224.486_P_27.857382629568477 has been executed and will be used
# Simulations_ph1_T_222.986_P_-7.769083251413896 has been executed and will be used
# Simulations_ph2_T_222.986_P_-7.769083251413896 has been executed and will be used
# Simulations_ph1_T_222.986_P_-15.672245722056061 has been executed and will be used
# Simulations_ph2_T_222.986_P_-15.672245722056061 has been executed and will be used
# Simulations_ph1_T_221.486_P_-55.57092946290018 has been executed and will be used
# Simulations_ph2_T_221.486_P_-55.57092946290018 has been executed and will be used
# Simulations_ph1_T_221.486_P_-54.076882278724796 has been executed and will be used
# Simulations_ph2_T_221.486_P_-54.076882278724796 has been executed and will be used
# Simulations_ph1_T_219.986_P_-99.02112419915501 has been executed and will be used
# Simulations_ph2_T_219.986_P_-99.02112419915501 has been executed and will be used
# Simulations_ph1_T_219.986_P_-92.10129069469298 has been executed and will be used
# Simulations_ph2_T_219.986_P_-92.10129069469298 has been executed and will be used
# Simulations_ph1_T_218.486_P_-142.90753097912835 has been executed and will be used
# Simulations_ph2_T_218.486_P_-142.90753097912835 has been executed and will be used
# Simulations_ph1_T_218.486_P_-140.94880251027502 has been executed and will be used
# Simulations_ph2_T_218.486_P_-140.94880251027502 has been executed and will be used
# Simulations_ph1_T_216.986_P_-183.2298023182022 has been executed and will be used
# Simulations_ph2_T_216.986_P_-183.2298023182022 has been executed and will be used
# Simulations_ph1_T_216.986_P_-184.8397385649506 has been executed and will be used
# Simulations_ph2_T_216.986_P_-184.8397385649506 has been executed and will be used
# Simulations_ph1_T_215.486_P_-241.64771066443006 has been executed and will be used
# Simulations_ph2_T_215.486_P_-241.64771066443006 has been executed and will be used
# Simulations_ph1_T_215.486_P_-233.91050722615756 has been executed and will be used
# Simulations_ph2_T_215.486_P_-233.91050722615756 has been executed and will be used
# Simulations_ph1_T_213.986_P_-280.923828128847 has been executed and will be used
# Simulations_ph2_T_213.986_P_-280.923828128847 has been executed and will be used
# Simulations_ph1_T_213.986_P_-278.8189392584378 has been executed and will be used
# Simulations_ph2_T_213.986_P_-278.8189392584378 has been executed and will be used
# Simulations_ph1_T_212.486_P_-330.2417430173914 has been executed and will be used
# Simulations_ph2_T_212.486_P_-330.2417430173914 has been executed and will be used

# %%
plt.scatter(T_lst, P_lst)

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ii_liq.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-liq/ii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='ii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-liq/liq_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='liq')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)

# %%
# plt.scatter(exp_liq['T'], exp_liq['P'], c='gray', label='exp')
# plt.plot(T_lst, np.array(P_lst)*1e-4, label='ACE')
# plt.scatter(ih_scan['T'], ih_scan['P'], label='DeepMD')
plt.scatter(exp_pd['T'], exp_pd['P']*1e-3, c='gray', label='exp', marker='.')
plt.scatter(ih_liq[0,:],ih_liq[1,:], label='ih-liq', marker='.')
plt.scatter(v_liq[0,:],v_liq[1,:], label='v-liq', marker='.')
plt.scatter(vi_liq[0,:],vi_liq[1,:], label='vi-liq', marker='.')
plt.yscale('log')

plt.scatter(T_triple_ih_liq, P_triple_ih_liq, marker='*', color='k')
plt.scatter(T_triple_v_vi, P_triple_v_vi, marker='*', color='k', label='Triples')

plt.legend(frameon=0, loc='best', fontsize=12, ncol=2)
