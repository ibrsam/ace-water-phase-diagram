# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram\
/GibbsDuhemSimulations/IceII_Liquid/Initial/IceII/iceII.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'H'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 11:47:32    -6238.596941*       2.4495
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 11:47:35    -6260.026631*       0.6158
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations\
/IceIh_Liquid/Initial/IceIh/water.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'H'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 11:48:20    -4179.602444*       0.2890
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('export CUDA_VISIBLE_DEVICES=0;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('export CUDA_VISIBLE_DEVICES=0;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-ih/ii'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-ih/ih'


T = 269.618; P = 3828; T_step = -3
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**5
barostat_ph1 = 'tri'; barostat_ph2 = 'aniso'

skip = 100
n_pnts = 80

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_269.618_P_3828 has been executed and will be used
# Simulations_ph2_T_269.618_P_3828 has been executed and will be used
# Simulations_ph1_T_268.118_P_3836.824809271761 has been executed and will be used
# Simulations_ph2_T_268.118_P_3836.824809271761 has been executed and will be used
# Simulations_ph1_T_268.118_P_3835.141349843092 has been executed and will be used
# Simulations_ph2_T_268.118_P_3835.141349843092 has been executed and will be used
# Simulations_ph1_T_266.618_P_3836.9690064246893 has been executed and will be used
# Simulations_ph2_T_266.618_P_3836.9690064246893 has been executed and will be used
# Simulations_ph1_T_266.618_P_3840.048257319443 has been executed and will be used
# Simulations_ph2_T_266.618_P_3840.048257319443 has been executed and will be used
# Simulations_ph1_T_265.118_P_3844.9404127607045 has been executed and will be used
# Simulations_ph2_T_265.118_P_3844.9404127607045 has been executed and will be used
# Simulations_ph1_T_265.118_P_3847.0680305824335 has been executed and will be used
# Simulations_ph2_T_265.118_P_3847.0680305824335 has been executed and will be used
# Simulations_ph1_T_263.618_P_3849.777105450107 has been executed and will be used
# Simulations_ph2_T_263.618_P_3849.777105450107 has been executed and will be used
# Simulations_ph1_T_263.618_P_3851.886734004403 has been executed and will be used
# Simulations_ph2_T_263.618_P_3851.886734004403 has been executed and will be used
# Simulations_ph1_T_262.118_P_3858.290376890381 has been executed and will be used
# Simulations_ph2_T_262.118_P_3858.290376890381 has been executed and will be used
# Simulations_ph1_T_262.118_P_3855.239097272346 has been executed and will be used
# Simulations_ph2_T_262.118_P_3855.239097272346 has been executed and will be used
# Simulations_ph1_T_260.618_P_3863.2209335607577 has been executed and will be used
# Simulations_ph2_T_260.618_P_3863.2209335607577 has been executed and will be used
# Simulations_ph1_T_260.618_P_3861.6065427962094 has been executed and will be used
# Simulations_ph2_T_260.618_P_3861.6065427962094 has been executed and will be used
# Simulations_ph1_T_259.118_P_3868.352593412452 has been executed and will be used
# Simulations_ph2_T_259.118_P_3868.352593412452 has been executed and will be used
# Simulations_ph1_T_259.118_P_3865.673230524636 has been executed and will be used
# Simulations_ph2_T_259.118_P_3865.673230524636 has been executed and will be used
# Simulations_ph1_T_257.618_P_3872.5161603852307 has been executed and will be used
# Simulations_ph2_T_257.618_P_3872.5161603852307 has been executed and will be used
# Simulations_ph1_T_257.618_P_3872.0797737705266 has been executed and will be used
# Simulations_ph2_T_257.618_P_3872.0797737705266 has been executed and will be used
# Simulations_ph1_T_256.118_P_3875.5070290351937 has been executed and will be used
# Simulations_ph2_T_256.118_P_3875.5070290351937 has been executed and will be used
# Simulations_ph1_T_256.118_P_3878.78538115397 has been executed and will be used
# Simulations_ph2_T_256.118_P_3878.78538115397 has been executed and will be used
# Simulations_ph1_T_254.618_P_3881.3979835562927 has been executed and will be used
# Simulations_ph2_T_254.618_P_3881.3979835562927 has been executed and will be used
# Simulations_ph1_T_254.618_P_3882.5136788040854 has been executed and will be used
# Simulations_ph2_T_254.618_P_3882.5136788040854 has been executed and will be used
# Simulations_ph1_T_253.118_P_3887.231836742464 has been executed and will be used
# Simulations_ph2_T_253.118_P_3887.231836742464 has been executed and will be used
# Simulations_ph1_T_253.118_P_3887.3568635535134 has been executed and will be used
# Simulations_ph2_T_253.118_P_3887.3568635535134 has been executed and will be used
# Simulations_ph1_T_251.618_P_3892.141841055154 has been executed and will be used
# Simulations_ph2_T_251.618_P_3892.141841055154 has been executed and will be used
# Simulations_ph1_T_251.618_P_3892.055258040641 has been executed and will be used
# Simulations_ph2_T_251.618_P_3892.055258040641 has been executed and will be used
# Simulations_ph1_T_250.118_P_3896.876094269414 has been executed and will be used
# Simulations_ph2_T_250.118_P_3896.876094269414 has been executed and will be used
# Simulations_ph1_T_250.118_P_3898.8225031993466 has been executed and will be used
# Simulations_ph2_T_250.118_P_3898.8225031993466 has been executed and will be used
# Simulations_ph1_T_248.618_P_3902.5532335117223 has been executed and will be used
# Simulations_ph2_T_248.618_P_3902.5532335117223 has been executed and will be used
# Simulations_ph1_T_248.618_P_3903.525495256286 has been executed and will be used
# Simulations_ph2_T_248.618_P_3903.525495256286 has been executed and will be used
# Simulations_ph1_T_247.118_P_3907.949364698691 has been executed and will be used
# Simulations_ph2_T_247.118_P_3907.949364698691 has been executed and will be used
# Simulations_ph1_T_247.118_P_3908.960272398733 has been executed and will be used
# Simulations_ph2_T_247.118_P_3908.960272398733 has been executed and will be used
# Simulations_ph1_T_245.618_P_3910.5954653218037 has been executed and will be used
# Simulations_ph2_T_245.618_P_3910.5954653218037 has been executed and will be used
# Simulations_ph1_T_245.618_P_3912.6378856344068 has been executed and will be used
# Simulations_ph2_T_245.618_P_3912.6378856344068 has been executed and will be used
# Simulations_ph1_T_244.118_P_3915.4781779407303 has been executed and will be used
# Simulations_ph2_T_244.118_P_3915.4781779407303 has been executed and will be used
# Simulations_ph1_T_244.118_P_3919.175771672741 has been executed and will be used
# Simulations_ph2_T_244.118_P_3919.175771672741 has been executed and will be used
# Simulations_ph1_T_242.618_P_3921.1802365130884 has been executed and will be used
# Simulations_ph2_T_242.618_P_3921.1802365130884 has been executed and will be used
# Simulations_ph1_T_242.618_P_3922.413107073025 has been executed and will be used
# Simulations_ph2_T_242.618_P_3922.413107073025 has been executed and will be used
# Simulations_ph1_T_241.118_P_3926.1906525865093 has been executed and will be used
# Simulations_ph2_T_241.118_P_3926.1906525865093 has been executed and will be used
# Simulations_ph1_T_241.118_P_3927.3977365168344 has been executed and will be used
# Simulations_ph2_T_241.118_P_3927.3977365168344 has been executed and will be used
# Simulations_ph1_T_239.618_P_3933.19498217914 has been executed and will be used
# Simulations_ph2_T_239.618_P_3933.19498217914 has been executed and will be used
# Simulations_ph1_T_239.618_P_3931.8664705751794 has been executed and will be used
# Simulations_ph2_T_239.618_P_3931.8664705751794 has been executed and will be used
# Simulations_ph1_T_238.118_P_3937.2572542274384 has been executed and will be used
# Simulations_ph2_T_238.118_P_3937.2572542274384 has been executed and will be used
# Simulations_ph1_T_238.118_P_3934.7876642131296 has been executed and will be used
# Simulations_ph2_T_238.118_P_3934.7876642131296 has been executed and will be used
# Simulations_ph1_T_236.618_P_3943.7291624643553 has been executed and will be used
# Simulations_ph2_T_236.618_P_3943.7291624643553 has been executed and will be used
# Simulations_ph1_T_236.618_P_3940.452636764494 has been executed and will be used
# Simulations_ph2_T_236.618_P_3940.452636764494 has been executed and will be used
# Simulations_ph1_T_235.118_P_3945.8752266651168 has been executed and will be used
# Simulations_ph2_T_235.118_P_3945.8752266651168 has been executed and will be used
# Simulations_ph1_T_235.118_P_3942.4248390897933 has been executed and will be used
# Simulations_ph2_T_235.118_P_3942.4248390897933 has been executed and will be used
# Simulations_ph1_T_233.618_P_3950.1722868135844 has been executed and will be used
# Simulations_ph2_T_233.618_P_3950.1722868135844 has been executed and will be used
# Simulations_ph1_T_233.618_P_3948.1525715152206 has been executed and will be used
# Simulations_ph2_T_233.618_P_3948.1525715152206 has been executed and will be used
# Simulations_ph1_T_232.118_P_3952.514040456375 has been executed and will be used
# Simulations_ph2_T_232.118_P_3952.514040456375 has been executed and will be used
# Simulations_ph1_T_232.118_P_3952.068853129726 has been executed and will be used
# Simulations_ph2_T_232.118_P_3952.068853129726 has been executed and will be used
# Simulations_ph1_T_230.618_P_3954.4050934803927 has been executed and will be used
# Simulations_ph2_T_230.618_P_3954.4050934803927 has been executed and will be used
# Simulations_ph1_T_230.618_P_3955.3026758276133 has been executed and will be used
# Simulations_ph2_T_230.618_P_3955.3026758276133 has been executed and will be used
# Simulations_ph1_T_229.118_P_3960.2653872805163 has been executed and will be used
# Simulations_ph2_T_229.118_P_3960.2653872805163 has been executed and will be used
# Simulations_ph1_T_229.118_P_3957.8168223252087 has been executed and will be used
# Simulations_ph2_T_229.118_P_3957.8168223252087 has been executed and will be used
# Simulations_ph1_T_227.618_P_3964.9887630518047 has been executed and will be used
# Simulations_ph2_T_227.618_P_3964.9887630518047 has been executed and will be used
# Simulations_ph1_T_227.618_P_3962.8185206433527 has been executed and will be used
# Simulations_ph2_T_227.618_P_3962.8185206433527 has been executed and will be used
# Simulations_ph1_T_226.118_P_3967.0162998983633 has been executed and will be used
# Simulations_ph2_T_226.118_P_3967.0162998983633 has been executed and will be used
# Simulations_ph1_T_226.118_P_3966.7384900091965 has been executed and will be used
# Simulations_ph2_T_226.118_P_3966.7384900091965 has been executed and will be used
# Simulations_ph1_T_224.618_P_3971.020898192962 has been executed and will be used
# Simulations_ph2_T_224.618_P_3971.020898192962 has been executed and will be used
# Simulations_ph1_T_224.618_P_3970.3078156947804 has been executed and will be used
# Simulations_ph2_T_224.618_P_3970.3078156947804 has been executed and will be used
# Simulations_ph1_T_223.118_P_3973.3787271127208 has been executed and will be used
# Simulations_ph2_T_223.118_P_3973.3787271127208 has been executed and will be used
# Simulations_ph1_T_223.118_P_3973.1640736655936 has been executed and will be used
# Simulations_ph2_T_223.118_P_3973.1640736655936 has been executed and will be used
# Simulations_ph1_T_221.618_P_3976.752044143405 has been executed and will be used
# Simulations_ph2_T_221.618_P_3976.752044143405 has been executed and will be used
# Simulations_ph1_T_221.618_P_3976.617857928992 has been executed and will be used
# Simulations_ph2_T_221.618_P_3976.617857928992 has been executed and will be used
# Simulations_ph1_T_220.118_P_3981.0621357515024 has been executed and will be used
# Simulations_ph2_T_220.118_P_3981.0621357515024 has been executed and will be used
# Simulations_ph1_T_220.118_P_3981.4568256221773 has been executed and will be used
# Simulations_ph2_T_220.118_P_3981.4568256221773 has been executed and will be used
# Simulations_ph1_T_218.618_P_3982.013441665038 has been executed and will be used
# Simulations_ph2_T_218.618_P_3982.013441665038 has been executed and will be used
# Simulations_ph1_T_218.618_P_3984.176782762604 has been executed and will be used
# Simulations_ph2_T_218.618_P_3984.176782762604 has been executed and will be used
# Simulations_ph1_T_217.118_P_3987.5924135605383 has been executed and will be used
# Simulations_ph2_T_217.118_P_3987.5924135605383 has been executed and will be used
# Simulations_ph1_T_217.118_P_3987.239488899262 has been executed and will be used
# Simulations_ph2_T_217.118_P_3987.239488899262 has been executed and will be used
# Simulations_ph1_T_215.618_P_3987.4921025730478 has been executed and will be used
# Simulations_ph2_T_215.618_P_3987.4921025730478 has been executed and will be used
# Simulations_ph1_T_215.618_P_3989.43277834487 has been executed and will be used
# Simulations_ph2_T_215.618_P_3989.43277834487 has been executed and will be used
# Simulations_ph1_T_214.118_P_3992.7973988111717 has been executed and will be used
# Simulations_ph2_T_214.118_P_3992.7973988111717 has been executed and will be used
# Simulations_ph1_T_214.118_P_3992.5564699911106 has been executed and will be used
# Simulations_ph2_T_214.118_P_3992.5564699911106 has been executed and will be used
# Simulations_ph1_T_212.618_P_3992.5077867088808 has been executed and will be used
# Simulations_ph2_T_212.618_P_3992.5077867088808 has been executed and will be used
# Simulations_ph1_T_212.618_P_3994.4391065549516 has been executed and will be used
# Simulations_ph2_T_212.618_P_3994.4391065549516 has been executed and will be used
# Simulations_ph1_T_211.118_P_3998.0576156987727 has been executed and will be used
# Simulations_ph2_T_211.118_P_3998.0576156987727 has been executed and will be used
# Simulations_ph1_T_211.118_P_3997.686519195131 has been executed and will be used
# Simulations_ph2_T_211.118_P_3997.686519195131 has been executed and will be used
# Simulations_ph1_T_209.618_P_4001.4972127054675 has been executed and will be used
# Simulations_ph2_T_209.618_P_4001.4972127054675 has been executed and will be used
# Simulations_ph1_T_209.618_P_4001.3234864256456 has been executed and will be used
# Simulations_ph2_T_209.618_P_4001.3234864256456 has been executed and will be used
# Simulations_ph1_T_208.118_P_4004.132005526496 has been executed and will be used
# Simulations_ph2_T_208.118_P_4004.132005526496 has been executed and will be used
# Simulations_ph1_T_208.118_P_4002.810781308476 has been executed and will be used
# Simulations_ph2_T_208.118_P_4002.810781308476 has been executed and will be used
# Simulations_ph1_T_206.618_P_4005.904629608983 has been executed and will be used
# Simulations_ph2_T_206.618_P_4005.904629608983 has been executed and will be used
# Simulations_ph1_T_206.618_P_4005.544295295132 has been executed and will be used
# Simulations_ph2_T_206.618_P_4005.544295295132 has been executed and will be used
# Simulations_ph1_T_205.118_P_4007.317060350649 has been executed and will be used
# Simulations_ph2_T_205.118_P_4007.317060350649 has been executed and will be used
# Simulations_ph1_T_205.118_P_4008.553723754421 has been executed and will be used
# Simulations_ph2_T_205.118_P_4008.553723754421 has been executed and will be used
# Simulations_ph1_T_203.618_P_4011.4791204548424 has been executed and will be used
# Simulations_ph2_T_203.618_P_4011.4791204548424 has been executed and will be used
# Simulations_ph1_T_203.618_P_4010.9376176146247 has been executed and will be used
# Simulations_ph2_T_203.618_P_4010.9376176146247 has been executed and will be used
# Simulations_ph1_T_202.118_P_4011.5639492754135 has been executed and will be used
# Simulations_ph2_T_202.118_P_4011.5639492754135 has been executed and will be used
# Simulations_ph1_T_202.118_P_4012.586475559918 has been executed and will be used
# Simulations_ph2_T_202.118_P_4012.586475559918 has been executed and will be used
# Simulations_ph1_T_200.618_P_4014.412931974124 has been executed and will be used
# Simulations_ph2_T_200.618_P_4014.412931974124 has been executed and will be used
# Simulations_ph1_T_200.618_P_4013.9169535591436 has been executed and will be used
# Simulations_ph2_T_200.618_P_4013.9169535591436 has been executed and will be used
# Simulations_ph1_T_199.118_P_4015.976021199321 has been executed and will be used
# Simulations_ph2_T_199.118_P_4015.976021199321 has been executed and will be used
# Simulations_ph1_T_199.118_P_4017.531936042978 has been executed and will be used
# Simulations_ph2_T_199.118_P_4017.531936042978 has been executed and will be used
# Simulations_ph1_T_197.618_P_4022.0281539884177 has been executed and will be used
# Simulations_ph2_T_197.618_P_4022.0281539884177 has been executed and will be used
# Simulations_ph1_T_197.618_P_4021.035684641385 has been executed and will be used
# Simulations_ph2_T_197.618_P_4021.035684641385 has been executed and will be used
# Simulations_ph1_T_196.118_P_4023.905089513367 has been executed and will be used
# Simulations_ph2_T_196.118_P_4023.905089513367 has been executed and will be used
# Simulations_ph1_T_196.118_P_4023.3654727787707 has been executed and will be used
# Simulations_ph2_T_196.118_P_4023.3654727787707 has been executed and will be used
# Simulations_ph1_T_194.618_P_4027.4378219759856 has been executed and will be used
# Simulations_ph2_T_194.618_P_4027.4378219759856 has been executed and will be used
# Simulations_ph1_T_194.618_P_4026.589985406478 has been executed and will be used
# Simulations_ph2_T_194.618_P_4026.589985406478 has been executed and will be used
# Simulations_ph1_T_193.118_P_4030.0222843651677 has been executed and will be used
# Simulations_ph2_T_193.118_P_4030.0222843651677 has been executed and will be used
# Simulations_ph1_T_193.118_P_4026.755979407944 has been executed and will be used
# Simulations_ph2_T_193.118_P_4026.755979407944 has been executed and will be used
# Simulations_ph1_T_191.618_P_4033.4171158313015 has been executed and will be used
# Simulations_ph2_T_191.618_P_4033.4171158313015 has been executed and will be used
# Simulations_ph1_T_191.618_P_4030.74543189839 has been executed and will be used
# Simulations_ph2_T_191.618_P_4030.74543189839 has been executed and will be used
# Simulations_ph1_T_190.118_P_4033.4457636096067 has been executed and will be used
# Simulations_ph2_T_190.118_P_4033.4457636096067 has been executed and will be used
# Simulations_ph1_T_190.118_P_4032.8314195500766 has been executed and will be used
# Simulations_ph2_T_190.118_P_4032.8314195500766 has been executed and will be used
# Simulations_ph1_T_188.618_P_4031.9286113818694 has been executed and will be used
# Simulations_ph2_T_188.618_P_4031.9286113818694 has been executed and will be used
# Simulations_ph1_T_188.618_P_4034.2054843861774 has been executed and will be used
# Simulations_ph2_T_188.618_P_4034.2054843861774 has been executed and will be used
# Simulations_ph1_T_187.118_P_4036.68428734092 has been executed and will be used
# Simulations_ph2_T_187.118_P_4036.68428734092 has been executed and will be used
# Simulations_ph1_T_187.118_P_4035.582650267836 has been executed and will be used
# Simulations_ph2_T_187.118_P_4035.582650267836 has been executed and will be used
# Simulations_ph1_T_185.618_P_4040.1805069261914 has been executed and will be used
# Simulations_ph2_T_185.618_P_4040.1805069261914 has been executed and will be used
# Simulations_ph1_T_185.618_P_4038.602816313509 has been executed and will be used
# Simulations_ph2_T_185.618_P_4038.602816313509 has been executed and will be used
# Simulations_ph1_T_184.118_P_4041.5206953624697 has been executed and will be used
# Simulations_ph2_T_184.118_P_4041.5206953624697 has been executed and will be used
# Simulations_ph1_T_184.118_P_4038.378565638962 has been executed and will be used
# Simulations_ph2_T_184.118_P_4038.378565638962 has been executed and will be used
# Simulations_ph1_T_182.618_P_4041.1305670374018 has been executed and will be used
# Simulations_ph2_T_182.618_P_4041.1305670374018 has been executed and will be used
# Simulations_ph1_T_182.618_P_4040.5235079439126 has been executed and will be used
# Simulations_ph2_T_182.618_P_4040.5235079439126 has been executed and will be used
# Simulations_ph1_T_181.118_P_4039.854868772564 has been executed and will be used
# Simulations_ph2_T_181.118_P_4039.854868772564 has been executed and will be used
# Simulations_ph1_T_181.118_P_4043.357414511834 has been executed and will be used
# Simulations_ph2_T_181.118_P_4043.357414511834 has been executed and will be used
# Simulations_ph1_T_179.618_P_4044.27457718045 has been executed and will be used
# Simulations_ph2_T_179.618_P_4044.27457718045 has been executed and will be used
# Simulations_ph1_T_179.618_P_4043.6403357941604 has been executed and will be used
# Simulations_ph2_T_179.618_P_4043.6403357941604 has been executed and will be used
# Simulations_ph1_T_178.118_P_4044.6396787543777 has been executed and will be used
# Simulations_ph2_T_178.118_P_4044.6396787543777 has been executed and will be used
# Simulations_ph1_T_178.118_P_4046.0143817740527 has been executed and will be used
# Simulations_ph2_T_178.118_P_4046.0143817740527 has been executed and will be used
# Simulations_ph1_T_176.618_P_4046.94772398744 has been executed and will be used
# Simulations_ph2_T_176.618_P_4046.94772398744 has been executed and will be used
# Simulations_ph1_T_176.618_P_4047.5299952116725 has been executed and will be used
# Simulations_ph2_T_176.618_P_4047.5299952116725 has been executed and will be used
# Simulations_ph1_T_175.118_P_4047.709884197067 has been executed and will be used
# Simulations_ph2_T_175.118_P_4047.709884197067 has been executed and will be used
# Simulations_ph1_T_175.118_P_4049.544527866773 has been executed and will be used
# Simulations_ph2_T_175.118_P_4049.544527866773 has been executed and will be used
# Simulations_ph1_T_173.618_P_4045.4905696496985 has been executed and will be used
# Simulations_ph2_T_173.618_P_4045.4905696496985 has been executed and will be used
# Simulations_ph1_T_173.618_P_4049.3857861928786 has been executed and will be used
# Simulations_ph2_T_173.618_P_4049.3857861928786 has been executed and will be used
# Simulations_ph1_T_172.118_P_4050.6464651972406 has been executed and will be used
# Simulations_ph2_T_172.118_P_4050.6464651972406 has been executed and will be used
# Simulations_ph1_T_172.118_P_4051.0414786736483 has been executed and will be used
# Simulations_ph2_T_172.118_P_4051.0414786736483 has been executed and will be used
# Simulations_ph1_T_170.618_P_4052.276961289311 has been executed and will be used
# Simulations_ph2_T_170.618_P_4052.276961289311 has been executed and will be used
# Simulations_ph1_T_170.618_P_4052.602181892266 has been executed and will be used
# Simulations_ph2_T_170.618_P_4052.602181892266 has been executed and will be used
# Simulations_ph1_T_169.118_P_4053.518992975807 has been executed and will be used
# Simulations_ph2_T_169.118_P_4053.518992975807 has been executed and will be used
# Simulations_ph1_T_169.118_P_4053.494238189426 has been executed and will be used
# Simulations_ph2_T_169.118_P_4053.494238189426 has been executed and will be used
# Simulations_ph1_T_167.618_P_4055.543530140923 has been executed and will be used
# Simulations_ph2_T_167.618_P_4055.543530140923 has been executed and will be used
# Simulations_ph1_T_167.618_P_4054.550610308355 has been executed and will be used
# Simulations_ph2_T_167.618_P_4054.550610308355 has been executed and will be used
# Simulations_ph1_T_166.118_P_4053.5996178534015 has been executed and will be used
# Simulations_ph2_T_166.118_P_4053.5996178534015 has been executed and will be used
# Simulations_ph1_T_166.118_P_4054.7337554895894 has been executed and will be used
# Simulations_ph2_T_166.118_P_4054.7337554895894 has been executed and will be used
# Simulations_ph1_T_164.618_P_4060.1462395477515 has been executed and will be used
# Simulations_ph2_T_164.618_P_4060.1462395477515 has been executed and will be used
# Simulations_ph1_T_164.618_P_4056.573515925581 has been executed and will be used
# Simulations_ph2_T_164.618_P_4056.573515925581 has been executed and will be used
# Simulations_ph1_T_163.118_P_4057.8534489469603 has been executed and will be used
# Simulations_ph2_T_163.118_P_4057.8534489469603 has been executed and will be used
# Simulations_ph1_T_163.118_P_4058.9542362092925 has been executed and will be used
# Simulations_ph2_T_163.118_P_4058.9542362092925 has been executed and will be used
# Simulations_ph1_T_161.618_P_4062.041249354232 has been executed and will be used
# Simulations_ph2_T_161.618_P_4062.041249354232 has been executed and will be used
# Simulations_ph1_T_161.618_P_4061.373475271805 has been executed and will be used
# Simulations_ph2_T_161.618_P_4061.373475271805 has been executed and will be used
# Simulations_ph1_T_160.118_P_4062.366814885009 has been executed and will be used
# Simulations_ph2_T_160.118_P_4062.366814885009 has been executed and will be used
# Simulations_ph1_T_160.118_P_4063.5015951815435 has been executed and will be used
# Simulations_ph2_T_160.118_P_4063.5015951815435 has been executed and will be used
# Simulations_ph1_T_158.618_P_4065.797926858874 has been executed and will be used
# Simulations_ph2_T_158.618_P_4065.797926858874 has been executed and will be used
# Simulations_ph1_T_158.618_P_4064.758575875456 has been executed and will be used
# Simulations_ph2_T_158.618_P_4064.758575875456 has been executed and will be used
# Simulations_ph1_T_157.118_P_4065.061155438171 has been executed and will be used
# Simulations_ph2_T_157.118_P_4065.061155438171 has been executed and will be used
# Simulations_ph1_T_157.118_P_4063.7118413199682 has been executed and will be used
# Simulations_ph2_T_157.118_P_4063.7118413199682 has been executed and will be used
# Simulations_ph1_T_155.618_P_4070.4495019882884 has been executed and will be used
# Simulations_ph2_T_155.618_P_4070.4495019882884 has been executed and will be used
# Simulations_ph1_T_155.618_P_4066.572687121395 has been executed and will be used
# Simulations_ph2_T_155.618_P_4066.572687121395 has been executed and will be used
# Simulations_ph1_T_154.118_P_4067.2958632910368 has been executed and will be used
# Simulations_ph2_T_154.118_P_4067.2958632910368 has been executed and will be used
# Simulations_ph1_T_154.118_P_4067.5228632558687 has been executed and will be used
# Simulations_ph2_T_154.118_P_4067.5228632558687 has been executed and will be used
# Simulations_ph1_T_152.618_P_4065.5263269947295 has been executed and will be used
# Simulations_ph2_T_152.618_P_4065.5263269947295 has been executed and will be used
# Simulations_ph1_T_152.618_P_4067.5834712015553 has been executed and will be used
# Simulations_ph2_T_152.618_P_4067.5834712015553 has been executed and will be used
# Simulations_ph1_T_151.118_P_4067.836606065073 has been executed and will be used
# Simulations_ph2_T_151.118_P_4067.836606065073 has been executed and will be used
# Simulations_ph1_T_151.118_P_4069.0657769868917 has been executed and will be used
# Simulations_ph2_T_151.118_P_4069.0657769868917 has been executed and will be used
# Simulations_ph1_T_149.618_P_4066.9959126647004 has been executed and will be used
# Simulations_ph2_T_149.618_P_4066.9959126647004 has been executed and will be used
# Simulations_ph1_T_149.618_P_4068.743740801999 has been executed and will be used
# Simulations_ph2_T_149.618_P_4068.743740801999 has been executed and will be used
# Simulations_ph1_T_148.118_P_4068.4221647672025 has been executed and will be used
# Simulations_ph2_T_148.118_P_4068.4221647672025 has been executed and will be used
# Simulations_ph1_T_148.118_P_4070.7670712584277 has been executed and will be used
# Simulations_ph2_T_148.118_P_4070.7670712584277 has been executed and will be used
# Simulations_ph1_T_146.618_P_4072.6584127994256 has been executed and will be used
# Simulations_ph2_T_146.618_P_4072.6584127994256 has been executed and will be used
# Simulations_ph1_T_146.618_P_4071.5465109938636 has been executed and will be used
# Simulations_ph2_T_146.618_P_4071.5465109938636 has been executed and will be used
# Simulations_ph1_T_145.118_P_4072.7502329405584 has been executed and will be used
# Simulations_ph2_T_145.118_P_4072.7502329405584 has been executed and will be used
# Simulations_ph1_T_145.118_P_4070.7180531333292 has been executed and will be used
# Simulations_ph2_T_145.118_P_4070.7180531333292 has been executed and will be used
# Simulations_ph1_T_143.618_P_4072.8897108766996 has been executed and will be used
# Simulations_ph2_T_143.618_P_4072.8897108766996 has been executed and will be used
# Simulations_ph1_T_143.618_P_4072.021156648023 has been executed and will be used
# Simulations_ph2_T_143.618_P_4072.021156648023 has been executed and will be used
# Simulations_ph1_T_142.118_P_4073.7620900138245 has been executed and will be used
# Simulations_ph2_T_142.118_P_4073.7620900138245 has been executed and will be used
# Simulations_ph1_T_142.118_P_4072.6884141205046 has been executed and will be used
# Simulations_ph2_T_142.118_P_4072.6884141205046 has been executed and will be used
# Simulations_ph1_T_140.618_P_4068.5934915453436 has been executed and will be used
# Simulations_ph2_T_140.618_P_4068.5934915453436 has been executed and will be used
# Simulations_ph1_T_140.618_P_4071.394425996403 has been executed and will be used
# Simulations_ph2_T_140.618_P_4071.394425996403 has been executed and will be used
# Simulations_ph1_T_139.118_P_4073.135970199561 has been executed and will be used
# Simulations_ph2_T_139.118_P_4073.135970199561 has been executed and will be used
# Simulations_ph1_T_139.118_P_4072.1613424516477 has been executed and will be used
# Simulations_ph2_T_139.118_P_4072.1613424516477 has been executed and will be used
# Simulations_ph1_T_137.618_P_4071.226718185024 has been executed and will be used
# Simulations_ph2_T_137.618_P_4071.226718185024 has been executed and will be used
# Simulations_ph1_T_137.618_P_4071.900546505154 has been executed and will be used
# Simulations_ph2_T_137.618_P_4071.900546505154 has been executed and will be used
# Simulations_ph1_T_136.118_P_4072.7275719892004 has been executed and will be used
# Simulations_ph2_T_136.118_P_4072.7275719892004 has been executed and will be used
# Simulations_ph1_T_136.118_P_4071.6421709834676 has been executed and will be used
# Simulations_ph2_T_136.118_P_4071.6421709834676 has been executed and will be used
# Simulations_ph1_T_134.618_P_4069.340114734274 has been executed and will be used
# Simulations_ph2_T_134.618_P_4069.340114734274 has been executed and will be used
# Simulations_ph1_T_134.618_P_4070.843266013335 has been executed and will be used
# Simulations_ph2_T_134.618_P_4070.843266013335 has been executed and will be used
# Simulations_ph1_T_133.118_P_4071.4542715076177 has been executed and will be used
# Simulations_ph2_T_133.118_P_4071.4542715076177 has been executed and will be used
# Simulations_ph1_T_133.118_P_4070.435188952601 has been executed and will be used
# Simulations_ph2_T_133.118_P_4070.435188952601 has been executed and will be used
# Simulations_ph1_T_131.618_P_4070.77553369987 has been executed and will be used
# Simulations_ph2_T_131.618_P_4070.77553369987 has been executed and will be used
# Simulations_ph1_T_131.618_P_4070.2481205548515 has been executed and will be used
# Simulations_ph2_T_131.618_P_4070.2481205548515 has been executed and will be used
# Simulations_ph1_T_130.118_P_4071.13233961845 has been executed and will be used
# Simulations_ph2_T_130.118_P_4071.13233961845 has been executed and will be used
# Simulations_ph1_T_130.118_P_4069.5053193643644 has been executed and will be used
# Simulations_ph2_T_130.118_P_4069.5053193643644 has been executed and will be used
# Simulations_ph1_T_128.618_P_4069.7162064105096 has been executed and will be used
# Simulations_ph2_T_128.618_P_4069.7162064105096 has been executed and will be used
# Simulations_ph1_T_128.618_P_4069.9914424636686 has been executed and will be used
# Simulations_ph2_T_128.618_P_4069.9914424636686 has been executed and will be used
# Simulations_ph1_T_127.118_P_4068.267621761555 has been executed and will be used
# Simulations_ph2_T_127.118_P_4068.267621761555 has been executed and will be used
# Simulations_ph1_T_127.118_P_4070.2844695024482 has been executed and will be used
# Simulations_ph2_T_127.118_P_4070.2844695024482 has been executed and will be used
# Simulations_ph1_T_125.618_P_4066.951546555547 has been executed and will be used
# Simulations_ph2_T_125.618_P_4066.951546555547 has been executed and will be used
# Simulations_ph1_T_125.618_P_4069.0640918281306 has been executed and will be used
# Simulations_ph2_T_125.618_P_4069.0640918281306 has been executed and will be used
# Simulations_ph1_T_124.118_P_4069.0715363760696 has been executed and will be used
# Simulations_ph2_T_124.118_P_4069.0715363760696 has been executed and will be used
# Simulations_ph1_T_124.118_P_4069.22427933712 has been executed and will be used
# Simulations_ph2_T_124.118_P_4069.22427933712 has been executed and will be used
# Simulations_ph1_T_122.618_P_4069.211072444379 has been executed and will be used
# Simulations_ph2_T_122.618_P_4069.211072444379 has been executed and will be used
# Simulations_ph1_T_122.618_P_4069.264137038716 has been executed and will be used
# Simulations_ph2_T_122.618_P_4069.264137038716 has been executed and will be used
# Simulations_ph1_T_121.118_P_4070.075773978365 has been executed and will be used
# Simulations_ph2_T_121.118_P_4070.075773978365 has been executed and will be used
# Simulations_ph1_T_121.118_P_4067.9361680613206 has been executed and will be used
# Simulations_ph2_T_121.118_P_4067.9361680613206 has been executed and will be used
# Simulations_ph1_T_119.618_P_4068.0789973656256 has been executed and will be used
# Simulations_ph2_T_119.618_P_4068.0789973656256 has been executed and will be used
# Simulations_ph1_T_119.618_P_4068.226811227139 has been executed and will be used
# Simulations_ph2_T_119.618_P_4068.226811227139 has been executed and will be used
# Simulations_ph1_T_118.118_P_4069.7071890599746 has been executed and will be used
# Simulations_ph2_T_118.118_P_4069.7071890599746 has been executed and will be used
# Simulations_ph1_T_118.118_P_4068.504995507323 has been executed and will be used
# Simulations_ph2_T_118.118_P_4068.504995507323 has been executed and will be used
# Simulations_ph1_T_116.618_P_4065.551406140985 has been executed and will be used
# Simulations_ph2_T_116.618_P_4065.551406140985 has been executed and will be used
# Simulations_ph1_T_116.618_P_4068.006438096189 has been executed and will be used
# Simulations_ph2_T_116.618_P_4068.006438096189 has been executed and will be used
# Simulations_ph1_T_115.118_P_4067.327232609328 has been executed and will be used
# Simulations_ph2_T_115.118_P_4067.327232609328 has been executed and will be used
# Simulations_ph1_T_115.118_P_4066.8422967845477 has been executed and will be used
# Simulations_ph2_T_115.118_P_4066.8422967845477 has been executed and will be used
# Simulations_ph1_T_113.618_P_4067.4055236276727 has been executed and will be used
# Simulations_ph2_T_113.618_P_4067.4055236276727 has been executed and will be used
# Simulations_ph1_T_113.618_P_4066.561927056377 has been executed and will be used
# Simulations_ph2_T_113.618_P_4066.561927056377 has been executed and will be used
# Simulations_ph1_T_112.118_P_4065.6002942038294 has been executed and will be used
# Simulations_ph2_T_112.118_P_4065.6002942038294 has been executed and will be used
# Simulations_ph1_T_112.118_P_4065.754887354063 has been executed and will be used
# Simulations_ph2_T_112.118_P_4065.754887354063 has been executed and will be used
# Simulations_ph1_T_110.618_P_4067.755387997356 has been executed and will be used
# Simulations_ph2_T_110.618_P_4067.755387997356 has been executed and will be used
# Simulations_ph1_T_110.618_P_4066.423980214928 has been executed and will be used
# Simulations_ph2_T_110.618_P_4066.423980214928 has been executed and will be used
# Simulations_ph1_T_109.118_P_4066.9369094746767 has been executed and will be used
# Simulations_ph2_T_109.118_P_4066.9369094746767 has been executed and will be used
# Simulations_ph1_T_109.118_P_4067.241457322426 has been executed and will be used
# Simulations_ph2_T_109.118_P_4067.241457322426 has been executed and will be used
# Simulations_ph1_T_107.618_P_4063.084995472169 has been executed and will be used
# Simulations_ph2_T_107.618_P_4063.084995472169 has been executed and will be used
# Simulations_ph1_T_107.618_P_4065.4248098770686 has been executed and will be used
# Simulations_ph2_T_107.618_P_4065.4248098770686 has been executed and will be used
# Simulations_ph1_T_106.118_P_4064.315307709145 has been executed and will be used
# Simulations_ph2_T_106.118_P_4064.315307709145 has been executed and will be used
# Simulations_ph1_T_106.118_P_4063.4801714029786 has been executed and will be used
# Simulations_ph2_T_106.118_P_4063.4801714029786 has been executed and will be used
# Simulations_ph1_T_104.618_P_4062.388519657568 has been executed and will be used
# Simulations_ph2_T_104.618_P_4062.388519657568 has been executed and will be used
# Simulations_ph1_T_104.618_P_4062.4967939281346 has been executed and will be used
# Simulations_ph2_T_104.618_P_4062.4967939281346 has been executed and will be used
# Simulations_ph1_T_103.118_P_4060.9411135743003 has been executed and will be used
# Simulations_ph2_T_103.118_P_4060.9411135743003 has been executed and will be used
# Simulations_ph1_T_103.118_P_4060.3851127676603 has been executed and will be used
# Simulations_ph2_T_103.118_P_4060.3851127676603 has been executed and will be used
# Simulations_ph1_T_101.618_P_4060.1515359949503 has been executed and will be used
# Simulations_ph2_T_101.618_P_4060.1515359949503 has been executed and will be used
# Simulations_ph1_T_101.618_P_4059.6475724706147 has been executed and will be used
# Simulations_ph2_T_101.618_P_4059.6475724706147 has been executed and will be used
# Simulations_ph1_T_100.118_P_4058.257598118501 has been executed and will be used
# Simulations_ph2_T_100.118_P_4058.257598118501 has been executed and will be used
# Simulations_ph1_T_100.118_P_4058.4184324409093 has been executed and will be used
# Simulations_ph2_T_100.118_P_4058.4184324409093 has been executed and will be used
# Simulations_ph1_T_98.618_P_4056.0739868437845 has been executed and will be used
# Simulations_ph2_T_98.618_P_4056.0739868437845 has been executed and will be used
# Simulations_ph1_T_98.618_P_4057.135317431278 has been executed and will be used
# Simulations_ph2_T_98.618_P_4057.135317431278 has been executed and will be used
# Simulations_ph1_T_97.118_P_4055.9975169686877 has been executed and will be used
# Simulations_ph2_T_97.118_P_4055.9975169686877 has been executed and will be used
# Simulations_ph1_T_97.118_P_4056.579363600184 has been executed and will be used
# Simulations_ph2_T_97.118_P_4056.579363600184 has been executed and will be used
# Simulations_ph1_T_95.618_P_4056.8427722802367 has been executed and will be used
# Simulations_ph2_T_95.618_P_4056.8427722802367 has been executed and will be used
# Simulations_ph1_T_95.618_P_4056.3151661549837 has been executed and will be used
# Simulations_ph2_T_95.618_P_4056.3151661549837 has been executed and will be used
# Simulations_ph1_T_94.118_P_4055.0905176570645 has been executed and will be used
# Simulations_ph2_T_94.118_P_4055.0905176570645 has been executed and will be used
# Simulations_ph1_T_94.118_P_4053.1447677265014 has been executed and will be used
# Simulations_ph2_T_94.118_P_4053.1447677265014 has been executed and will be used
# Simulations_ph1_T_92.618_P_4055.0024346353794 has been executed and will be used
# Simulations_ph2_T_92.618_P_4055.0024346353794 has been executed and will be used
# Simulations_ph1_T_92.618_P_4053.3372333403627 has been executed and will be used
# Simulations_ph2_T_92.618_P_4053.3372333403627 has been executed and will be used
# Simulations_ph1_T_91.118_P_4052.3617928810527 has been executed and will be used
# Simulations_ph2_T_91.118_P_4052.3617928810527 has been executed and will be used
# Simulations_ph1_T_91.118_P_4053.9654984925023 has been executed and will be used
# Simulations_ph2_T_91.118_P_4053.9654984925023 has been executed and will be used
# Simulations_ph1_T_89.618_P_4051.3832958737466 has been executed and will be used
# Simulations_ph2_T_89.618_P_4051.3832958737466 has been executed and will be used

# %%
plt.scatter(T_lst, P_lst)

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-ih/ii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='ii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-ih/ih_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='ih')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ii_ih.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
