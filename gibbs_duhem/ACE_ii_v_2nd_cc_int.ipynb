# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram\
/GibbsDuhemSimulations/IceII_Liquid/Initial/IceII/iceII.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 14:37:53    -6238.596941*       2.4495
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 14:37:56    -6260.026631*       0.6158
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/\
TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations/InitialConfigurations/IceV/iceV.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 14:38:03    -4834.065126*       2.3135
# BFGSLineSearch:    1[  2] 14:38:04    -4851.531667*       1.0293
# BFGSLineSearch:    2[  3] 14:38:05    -4860.725898*       2.6266
# BFGSLineSearch:    3[  5] 14:38:07    -4864.430067*       0.7583
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v-2/ii'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v-2/v'

T = 263.1503274251632; P = 2223.147977117857; T_step = -5
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**5
barostat_ph1 = 'tri'; barostat_ph2 = 'tri'

skip = 100
n_pnts = 20

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_263.1503274251632_P_2223.147977117857 has been executed and will be used
# Simulations_ph2_T_263.1503274251632_P_2223.147977117857 has been executed and will be used
# Simulations_ph1_T_260.6503274251632_P_2310.0568846251917 has been executed and will be used
# Simulations_ph2_T_260.6503274251632_P_2310.0568846251917 has been executed and will be used
# Simulations_ph1_T_260.6503274251632_P_2304.979753824149 has been executed and will be used
# Simulations_ph2_T_260.6503274251632_P_2304.979753824149 has been executed and will be used
# Simulations_ph1_T_258.1503274251632_P_2404.693755679706 has been executed and will be used
# Simulations_ph2_T_258.1503274251632_P_2404.693755679706 has been executed and will be used
# Simulations_ph1_T_258.1503274251632_P_2395.076724200926 has been executed and will be used
# Simulations_ph2_T_258.1503274251632_P_2395.076724200926 has been executed and will be used
# Simulations_ph1_T_255.6503274251632_P_2490.5080312575988 has been executed and will be used
# Simulations_ph2_T_255.6503274251632_P_2490.5080312575988 has been executed and will be used
# Simulations_ph1_T_255.6503274251632_P_2484.2852314279817 has been executed and will be used
# Simulations_ph2_T_255.6503274251632_P_2484.2852314279817 has been executed and will be used
# Simulations_ph1_T_253.1503274251632_P_2581.1691297860466 has been executed and will be used
# Simulations_ph2_T_253.1503274251632_P_2581.1691297860466 has been executed and will be used
# Simulations_ph1_T_253.1503274251632_P_2581.1182989892195 has been executed and will be used
# Simulations_ph2_T_253.1503274251632_P_2581.1182989892195 has been executed and will be used
# Simulations_ph1_T_250.6503274251632_P_2678.5496530817663 has been executed and will be used
# Simulations_ph2_T_250.6503274251632_P_2678.5496530817663 has been executed and will be used
# Simulations_ph1_T_250.6503274251632_P_2651.587498642359 has been executed and will be used
# Simulations_ph2_T_250.6503274251632_P_2651.587498642359 has been executed and will be used
# Simulations_ph1_T_248.1503274251632_P_2758.4338364713044 has been executed and will be used
# Simulations_ph2_T_248.1503274251632_P_2758.4338364713044 has been executed and will be used
# Simulations_ph1_T_248.1503274251632_P_2749.336102883358 has been executed and will be used
# Simulations_ph2_T_248.1503274251632_P_2749.336102883358 has been executed and will be used
# Simulations_ph1_T_245.6503274251632_P_2834.2366623954526 has been executed and will be used
# Simulations_ph2_T_245.6503274251632_P_2834.2366623954526 has been executed and will be used
# Simulations_ph1_T_245.6503274251632_P_2836.5963609687715 has been executed and will be used
# Simulations_ph2_T_245.6503274251632_P_2836.5963609687715 has been executed and will be used
# Simulations_ph1_T_243.1503274251632_P_2947.4195731260997 has been executed and will be used
# Simulations_ph2_T_243.1503274251632_P_2947.4195731260997 has been executed and will be used
# Simulations_ph1_T_243.1503274251632_P_2929.1284364700296 has been executed and will be used
# Simulations_ph2_T_243.1503274251632_P_2929.1284364700296 has been executed and will be used
# Simulations_ph1_T_240.6503274251632_P_3027.960389412114 has been executed and will be used
# Simulations_ph2_T_240.6503274251632_P_3027.960389412114 has been executed and will be used
# Simulations_ph1_T_240.6503274251632_P_3015.825049143374 has been executed and will be used
# Simulations_ph2_T_240.6503274251632_P_3015.825049143374 has been executed and will be used
# Simulations_ph1_T_238.1503274251632_P_3132.810857906907 has been executed and will be used
# Simulations_ph2_T_238.1503274251632_P_3132.810857906907 has been executed and will be used
# Simulations_ph1_T_238.1503274251632_P_3114.840699394078 has been executed and will be used
# Simulations_ph2_T_238.1503274251632_P_3114.840699394078 has been executed and will be used
# Simulations_ph1_T_235.6503274251632_P_3203.374513136367 has been executed and will be used
# Simulations_ph2_T_235.6503274251632_P_3203.374513136367 has been executed and will be used
# Simulations_ph1_T_235.6503274251632_P_3199.7814983755393 has been executed and will be used
# Simulations_ph2_T_235.6503274251632_P_3199.7814983755393 has been executed and will be used
# Simulations_ph1_T_233.1503274251632_P_3314.671915557191 has been executed and will be used
# Simulations_ph2_T_233.1503274251632_P_3314.671915557191 has been executed and will be used
# Simulations_ph1_T_233.1503274251632_P_3301.2898844881975 has been executed and will be used
# Simulations_ph2_T_233.1503274251632_P_3301.2898844881975 has been executed and will be used
# Simulations_ph1_T_230.6503274251632_P_3401.841588139466 has been executed and will be used
# Simulations_ph2_T_230.6503274251632_P_3401.841588139466 has been executed and will be used
# Simulations_ph1_T_230.6503274251632_P_3386.445561900422 has been executed and will be used
# Simulations_ph2_T_230.6503274251632_P_3386.445561900422 has been executed and will be used
# Simulations_ph1_T_228.1503274251632_P_3521.154668960919 has been executed and will be used
# Simulations_ph2_T_228.1503274251632_P_3521.154668960919 has been executed and will be used
# Simulations_ph1_T_228.1503274251632_P_3498.3492677128124 has been executed and will be used
# Simulations_ph2_T_228.1503274251632_P_3498.3492677128124 has been executed and will be used
# Simulations_ph1_T_225.6503274251632_P_3598.8594269243636 has been executed and will be used
# Simulations_ph2_T_225.6503274251632_P_3598.8594269243636 has been executed and will be used
# Simulations_ph1_T_225.6503274251632_P_3589.6970453817394 has been executed and will be used
# Simulations_ph2_T_225.6503274251632_P_3589.6970453817394 has been executed and will be used
# Simulations_ph1_T_223.1503274251632_P_3664.5420789441046 has been executed and will be used
# Simulations_ph2_T_223.1503274251632_P_3664.5420789441046 has been executed and will be used
# Simulations_ph1_T_223.1503274251632_P_3681.6834927578857 has been executed and will be used
# Simulations_ph2_T_223.1503274251632_P_3681.6834927578857 has been executed and will be used
# Simulations_ph1_T_220.6503274251632_P_3781.3875504787216 has been executed and will be used
# Simulations_ph2_T_220.6503274251632_P_3781.3875504787216 has been executed and will be used
# Simulations_ph1_T_220.6503274251632_P_3759.170567488204 has been executed and will be used
# Simulations_ph2_T_220.6503274251632_P_3759.170567488204 has been executed and will be used
# Simulations_ph1_T_218.1503274251632_P_3906.9458901882595 has been executed and will be used
# Simulations_ph2_T_218.1503274251632_P_3906.9458901882595 has been executed and will be used
# Simulations_ph1_T_218.1503274251632_P_3878.4858902470564 has been executed and will be used
# Simulations_ph2_T_218.1503274251632_P_3878.4858902470564 has been executed and will be used
# Simulations_ph1_T_215.6503274251632_P_3972.3777213420162 has been executed and will be used
# Simulations_ph2_T_215.6503274251632_P_3972.3777213420162 has been executed and will be used
# Simulations_ph1_T_215.6503274251632_P_3992.783924371757 has been executed and will be used
# Simulations_ph2_T_215.6503274251632_P_3992.783924371757 has been executed and will be used
# Simulations_ph1_T_213.1503274251632_P_4103.474069798711 has been executed and will be used
# Simulations_ph2_T_213.1503274251632_P_4103.474069798711 has been executed and will be used
# Simulations_ph1_T_213.1503274251632_P_4099.14713521463 has been executed and will be used
# Simulations_ph2_T_213.1503274251632_P_4099.14713521463 has been executed and will be used
# Simulations_ph1_T_210.6503274251632_P_4184.745706792649 has been executed and will be used
# Simulations_ph2_T_210.6503274251632_P_4184.745706792649 has been executed and will be used
# Simulations_ph1_T_210.6503274251632_P_4197.410002246794 has been executed and will be used
# Simulations_ph2_T_210.6503274251632_P_4197.410002246794 has been executed and will be used
# Simulations_ph1_T_208.1503274251632_P_4301.096167899671 has been executed and will be used
# Simulations_ph2_T_208.1503274251632_P_4301.096167899671 has been executed and will be used
# Simulations_ph1_T_208.1503274251632_P_4288.017423461961 has been executed and will be used
# Simulations_ph2_T_208.1503274251632_P_4288.017423461961 has been executed and will be used
# Simulations_ph1_T_205.6503274251632_P_4373.827594180387 has been executed and will be used
# Simulations_ph2_T_205.6503274251632_P_4373.827594180387 has been executed and will be used
# Simulations_ph1_T_205.6503274251632_P_4391.747704550312 has been executed and will be used
# Simulations_ph2_T_205.6503274251632_P_4391.747704550312 has been executed and will be used
# Simulations_ph1_T_203.1503274251632_P_4469.394184312546 has been executed and will be used
# Simulations_ph2_T_203.1503274251632_P_4469.394184312546 has been executed and will be used
# Simulations_ph1_T_203.1503274251632_P_4477.248804443098 has been executed and will be used
# Simulations_ph2_T_203.1503274251632_P_4477.248804443098 has been executed and will be used
# Simulations_ph1_T_200.6503274251632_P_4586.347902688832 has been executed and will be used
# Simulations_ph2_T_200.6503274251632_P_4586.347902688832 has been executed and will be used
# Simulations_ph1_T_200.6503274251632_P_4564.459347871754 has been executed and will be used
# Simulations_ph2_T_200.6503274251632_P_4564.459347871754 has been executed and will be used
# Simulations_ph1_T_198.1503274251632_P_4674.315340115187 has been executed and will be used
# Simulations_ph2_T_198.1503274251632_P_4674.315340115187 has been executed and will be used
# Simulations_ph1_T_198.1503274251632_P_4674.2938901659345 has been executed and will be used
# Simulations_ph2_T_198.1503274251632_P_4674.2938901659345 has been executed and will be used
# Simulations_ph1_T_195.6503274251632_P_4775.297258742933 has been executed and will be used
# Simulations_ph2_T_195.6503274251632_P_4775.297258742933 has been executed and will be used
# Simulations_ph1_T_195.6503274251632_P_4775.477552473718 has been executed and will be used
# Simulations_ph2_T_195.6503274251632_P_4775.477552473718 has been executed and will be used
# Simulations_ph1_T_193.1503274251632_P_4883.523454772244 has been executed and will be used
# Simulations_ph2_T_193.1503274251632_P_4883.523454772244 has been executed and will be used
# Simulations_ph1_T_193.1503274251632_P_4890.480625226693 has been executed and will be used
# Simulations_ph2_T_193.1503274251632_P_4890.480625226693 has been executed and will be used
# Simulations_ph1_T_190.6503274251632_P_4981.75400051268 has been executed and will be used
# Simulations_ph2_T_190.6503274251632_P_4981.75400051268 has been executed and will be used
# Simulations_ph1_T_190.6503274251632_P_4990.068961086007 has been executed and will be used
# Simulations_ph2_T_190.6503274251632_P_4990.068961086007 has been executed and will be used
# Simulations_ph1_T_188.1503274251632_P_5085.096324381181 has been executed and will be used
# Simulations_ph2_T_188.1503274251632_P_5085.096324381181 has been executed and will be used
# Simulations_ph1_T_188.1503274251632_P_5086.447733146751 has been executed and will be used
# Simulations_ph2_T_188.1503274251632_P_5086.447733146751 has been executed and will be used
# Simulations_ph1_T_185.6503274251632_P_5203.583843383486 has been executed and will be used
# Simulations_ph2_T_185.6503274251632_P_5203.583843383486 has been executed and will be used
# Simulations_ph1_T_185.6503274251632_P_5198.610967222353 has been executed and will be used
# Simulations_ph2_T_185.6503274251632_P_5198.610967222353 has been executed and will be used
# Simulations_ph1_T_183.1503274251632_P_5304.82515515155 has been executed and will be used
# Simulations_ph2_T_183.1503274251632_P_5304.82515515155 has been executed and will be used
# Simulations_ph1_T_183.1503274251632_P_5304.59592612131 has been executed and will be used
# Simulations_ph2_T_183.1503274251632_P_5304.59592612131 has been executed and will be used
# Simulations_ph1_T_180.6503274251632_P_5417.489804211826 has been executed and will be used
# Simulations_ph2_T_180.6503274251632_P_5417.489804211826 has been executed and will be used
# Simulations_ph1_T_180.6503274251632_P_5398.379134167738 has been executed and will be used
# Simulations_ph2_T_180.6503274251632_P_5398.379134167738 has been executed and will be used
# Simulations_ph1_T_178.1503274251632_P_5465.878331302259 has been executed and will be used
# Simulations_ph2_T_178.1503274251632_P_5465.878331302259 has been executed and will be used
# Simulations_ph1_T_178.1503274251632_P_5488.221732778797 has been executed and will be used
# Simulations_ph2_T_178.1503274251632_P_5488.221732778797 has been executed and will be used
# Simulations_ph1_T_175.6503274251632_P_5591.7918688757745 has been executed and will be used
# Simulations_ph2_T_175.6503274251632_P_5591.7918688757745 has been executed and will be used
# Simulations_ph1_T_175.6503274251632_P_5594.284283107606 has been executed and will be used
# Simulations_ph2_T_175.6503274251632_P_5594.284283107606 has been executed and will be used
# Simulations_ph1_T_173.1503274251632_P_5679.3106675661775 has been executed and will be used
# Simulations_ph2_T_173.1503274251632_P_5679.3106675661775 has been executed and will be used
# Simulations_ph1_T_173.1503274251632_P_5700.072477359415 has been executed and will be used
# Simulations_ph2_T_173.1503274251632_P_5700.072477359415 has been executed and will be used
# Simulations_ph1_T_170.6503274251632_P_5803.909909176062 has been executed and will be used
# Simulations_ph2_T_170.6503274251632_P_5803.909909176062 has been executed and will be used
# Simulations_ph1_T_170.6503274251632_P_5808.958345064656 has been executed and will be used
# Simulations_ph2_T_170.6503274251632_P_5808.958345064656 has been executed and will be used
# Simulations_ph1_T_168.1503274251632_P_5917.620488235212 has been executed and will be used
# Simulations_ph2_T_168.1503274251632_P_5917.620488235212 has been executed and will be used
# Simulations_ph1_T_168.1503274251632_P_5918.352916545016 has been executed and will be used
# Simulations_ph2_T_168.1503274251632_P_5918.352916545016 has been executed and will be used
# Simulations_ph1_T_165.6503274251632_P_6017.8500621845005 has been executed and will be used
# Simulations_ph2_T_165.6503274251632_P_6017.8500621845005 has been executed and will be used
# Simulations_ph1_T_165.6503274251632_P_6006.858601958811 has been executed and will be used
# Simulations_ph2_T_165.6503274251632_P_6006.858601958811 has been executed and will be used
# Simulations_ph1_T_163.1503274251632_P_6179.523176009174 has been executed and will be used
# Simulations_ph2_T_163.1503274251632_P_6179.523176009174 has been executed and will be used

# %%
plt.scatter(T_lst, P_lst)

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/ii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='ii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/v_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='v')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()
# Out:
# cat: /home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/ii_T_263.1503274251632_P_2223.147977117857/lmp.out: No such file or directory
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 8
#       6 for i in range(n_pnts):
#       7     path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/ii_T_{T_lst[i]}_P_{P_lst[i]}'
# ----> 8     log = read_log(f'{path}')[-1]
#      11     ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='ii')
#      12     ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
#
# IndexError: list index out of range

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ii_v_2nd.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
