# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram\
/GibbsDuhemSimulations/IceII_Liquid/Initial/IceII/iceII.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 15:03:41    -6238.596941*       2.4495
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 15:03:44    -6260.026631*       0.6158
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/\
TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations/InitialConfigurations/IceV/iceV.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 15:03:45    -4834.065126*       2.3135
# BFGSLineSearch:    1[  2] 15:03:47    -4851.531667*       1.0293
# BFGSLineSearch:    2[  3] 15:03:48    -4860.725898*       2.6266
# BFGSLineSearch:    3[  5] 15:03:50    -4864.430067*       0.7583
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('nohup lmp_cic -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('nohup lmp_cic -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/ii'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/v'

T = 215.46856013394574; P = 3989.654484195611; T_step = -3
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**5
barostat_ph1 = 'tri'; barostat_ph2 = 'tri'

skip = 100
n_pnts = 45

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_215.46856013394574_P_3989.654484195611 has been executed and will be used
# Simulations_ph2_T_215.46856013394574_P_3989.654484195611 has been executed and will be used
# Simulations_ph1_T_213.96856013394574_P_4056.3553803275868 has been executed and will be used
# Simulations_ph2_T_213.96856013394574_P_4056.3553803275868 has been executed and will be used
# Simulations_ph1_T_213.96856013394574_P_4044.8572886548486 has been executed and will be used
# Simulations_ph2_T_213.96856013394574_P_4044.8572886548486 has been executed and will be used
# Simulations_ph1_T_212.46856013394574_P_4111.212923070891 has been executed and will be used
# Simulations_ph2_T_212.46856013394574_P_4111.212923070891 has been executed and will be used
# Simulations_ph1_T_212.46856013394574_P_4107.650439540343 has been executed and will be used
# Simulations_ph2_T_212.46856013394574_P_4107.650439540343 has been executed and will be used
# Simulations_ph1_T_210.96856013394574_P_4158.738594785081 has been executed and will be used
# Simulations_ph2_T_210.96856013394574_P_4158.738594785081 has been executed and will be used
# Simulations_ph1_T_210.96856013394574_P_4157.0458413468905 has been executed and will be used
# Simulations_ph2_T_210.96856013394574_P_4157.0458413468905 has been executed and will be used
# Simulations_ph1_T_209.46856013394574_P_4232.702354765783 has been executed and will be used
# Simulations_ph2_T_209.46856013394574_P_4232.702354765783 has been executed and will be used
# Simulations_ph1_T_209.46856013394574_P_4219.257893725843 has been executed and will be used
# Simulations_ph2_T_209.46856013394574_P_4219.257893725843 has been executed and will be used
# Simulations_ph1_T_207.96856013394574_P_4281.470496314234 has been executed and will be used
# Simulations_ph2_T_207.96856013394574_P_4281.470496314234 has been executed and will be used
# Simulations_ph1_T_207.96856013394574_P_4271.3256526855075 has been executed and will be used
# Simulations_ph2_T_207.96856013394574_P_4271.3256526855075 has been executed and will be used
# Simulations_ph1_T_206.46856013394574_P_4320.065566195696 has been executed and will be used
# Simulations_ph2_T_206.46856013394574_P_4320.065566195696 has been executed and will be used
# Simulations_ph1_T_206.46856013394574_P_4327.951316141233 has been executed and will be used
# Simulations_ph2_T_206.46856013394574_P_4327.951316141233 has been executed and will be used
# Simulations_ph1_T_204.96856013394574_P_4379.915139312022 has been executed and will be used
# Simulations_ph2_T_204.96856013394574_P_4379.915139312022 has been executed and will be used
# Simulations_ph1_T_204.96856013394574_P_4391.898219650919 has been executed and will be used
# Simulations_ph2_T_204.96856013394574_P_4391.898219650919 has been executed and will be used
# Simulations_ph1_T_203.46856013394574_P_4473.8023191753055 has been executed and will be used
# Simulations_ph2_T_203.46856013394574_P_4473.8023191753055 has been executed and will be used
# Simulations_ph1_T_203.46856013394574_P_4452.432718972474 has been executed and will be used
# Simulations_ph2_T_203.46856013394574_P_4452.432718972474 has been executed and will be used
# Simulations_ph1_T_201.96856013394574_P_4505.306102013348 has been executed and will be used
# Simulations_ph2_T_201.96856013394574_P_4505.306102013348 has been executed and will be used
# Simulations_ph1_T_201.96856013394574_P_4519.659016394315 has been executed and will be used
# Simulations_ph2_T_201.96856013394574_P_4519.659016394315 has been executed and will be used
# Simulations_ph1_T_200.46856013394574_P_4571.991428446981 has been executed and will be used
# Simulations_ph2_T_200.46856013394574_P_4571.991428446981 has been executed and will be used
# Simulations_ph1_T_200.46856013394574_P_4575.987053416051 has been executed and will be used
# Simulations_ph2_T_200.46856013394574_P_4575.987053416051 has been executed and will be used
# Simulations_ph1_T_198.96856013394574_P_4647.366974490636 has been executed and will be used
# Simulations_ph2_T_198.96856013394574_P_4647.366974490636 has been executed and will be used
# Simulations_ph1_T_198.96856013394574_P_4648.762375485115 has been executed and will be used
# Simulations_ph2_T_198.96856013394574_P_4648.762375485115 has been executed and will be used
# Simulations_ph1_T_197.46856013394574_P_4695.42358500491 has been executed and will be used
# Simulations_ph2_T_197.46856013394574_P_4695.42358500491 has been executed and will be used
# Simulations_ph1_T_197.46856013394574_P_4710.4405898417535 has been executed and will be used
# Simulations_ph2_T_197.46856013394574_P_4710.4405898417535 has been executed and will be used
# Simulations_ph1_T_195.96856013394574_P_4767.078956203772 has been executed and will be used
# Simulations_ph2_T_195.96856013394574_P_4767.078956203772 has been executed and will be used
# Simulations_ph1_T_195.96856013394574_P_4771.530414472706 has been executed and will be used
# Simulations_ph2_T_195.96856013394574_P_4771.530414472706 has been executed and will be used
# Simulations_ph1_T_194.46856013394574_P_4821.966769507541 has been executed and will be used
# Simulations_ph2_T_194.46856013394574_P_4821.966769507541 has been executed and will be used
# Simulations_ph1_T_194.46856013394574_P_4826.458465820678 has been executed and will be used
# Simulations_ph2_T_194.46856013394574_P_4826.458465820678 has been executed and will be used
# Simulations_ph1_T_192.96856013394574_P_4877.7641132937315 has been executed and will be used
# Simulations_ph2_T_192.96856013394574_P_4877.7641132937315 has been executed and will be used
# Simulations_ph1_T_192.96856013394574_P_4887.668952279449 has been executed and will be used
# Simulations_ph2_T_192.96856013394574_P_4887.668952279449 has been executed and will be used
# Simulations_ph1_T_191.46856013394574_P_4937.946336964362 has been executed and will be used
# Simulations_ph2_T_191.46856013394574_P_4937.946336964362 has been executed and will be used
# Simulations_ph1_T_191.46856013394574_P_4942.416965307176 has been executed and will be used
# Simulations_ph2_T_191.46856013394574_P_4942.416965307176 has been executed and will be used
# Simulations_ph1_T_189.96856013394574_P_4999.409502444209 has been executed and will be used
# Simulations_ph2_T_189.96856013394574_P_4999.409502444209 has been executed and will be used
# Simulations_ph1_T_189.96856013394574_P_4986.299800498649 has been executed and will be used
# Simulations_ph2_T_189.96856013394574_P_4986.299800498649 has been executed and will be used
# Simulations_ph1_T_188.46856013394574_P_5061.315759918742 has been executed and will be used
# Simulations_ph2_T_188.46856013394574_P_5061.315759918742 has been executed and will be used
# Simulations_ph1_T_188.46856013394574_P_5049.012907828997 has been executed and will be used
# Simulations_ph2_T_188.46856013394574_P_5049.012907828997 has been executed and will be used
# Simulations_ph1_T_186.96856013394574_P_5113.229330160507 has been executed and will be used
# Simulations_ph2_T_186.96856013394574_P_5113.229330160507 has been executed and will be used
# Simulations_ph1_T_186.96856013394574_P_5098.081255171406 has been executed and will be used
# Simulations_ph2_T_186.96856013394574_P_5098.081255171406 has been executed and will be used
# Simulations_ph1_T_185.46856013394574_P_5166.566416883483 has been executed and will be used
# Simulations_ph2_T_185.46856013394574_P_5166.566416883483 has been executed and will be used
# Simulations_ph1_T_185.46856013394574_P_5160.568439449188 has been executed and will be used
# Simulations_ph2_T_185.46856013394574_P_5160.568439449188 has been executed and will be used
# Simulations_ph1_T_183.96856013394574_P_5221.95045998221 has been executed and will be used
# Simulations_ph2_T_183.96856013394574_P_5221.95045998221 has been executed and will be used
# Simulations_ph1_T_183.96856013394574_P_5215.548430558665 has been executed and will be used
# Simulations_ph2_T_183.96856013394574_P_5215.548430558665 has been executed and will be used
# Simulations_ph1_T_182.46856013394574_P_5294.924441460183 has been executed and will be used
# Simulations_ph2_T_182.46856013394574_P_5294.924441460183 has been executed and will be used
# Simulations_ph1_T_182.46856013394574_P_5282.796889946676 has been executed and will be used
# Simulations_ph2_T_182.46856013394574_P_5282.796889946676 has been executed and will be used
# Simulations_ph1_T_180.96856013394574_P_5346.1072104387495 has been executed and will be used
# Simulations_ph2_T_180.96856013394574_P_5346.1072104387495 has been executed and will be used
# Simulations_ph1_T_180.96856013394574_P_5335.870694961289 has been executed and will be used
# Simulations_ph2_T_180.96856013394574_P_5335.870694961289 has been executed and will be used
# Simulations_ph1_T_179.46856013394574_P_5394.582967504951 has been executed and will be used
# Simulations_ph2_T_179.46856013394574_P_5394.582967504951 has been executed and will be used
# Simulations_ph1_T_179.46856013394574_P_5398.35826830729 has been executed and will be used
# Simulations_ph2_T_179.46856013394574_P_5398.35826830729 has been executed and will be used
# Simulations_ph1_T_177.96856013394574_P_5451.759510237356 has been executed and will be used
# Simulations_ph2_T_177.96856013394574_P_5451.759510237356 has been executed and will be used
# Simulations_ph1_T_177.96856013394574_P_5452.665872083943 has been executed and will be used
# Simulations_ph2_T_177.96856013394574_P_5452.665872083943 has been executed and will be used
# Simulations_ph1_T_176.46856013394574_P_5530.6350946579705 has been executed and will be used
# Simulations_ph2_T_176.46856013394574_P_5530.6350946579705 has been executed and will be used
# Simulations_ph1_T_176.46856013394574_P_5515.484533320916 has been executed and will be used
# Simulations_ph2_T_176.46856013394574_P_5515.484533320916 has been executed and will be used
# Simulations_ph1_T_174.96856013394574_P_5595.518716325 has been executed and will be used
# Simulations_ph2_T_174.96856013394574_P_5595.518716325 has been executed and will be used
# Simulations_ph1_T_174.96856013394574_P_5569.4799064825465 has been executed and will be used
# Simulations_ph2_T_174.96856013394574_P_5569.4799064825465 has been executed and will be used
# Simulations_ph1_T_173.46856013394574_P_5638.391299365703 has been executed and will be used
# Simulations_ph2_T_173.46856013394574_P_5638.391299365703 has been executed and will be used
# Simulations_ph1_T_173.46856013394574_P_5632.796625278603 has been executed and will be used
# Simulations_ph2_T_173.46856013394574_P_5632.796625278603 has been executed and will be used
# Simulations_ph1_T_171.96856013394574_P_5712.983080039164 has been executed and will be used
# Simulations_ph2_T_171.96856013394574_P_5712.983080039164 has been executed and will be used
# Simulations_ph1_T_171.96856013394574_P_5706.003870716924 has been executed and will be used
# Simulations_ph2_T_171.96856013394574_P_5706.003870716924 has been executed and will be used
# Simulations_ph1_T_170.46856013394574_P_5736.630314867282 has been executed and will be used
# Simulations_ph2_T_170.46856013394574_P_5736.630314867282 has been executed and will be used
# Simulations_ph1_T_170.46856013394574_P_5761.701786858274 has been executed and will be used
# Simulations_ph2_T_170.46856013394574_P_5761.701786858274 has been executed and will be used
# Simulations_ph1_T_168.96856013394574_P_5816.250631114695 has been executed and will be used
# Simulations_ph2_T_168.96856013394574_P_5816.250631114695 has been executed and will be used
# Simulations_ph1_T_168.96856013394574_P_5830.581735441359 has been executed and will be used
# Simulations_ph2_T_168.96856013394574_P_5830.581735441359 has been executed and will be used
# Simulations_ph1_T_167.46856013394574_P_5901.052361052443 has been executed and will be used
# Simulations_ph2_T_167.46856013394574_P_5901.052361052443 has been executed and will be used
# Simulations_ph1_T_167.46856013394574_P_5889.248054590225 has been executed and will be used
# Simulations_ph2_T_167.46856013394574_P_5889.248054590225 has been executed and will be used
# Simulations_ph1_T_165.96856013394574_P_5946.095537428898 has been executed and will be used
# Simulations_ph2_T_165.96856013394574_P_5946.095537428898 has been executed and will be used
# Simulations_ph1_T_165.96856013394574_P_5958.678880593737 has been executed and will be used
# Simulations_ph2_T_165.96856013394574_P_5958.678880593737 has been executed and will be used
# Simulations_ph1_T_164.46856013394574_P_6037.66436636019 has been executed and will be used
# Simulations_ph2_T_164.46856013394574_P_6037.66436636019 has been executed and will be used
# Simulations_ph1_T_164.46856013394574_P_6021.8556897435 has been executed and will be used
# Simulations_ph2_T_164.46856013394574_P_6021.8556897435 has been executed and will be used
# Simulations_ph1_T_162.96856013394574_P_6083.485301621609 has been executed and will be used
# Simulations_ph2_T_162.96856013394574_P_6083.485301621609 has been executed and will be used
# Simulations_ph1_T_162.96856013394574_P_6087.67817171068 has been executed and will be used
# Simulations_ph2_T_162.96856013394574_P_6087.67817171068 has been executed and will be used
# Simulations_ph1_T_161.46856013394574_P_6148.9763129219855 has been executed and will be used
# Simulations_ph2_T_161.46856013394574_P_6148.9763129219855 has been executed and will be used
# Simulations_ph1_T_161.46856013394574_P_6147.022902018996 has been executed and will be used
# Simulations_ph2_T_161.46856013394574_P_6147.022902018996 has been executed and will be used
# Simulations_ph1_T_159.96856013394574_P_6207.01751189885 has been executed and will be used
# Simulations_ph2_T_159.96856013394574_P_6207.01751189885 has been executed and will be used
# Simulations_ph1_T_159.96856013394574_P_6209.752250958058 has been executed and will be used
# Simulations_ph2_T_159.96856013394574_P_6209.752250958058 has been executed and will be used
# Simulations_ph1_T_158.46856013394574_P_6304.478887238887 has been executed and will be used
# Simulations_ph2_T_158.46856013394574_P_6304.478887238887 has been executed and will be used
# Simulations_ph1_T_158.46856013394574_P_6282.247130056842 has been executed and will be used
# Simulations_ph2_T_158.46856013394574_P_6282.247130056842 has been executed and will be used
# Simulations_ph1_T_156.96856013394574_P_6351.542095650421 has been executed and will be used
# Simulations_ph2_T_156.96856013394574_P_6351.542095650421 has been executed and will be used
# Simulations_ph1_T_156.96856013394574_P_6351.720015815287 has been executed and will be used
# Simulations_ph2_T_156.96856013394574_P_6351.720015815287 has been executed and will be used
# Simulations_ph1_T_155.46856013394574_P_6424.92258518424 has been executed and will be used
# Simulations_ph2_T_155.46856013394574_P_6424.92258518424 has been executed and will be used
# Simulations_ph1_T_155.46856013394574_P_6419.066300645403 has been executed and will be used
# Simulations_ph2_T_155.46856013394574_P_6419.066300645403 has been executed and will be used
# Simulations_ph1_T_153.96856013394574_P_6477.033637916985 has been executed and will be used
# Simulations_ph2_T_153.96856013394574_P_6477.033637916985 has been executed and will be used
# Simulations_ph1_T_153.96856013394574_P_6480.005049126876 has been executed and will be used
# Simulations_ph2_T_153.96856013394574_P_6480.005049126876 has been executed and will be used
# Simulations_ph1_T_152.46856013394574_P_6553.3384148132745 has been executed and will be used
# Simulations_ph2_T_152.46856013394574_P_6553.3384148132745 has been executed and will be used
# Simulations_ph1_T_152.46856013394574_P_6542.408356496821 has been executed and will be used
# Simulations_ph2_T_152.46856013394574_P_6542.408356496821 has been executed and will be used
# Simulations_ph1_T_150.96856013394574_P_6598.397674878377 has been executed and will be used
# Simulations_ph2_T_150.96856013394574_P_6598.397674878377 has been executed and will be used
# Simulations_ph1_T_150.96856013394574_P_6598.968666581949 has been executed and will be used
# Simulations_ph2_T_150.96856013394574_P_6598.968666581949 has been executed and will be used
# Simulations_ph1_T_149.46856013394574_P_6676.762900156544 has been executed and will be used
# Simulations_ph2_T_149.46856013394574_P_6676.762900156544 has been executed and will be used
# Simulations_ph1_T_149.46856013394574_P_6667.608252491038 has been executed and will be used
# Simulations_ph2_T_149.46856013394574_P_6667.608252491038 has been executed and will be used
# Simulations_ph1_T_147.96856013394574_P_6730.2900625042075 has been executed and will be used
# Simulations_ph2_T_147.96856013394574_P_6730.2900625042075 has been executed and will be used
# Simulations_ph1_T_147.96856013394574_P_6731.667024454295 has been executed and will be used
# Simulations_ph2_T_147.96856013394574_P_6731.667024454295 has been executed and will be used
# Simulations_ph1_T_146.46856013394574_P_6788.167059761252 has been executed and will be used
# Simulations_ph2_T_146.46856013394574_P_6788.167059761252 has been executed and will be used
# Simulations_ph1_T_146.46856013394574_P_6793.488365508878 has been executed and will be used
# Simulations_ph2_T_146.46856013394574_P_6793.488365508878 has been executed and will be used
# Simulations_ph1_T_144.96856013394574_P_6859.8278812190465 has been executed and will be used
# Simulations_ph2_T_144.96856013394574_P_6859.8278812190465 has been executed and will be used
# Simulations_ph1_T_144.96856013394574_P_6863.181349506241 has been executed and will be used
# Simulations_ph2_T_144.96856013394574_P_6863.181349506241 has been executed and will be used
# Simulations_ph1_T_143.46856013394574_P_6915.2996231647785 has been executed and will be used
# Simulations_ph2_T_143.46856013394574_P_6915.2996231647785 has been executed and will be used
# Simulations_ph1_T_143.46856013394574_P_6922.568360427791 has been executed and will be used
# Simulations_ph2_T_143.46856013394574_P_6922.568360427791 has been executed and will be used
# Simulations_ph1_T_141.96856013394574_P_6978.852453029447 has been executed and will be used
# Simulations_ph2_T_141.96856013394574_P_6978.852453029447 has been executed and will be used
# Simulations_ph1_T_141.96856013394574_P_6988.839321458004 has been executed and will be used
# Simulations_ph2_T_141.96856013394574_P_6988.839321458004 has been executed and will be used
# Simulations_ph1_T_140.46856013394574_P_7049.152569436096 has been executed and will be used
# Simulations_ph2_T_140.46856013394574_P_7049.152569436096 has been executed and will be used
# Simulations_ph1_T_140.46856013394574_P_7052.545148715146 has been executed and will be used
# Simulations_ph2_T_140.46856013394574_P_7052.545148715146 has been executed and will be used
# Simulations_ph1_T_138.96856013394574_P_7104.9416136879 has been executed and will be used
# Simulations_ph2_T_138.96856013394574_P_7104.9416136879 has been executed and will be used
# Simulations_ph1_T_138.96856013394574_P_7119.868339557536 has been executed and will be used
# Simulations_ph2_T_138.96856013394574_P_7119.868339557536 has been executed and will be used
# Simulations_ph1_T_137.46856013394574_P_7198.524099955531 has been executed and will be used
# Simulations_ph2_T_137.46856013394574_P_7198.524099955531 has been executed and will be used
# Simulations_ph1_T_137.46856013394574_P_7186.064016815919 has been executed and will be used
# Simulations_ph2_T_137.46856013394574_P_7186.064016815919 has been executed and will be used
# Simulations_ph1_T_135.96856013394574_P_7239.9379042650935 has been executed and will be used
# Simulations_ph2_T_135.96856013394574_P_7239.9379042650935 has been executed and will be used
# Simulations_ph1_T_135.96856013394574_P_7257.231279918776 has been executed and will be used
# Simulations_ph2_T_135.96856013394574_P_7257.231279918776 has been executed and will be used
# Simulations_ph1_T_134.46856013394574_P_7327.739276844024 has been executed and will be used
# Simulations_ph2_T_134.46856013394574_P_7327.739276844024 has been executed and will be used
# Simulations_ph1_T_134.46856013394574_P_7319.655407284047 has been executed and will be used
# Simulations_ph2_T_134.46856013394574_P_7319.655407284047 has been executed and will be used
# Simulations_ph1_T_132.96856013394574_P_7390.107229271061 has been executed and will be used
# Simulations_ph2_T_132.96856013394574_P_7390.107229271061 has been executed and will be used
# Simulations_ph1_T_132.96856013394574_P_7388.733447869963 has been executed and will be used
# Simulations_ph2_T_132.96856013394574_P_7388.733447869963 has been executed and will be used
# Simulations_ph1_T_131.46856013394574_P_7487.400219320527 has been executed and will be used
# Simulations_ph2_T_131.46856013394574_P_7487.400219320527 has been executed and will be used
# Simulations_ph1_T_131.46856013394574_P_7468.046875635015 has been executed and will be used
# Simulations_ph2_T_131.46856013394574_P_7468.046875635015 has been executed and will be used
# Simulations_ph1_T_129.96856013394574_P_7543.609068751343 has been executed and will be used
# Simulations_ph2_T_129.96856013394574_P_7543.609068751343 has been executed and will be used
# Simulations_ph1_T_129.96856013394574_P_7525.026629976782 has been executed and will be used
# Simulations_ph2_T_129.96856013394574_P_7525.026629976782 has been executed and will be used
# Simulations_ph1_T_128.46856013394574_P_7594.345151099604 has been executed and will be used
# Simulations_ph2_T_128.46856013394574_P_7594.345151099604 has been executed and will be used
# Simulations_ph1_T_128.46856013394574_P_7594.401307537252 has been executed and will be used
# Simulations_ph2_T_128.46856013394574_P_7594.401307537252 has been executed and will be used
# Simulations_ph1_T_126.96856013394574_P_7655.138816858766 has been executed and will be used
# Simulations_ph2_T_126.96856013394574_P_7655.138816858766 has been executed and will be used
# Simulations_ph1_T_126.96856013394574_P_7653.703127431393 has been executed and will be used
# Simulations_ph2_T_126.96856013394574_P_7653.703127431393 has been executed and will be used
# Simulations_ph1_T_125.46856013394574_P_7760.0019358149975 has been executed and will be used
# Simulations_ph2_T_125.46856013394574_P_7760.0019358149975 has been executed and will be used
# Simulations_ph1_T_125.46856013394574_P_7729.9654025771715 has been done
# Simulations_ph2_T_125.46856013394574_P_7729.9654025771715 has been executed and will be used
# /tmp/ipykernel_1922404/2415844934.py:20: UserWarning: Last run is not finished
#   warnings.warn('Last run is not finished')
# Simulations_ph1_T_123.96856013394574_P_7806.18228821329 has been done
# Simulations_ph2_T_123.96856013394574_P_7806.18228821329 has been done
# Simulations_ph1_T_123.96856013394574_P_7793.986871609532 has been done
# Simulations_ph2_T_123.96856013394574_P_7793.986871609532 has been done
# Simulations_ph1_T_122.46856013394574_P_7863.095260880157 has been done
# Simulations_ph2_T_122.46856013394574_P_7863.095260880157 has been done
# Simulations_ph1_T_122.46856013394574_P_7863.5203073384755 has been done
# Simulations_ph2_T_122.46856013394574_P_7863.5203073384755 has been done
# Simulations_ph1_T_120.96856013394574_P_7927.1626935723625 has been done
# Simulations_ph2_T_120.96856013394574_P_7927.1626935723625 has been done
# Simulations_ph1_T_120.96856013394574_P_7930.430666553647 has been done
# Simulations_ph2_T_120.96856013394574_P_7930.430666553647 has been done
# Simulations_ph1_T_119.46856013394574_P_8002.195504328038 has been done
# Simulations_ph2_T_119.46856013394574_P_8002.195504328038 has been done
# Simulations_ph1_T_119.46856013394574_P_7996.085043434899 has been done
# Simulations_ph2_T_119.46856013394574_P_7996.085043434899 has been done
# Simulations_ph1_T_117.96856013394574_P_8054.690644379701 has been done
# Simulations_ph2_T_117.96856013394574_P_8054.690644379701 has been done
# Simulations_ph1_T_117.96856013394574_P_8053.404341702181 has been done
# Simulations_ph2_T_117.96856013394574_P_8053.404341702181 has been done
# Simulations_ph1_T_116.46856013394574_P_8121.810209487836 has been done
# Simulations_ph2_T_116.46856013394574_P_8121.810209487836 has been done
# Simulations_ph1_T_116.46856013394574_P_8119.801064357456 has been done
# Simulations_ph2_T_116.46856013394574_P_8119.801064357456 has been done
# Simulations_ph1_T_114.96856013394574_P_8179.5727077708925 has been done
# Simulations_ph2_T_114.96856013394574_P_8179.5727077708925 has been done
# Simulations_ph1_T_114.96856013394574_P_8190.291468923027 has been done
# Simulations_ph2_T_114.96856013394574_P_8190.291468923027 has been done
# Simulations_ph1_T_113.46856013394574_P_8247.245016692808 has been done
# Simulations_ph2_T_113.46856013394574_P_8247.245016692808 has been done
# Simulations_ph1_T_113.46856013394574_P_8254.20782020911 has been done
# Simulations_ph2_T_113.46856013394574_P_8254.20782020911 has been done
# Simulations_ph1_T_111.96856013394574_P_8330.615711188244 has been done
# Simulations_ph2_T_111.96856013394574_P_8330.615711188244 has been done
# Simulations_ph1_T_111.96856013394574_P_8316.825365107687 has been done
# Simulations_ph2_T_111.96856013394574_P_8316.825365107687 has been done
# Simulations_ph1_T_110.46856013394574_P_8390.499042229869 has been done
# Simulations_ph2_T_110.46856013394574_P_8390.499042229869 has been done
# Simulations_ph1_T_110.46856013394574_P_8388.12000283857 has been done
# Simulations_ph2_T_110.46856013394574_P_8388.12000283857 has been done
# Simulations_ph1_T_108.96856013394574_P_8455.324025269352 has been done
# Simulations_ph2_T_108.96856013394574_P_8455.324025269352 has been done
# Simulations_ph1_T_108.96856013394574_P_8452.463490201855 has been done
# Simulations_ph2_T_108.96856013394574_P_8452.463490201855 has been done
# Simulations_ph1_T_107.46856013394574_P_8506.918277598272 has been done
# Simulations_ph2_T_107.46856013394574_P_8506.918277598272 has been done
# Simulations_ph1_T_107.46856013394574_P_8514.56338826494 has been done
# Simulations_ph2_T_107.46856013394574_P_8514.56338826494 has been done
# Simulations_ph1_T_105.96856013394574_P_8575.054487693194 has been done
# Simulations_ph2_T_105.96856013394574_P_8575.054487693194 has been done
# Simulations_ph1_T_105.96856013394574_P_8578.866323079184 has been done
# Simulations_ph2_T_105.96856013394574_P_8578.866323079184 has been done
# Simulations_ph1_T_104.46856013394574_P_8655.554570559814 has been done
# Simulations_ph2_T_104.46856013394574_P_8655.554570559814 has been done
# Simulations_ph1_T_104.46856013394574_P_8647.136687038497 has been done
# Simulations_ph2_T_104.46856013394574_P_8647.136687038497 has been done
# Simulations_ph1_T_102.96856013394574_P_8716.726033384617 has been done
# Simulations_ph2_T_102.96856013394574_P_8716.726033384617 has been done
# Simulations_ph1_T_102.96856013394574_P_8720.897492628292 has been done
# Simulations_ph2_T_102.96856013394574_P_8720.897492628292 has been done
# Simulations_ph1_T_101.46856013394574_P_8796.592654365784 has been done
# Simulations_ph2_T_101.46856013394574_P_8796.592654365784 has been done
# Simulations_ph1_T_101.46856013394574_P_8792.061256219342 has been done
# Simulations_ph2_T_101.46856013394574_P_8792.061256219342 has been done
# Simulations_ph1_T_99.96856013394574_P_8860.962361120159 has been done
# Simulations_ph2_T_99.96856013394574_P_8860.962361120159 has been done
# Simulations_ph1_T_99.96856013394574_P_8855.732736752063 has been done
# Simulations_ph2_T_99.96856013394574_P_8855.732736752063 has been done
# Simulations_ph1_T_98.46856013394574_P_8938.038007112313 has been done
# Simulations_ph2_T_98.46856013394574_P_8938.038007112313 has been done
# Simulations_ph1_T_98.46856013394574_P_8929.906574292578 has been done
# Simulations_ph2_T_98.46856013394574_P_8929.906574292578 has been done
# Simulations_ph1_T_96.96856013394574_P_8988.949902781975 has been done
# Simulations_ph2_T_96.96856013394574_P_8988.949902781975 has been done
# Simulations_ph1_T_96.96856013394574_P_8995.175109588603 has been done
# Simulations_ph2_T_96.96856013394574_P_8995.175109588603 has been done
# Simulations_ph1_T_95.46856013394574_P_9057.31628638306 has been done
# Simulations_ph2_T_95.46856013394574_P_9057.31628638306 has been done
# Simulations_ph1_T_95.46856013394574_P_9056.500401081274 has been done
# Simulations_ph2_T_95.46856013394574_P_9056.500401081274 has been done
# Simulations_ph1_T_93.96856013394574_P_9127.650270369937 has been done
# Simulations_ph2_T_93.96856013394574_P_9127.650270369937 has been done
# Simulations_ph1_T_93.96856013394574_P_9138.044087468586 has been done
# Simulations_ph2_T_93.96856013394574_P_9138.044087468586 has been done
# Simulations_ph1_T_92.46856013394574_P_9193.190275788154 has been done
# Simulations_ph2_T_92.46856013394574_P_9193.190275788154 has been done
# Simulations_ph1_T_92.46856013394574_P_9201.038213296322 has been done
# Simulations_ph2_T_92.46856013394574_P_9201.038213296322 has been done
# Simulations_ph1_T_90.96856013394574_P_9274.986386318185 has been done
# Simulations_ph2_T_90.96856013394574_P_9274.986386318185 has been done
# Simulations_ph1_T_90.96856013394574_P_9273.452276449112 has been done
# Simulations_ph2_T_90.96856013394574_P_9273.452276449112 has been done
# Simulations_ph1_T_89.46856013394574_P_9335.991018170349 has been done
# Simulations_ph2_T_89.46856013394574_P_9335.991018170349 has been done
# Simulations_ph1_T_89.46856013394574_P_9339.52416427133 has been done
# Simulations_ph2_T_89.46856013394574_P_9339.52416427133 has been done
# Simulations_ph1_T_87.96856013394574_P_9403.79846127504 has been done
# Simulations_ph2_T_87.96856013394574_P_9403.79846127504 has been done
# Simulations_ph1_T_87.96856013394574_P_9412.73704692496 has been done
# Simulations_ph2_T_87.96856013394574_P_9412.73704692496 has been done
# Simulations_ph1_T_86.46856013394574_P_9471.32948025375 has been done
# Simulations_ph2_T_86.46856013394574_P_9471.32948025375 has been done
# Simulations_ph1_T_86.46856013394574_P_9471.835034154507 has been done
# Simulations_ph2_T_86.46856013394574_P_9471.835034154507 has been done
# Simulations_ph1_T_84.96856013394574_P_9550.490132344641 has been done
# Simulations_ph2_T_84.96856013394574_P_9550.490132344641 has been done
# Simulations_ph1_T_84.96856013394574_P_9541.331085183923 has been done
# Simulations_ph2_T_84.96856013394574_P_9541.331085183923 has been done
# Simulations_ph1_T_83.46856013394574_P_9615.90258779546 has been done
# Simulations_ph2_T_83.46856013394574_P_9615.90258779546 has been done
# Simulations_ph1_T_83.46856013394574_P_9616.575065119847 has been done
# Simulations_ph2_T_83.46856013394574_P_9616.575065119847 has been done
# Simulations_ph1_T_81.96856013394574_P_9680.45214007722 has been done
# Simulations_ph2_T_81.96856013394574_P_9680.45214007722 has been done
# Simulations_ph1_T_81.96856013394574_P_9683.012136245356 has been done
# Simulations_ph2_T_81.96856013394574_P_9683.012136245356 has been done
# Simulations_ph1_T_80.46856013394574_P_9757.740048666286 has been done
# Simulations_ph2_T_80.46856013394574_P_9757.740048666286 has been done

# %%
plt.scatter(T_lst, P_lst)

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/ii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='ii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/ii-v/v_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='v')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/ii_v.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
