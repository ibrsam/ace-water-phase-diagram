# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/\
GibbsDuhemSimulations/IceIII_Liquid/Initial/IceIII/iceIII.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 13:35:21    -4664.396143*       2.4560
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 13:35:22    -4682.395237*       0.9694
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations\
/IceIh_Liquid/Initial/IceIh/water.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 13:35:29    -4179.602444*       0.2890
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('export CUDA_VISIBLE_DEVICES=0;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('export CUDA_VISIBLE_DEVICES=0;\
        nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/iii-ih/iii'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/iii-ih/ih'


T = 268.921; P = 3885; T_step = -3
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**5
barostat_ph1 = 'aniso'; barostat_ph2 = 'aniso'

skip = 100
n_pnts = 20

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_268.921_P_3885 has been done
# Simulations_ph2_T_268.921_P_3885 has been done
# Simulations_ph1_T_267.421_P_3903.341517303874 has been done
# Simulations_ph2_T_267.421_P_3903.341517303874 has been done
# Simulations_ph1_T_267.421_P_3898.5810057584304 has been done
# Simulations_ph2_T_267.421_P_3898.5810057584304 has been done
# Simulations_ph1_T_265.921_P_3922.0092092627433 has been done
# Simulations_ph2_T_265.921_P_3922.0092092627433 has been done
# Simulations_ph1_T_265.921_P_3917.6022899261434 has been done
# Simulations_ph2_T_265.921_P_3917.6022899261434 has been done
# Simulations_ph1_T_264.421_P_3934.140153309401 has been done
# Simulations_ph2_T_264.421_P_3934.140153309401 has been done
# Simulations_ph1_T_264.421_P_3934.4951133759323 has been done
# Simulations_ph2_T_264.421_P_3934.4951133759323 has been done
# Simulations_ph1_T_262.921_P_3955.2546961808994 has been done
# Simulations_ph2_T_262.921_P_3955.2546961808994 has been done
# Simulations_ph1_T_262.921_P_3952.778761556263 has been done
# Simulations_ph2_T_262.921_P_3952.778761556263 has been done
# Simulations_ph1_T_261.421_P_3970.507306927854 has been done
# Simulations_ph2_T_261.421_P_3970.507306927854 has been done
# Simulations_ph1_T_261.421_P_3968.390013949486 has been done
# Simulations_ph2_T_261.421_P_3968.390013949486 has been done
# Simulations_ph1_T_259.921_P_3990.0044461029006 has been done
# Simulations_ph2_T_259.921_P_3990.0044461029006 has been done
# Simulations_ph1_T_259.921_P_3986.603288572668 has been done
# Simulations_ph2_T_259.921_P_3986.603288572668 has been done
# Simulations_ph1_T_258.421_P_4006.161113530543 has been done
# Simulations_ph2_T_258.421_P_4006.161113530543 has been done
# Simulations_ph1_T_258.421_P_4002.743448012305 has been done
# Simulations_ph2_T_258.421_P_4002.743448012305 has been done
# Simulations_ph1_T_256.921_P_4016.432207247658 has been done
# Simulations_ph2_T_256.921_P_4016.432207247658 has been done
# Simulations_ph1_T_256.921_P_4019.0568396223825 has been done
# Simulations_ph2_T_256.921_P_4019.0568396223825 has been done
# Simulations_ph1_T_255.421_P_4032.2296552535595 has been done
# Simulations_ph2_T_255.421_P_4032.2296552535595 has been done
# Simulations_ph1_T_255.421_P_4033.6006014520804 has been done
# Simulations_ph2_T_255.421_P_4033.6006014520804 has been done
# Simulations_ph1_T_253.921_P_4049.634805817028 has been done
# Simulations_ph2_T_253.921_P_4049.634805817028 has been done
# Simulations_ph1_T_253.921_P_4048.780076758165 has been done
# Simulations_ph2_T_253.921_P_4048.780076758165 has been done
# Simulations_ph1_T_252.421_P_4064.432584209952 has been done
# Simulations_ph2_T_252.421_P_4064.432584209952 has been done
# Simulations_ph1_T_252.421_P_4064.8746185114082 has been done
# Simulations_ph2_T_252.421_P_4064.8746185114082 has been done
# Simulations_ph1_T_250.921_P_4082.0215244245655 has been done
# Simulations_ph2_T_250.921_P_4082.0215244245655 has been done
# Simulations_ph1_T_250.921_P_4081.7362443672305 has been done
# Simulations_ph2_T_250.921_P_4081.7362443672305 has been done
# Simulations_ph1_T_249.421_P_4097.228513183088 has been done
# Simulations_ph2_T_249.421_P_4097.228513183088 has been done
# Simulations_ph1_T_249.421_P_4096.840096129069 has been done
# Simulations_ph2_T_249.421_P_4096.840096129069 has been done
# Simulations_ph1_T_247.921_P_4109.7443998684175 has been done
# Simulations_ph2_T_247.921_P_4109.7443998684175 has been done
# Simulations_ph1_T_247.921_P_4112.155555631076 has been done
# Simulations_ph2_T_247.921_P_4112.155555631076 has been done
# Simulations_ph1_T_246.421_P_4127.914080164471 has been done
# Simulations_ph2_T_246.421_P_4127.914080164471 has been done
# Simulations_ph1_T_246.421_P_4128.9849232170745 has been done
# Simulations_ph2_T_246.421_P_4128.9849232170745 has been done
# Simulations_ph1_T_244.921_P_4142.3240814305 has been done
# Simulations_ph2_T_244.921_P_4142.3240814305 has been done
# Simulations_ph1_T_244.921_P_4143.580086805128 has been done
# Simulations_ph2_T_244.921_P_4143.580086805128 has been done
# Simulations_ph1_T_243.421_P_4156.787682089002 has been done
# Simulations_ph2_T_243.421_P_4156.787682089002 has been done
# Simulations_ph1_T_243.421_P_4161.711291335953 has been done
# Simulations_ph2_T_243.421_P_4161.711291335953 has been done
# Simulations_ph1_T_241.921_P_4177.681924470032 has been done
# Simulations_ph2_T_241.921_P_4177.681924470032 has been done
# Simulations_ph1_T_241.921_P_4176.414268470653 has been done
# Simulations_ph2_T_241.921_P_4176.414268470653 has been done
# Simulations_ph1_T_240.421_P_4189.62846180096 has been done
# Simulations_ph2_T_240.421_P_4189.62846180096 has been done
# Simulations_ph1_T_240.421_P_4191.610502768247 has been done
# Simulations_ph2_T_240.421_P_4191.610502768247 has been done
# Simulations_ph1_T_238.921_P_4208.316906754609 has been done
# Simulations_ph2_T_238.921_P_4208.316906754609 has been done
# Simulations_ph1_T_238.921_P_4207.040853835766 has been done
# Simulations_ph2_T_238.921_P_4207.040853835766 has been done
# Simulations_ph1_T_237.421_P_4224.372375563333 has been done
# Simulations_ph2_T_237.421_P_4224.372375563333 has been done
# Simulations_ph1_T_237.421_P_4222.639771145146 has been done
# Simulations_ph2_T_237.421_P_4222.639771145146 has been done
# Simulations_ph1_T_235.921_P_4237.604056007137 has been done
# Simulations_ph2_T_235.921_P_4237.604056007137 has been done
# Simulations_ph1_T_235.921_P_4238.05314679135 has been done
# Simulations_ph2_T_235.921_P_4238.05314679135 has been done
# Simulations_ph1_T_234.421_P_4255.5676212529215 has been done
# Simulations_ph2_T_234.421_P_4255.5676212529215 has been done
# Simulations_ph1_T_234.421_P_4253.594940106221 has been done
# Simulations_ph2_T_234.421_P_4253.594940106221 has been done
# Simulations_ph1_T_232.921_P_4270.215951884629 has been done
# Simulations_ph2_T_232.921_P_4270.215951884629 has been done
# Simulations_ph1_T_232.921_P_4269.994014496552 has been done
# Simulations_ph2_T_232.921_P_4269.994014496552 has been done
# Simulations_ph1_T_231.421_P_4285.5593044097195 has been done
# Simulations_ph2_T_231.421_P_4285.5593044097195 has been done
# Simulations_ph1_T_231.421_P_4286.763254783167 has been done
# Simulations_ph2_T_231.421_P_4286.763254783167 has been done
# Simulations_ph1_T_229.921_P_4298.861907800599 has been done
# Simulations_ph2_T_229.921_P_4298.861907800599 has been done
# Simulations_ph1_T_229.921_P_4300.927560666695 has been done
# Simulations_ph2_T_229.921_P_4300.927560666695 has been done
# Simulations_ph1_T_228.421_P_4314.991335671772 has been done
# Simulations_ph2_T_228.421_P_4314.991335671772 has been done
# Simulations_ph1_T_228.421_P_4313.749106791202 has been done
# Simulations_ph2_T_228.421_P_4313.749106791202 has been done
# Simulations_ph1_T_226.921_P_4328.364376426019 has been done
# Simulations_ph2_T_226.921_P_4328.364376426019 has been done
# Simulations_ph1_T_226.921_P_4328.689811199886 has been done
# Simulations_ph2_T_226.921_P_4328.689811199886 has been done
# Simulations_ph1_T_225.421_P_4341.294100263841 has been done
# Simulations_ph2_T_225.421_P_4341.294100263841 has been done
# Simulations_ph1_T_225.421_P_4344.828208662789 has been done
# Simulations_ph2_T_225.421_P_4344.828208662789 has been done
# Simulations_ph1_T_223.921_P_4358.998388412296 has been done
# Simulations_ph2_T_223.921_P_4358.998388412296 has been done
# Simulations_ph1_T_223.921_P_4358.57095767184 has been done
# Simulations_ph2_T_223.921_P_4358.57095767184 has been done
# Simulations_ph1_T_222.421_P_4374.85521234827 has been done
# Simulations_ph2_T_222.421_P_4374.85521234827 has been done
# Simulations_ph1_T_222.421_P_4375.287611956918 has been done
# Simulations_ph2_T_222.421_P_4375.287611956918 has been done
# Simulations_ph1_T_220.921_P_4391.819472491265 has been done
# Simulations_ph2_T_220.921_P_4391.819472491265 has been done
# Simulations_ph1_T_220.921_P_4391.047820872815 has been done
# Simulations_ph2_T_220.921_P_4391.047820872815 has been done
# Simulations_ph1_T_219.421_P_4407.414097665626 has been done
# Simulations_ph2_T_219.421_P_4407.414097665626 has been done
# Simulations_ph1_T_219.421_P_4403.013252345345 has been done
# Simulations_ph2_T_219.421_P_4403.013252345345 has been done
# Simulations_ph1_T_217.921_P_4423.41302903616 has been done
# Simulations_ph2_T_217.921_P_4423.41302903616 has been done
# Simulations_ph1_T_217.921_P_4420.101771244954 has been done
# Simulations_ph2_T_217.921_P_4420.101771244954 has been done
# Simulations_ph1_T_216.421_P_4433.972683502187 has been done
# Simulations_ph2_T_216.421_P_4433.972683502187 has been done
# Simulations_ph1_T_216.421_P_4432.835351708708 has been done
# Simulations_ph2_T_216.421_P_4432.835351708708 has been done
# Simulations_ph1_T_214.921_P_4446.002814755857 has been done
# Simulations_ph2_T_214.921_P_4446.002814755857 has been done
# Simulations_ph1_T_214.921_P_4446.349796076036 has been done
# Simulations_ph2_T_214.921_P_4446.349796076036 has been done
# Simulations_ph1_T_213.421_P_4461.300242336032 has been done
# Simulations_ph2_T_213.421_P_4461.300242336032 has been done
# Simulations_ph1_T_213.421_P_4460.801624882342 has been done
# Simulations_ph2_T_213.421_P_4460.801624882342 has been done
# Simulations_ph1_T_211.921_P_4478.074235577995 has been done
# Simulations_ph2_T_211.921_P_4478.074235577995 has been done
# Simulations_ph1_T_211.921_P_4476.292114778504 has been done
# Simulations_ph2_T_211.921_P_4476.292114778504 has been done
# Simulations_ph1_T_210.421_P_4488.077919679377 has been done
# Simulations_ph2_T_210.421_P_4488.077919679377 has been done
# Simulations_ph1_T_210.421_P_4489.025730054653 has been done
# Simulations_ph2_T_210.421_P_4489.025730054653 has been done
# Simulations_ph1_T_208.921_P_4507.116083827842 has been done
# Simulations_ph2_T_208.921_P_4507.116083827842 has been done

# %%
plt.plot(T_lst, P_lst)

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/iii-ih/iii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='iii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/iii-ih/ih_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='ih')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/iii_ih.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
