# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/\
GibbsDuhemSimulations/IceVI_IceV/Initial/IceV/iceV.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 14:45:09    -4834.065126*       2.3135
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 14:45:11    -4851.531667*       1.0293
# BFGSLineSearch:    2[  3] 14:45:12    -4860.725898*       2.6266
# BFGSLineSearch:    3[  5] 14:45:14    -4864.430067*       0.7583
# True

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/\
GibbsDuhemSimulations/IceVI_IceV/Initial/IceVI/iceVI.data'
ph_2 = io.read(f'{path}',
                format='lammps-data')
ph_2.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_2.get_chemical_symbols())))
np.unique(ph_2.get_chemical_symbols())
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 14:45:58    -9202.841374*       2.2703
# /home/users/saadie5f/miniconda3/envs/ace/lib/python3.8/site-packages/ase/utils/__init__.py:62: FutureWarning: Please use atoms.cell.rank instead
#   warnings.warn(warning)
# BFGSLineSearch:    1[  2] 14:46:01    -9235.610513*       1.0207
# BFGSLineSearch:    2[  3] 14:46:04    -9256.268794*       2.4291
# BFGSLineSearch:    3[  5] 14:46:09    -9263.766116*       0.7261
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq, n_steps_pr, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq, n_steps_pr)
        os.system('export CUDA_VISIBLE_DEVICES=1; nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq, n_steps_pr)
        os.system('export CUDA_VISIBLE_DEVICES=1; nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
path = '../cc_int/ice_ih-liq/ice_ih'
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/v-vi/v'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/v-vi/vi'


T = 288.323; P = 5888; T_step = -3
n_steps_eq = 2*10**4; n_steps_pr = 2*10**5
barostat_ph1 = 'tri'; barostat_ph2 = 'aniso'

skip = 100
n_pnts = 60

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq, n_steps_pr, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                     barostat_ph1, barostat_ph2, n_steps_eq, n_steps_pr, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_288.323_P_5888 has been executed and will be used
# Simulations_ph2_T_288.323_P_5888 has been executed and will be used
# Simulations_ph1_T_286.823_P_5905.764579008121 has been executed and will be used
# Simulations_ph2_T_286.823_P_5905.764579008121 has been executed and will be used
# Simulations_ph1_T_286.823_P_5909.667484786693 has been executed and will be used
# Simulations_ph2_T_286.823_P_5909.667484786693 has been executed and will be used
# Simulations_ph1_T_285.323_P_5909.49678893585 has been executed and will be used
# Simulations_ph2_T_285.323_P_5909.49678893585 has been executed and will be used
# Simulations_ph1_T_285.323_P_5924.208401540663 has been executed and will be used
# Simulations_ph2_T_285.323_P_5924.208401540663 has been executed and will be used
# Simulations_ph1_T_283.823_P_5934.512606443187 has been executed and will be used
# Simulations_ph2_T_283.823_P_5934.512606443187 has been executed and will be used
# Simulations_ph1_T_283.823_P_5929.427127673244 has been executed and will be used
# Simulations_ph2_T_283.823_P_5929.427127673244 has been executed and will be used
# Simulations_ph1_T_282.323_P_5976.198392717247 has been executed and will be used
# Simulations_ph2_T_282.323_P_5976.198392717247 has been executed and will be used
# Simulations_ph1_T_282.323_P_5950.2520863181835 has been executed and will be used
# Simulations_ph2_T_282.323_P_5950.2520863181835 has been executed and will be used
# Simulations_ph1_T_280.823_P_5982.40002401599 has been executed and will be used
# Simulations_ph2_T_280.823_P_5982.40002401599 has been executed and will be used
# Simulations_ph1_T_280.823_P_5978.009558159215 has been executed and will be used
# Simulations_ph2_T_280.823_P_5978.009558159215 has been executed and will be used
# Simulations_ph1_T_279.323_P_6000.506090726896 has been executed and will be used
# Simulations_ph2_T_279.323_P_6000.506090726896 has been executed and will be used
# Simulations_ph1_T_279.323_P_6005.150126150711 has been executed and will be used
# Simulations_ph2_T_279.323_P_6005.150126150711 has been executed and will be used
# Simulations_ph1_T_277.823_P_6020.875410952536 has been executed and will be used
# Simulations_ph2_T_277.823_P_6020.875410952536 has been executed and will be used
# Simulations_ph1_T_277.823_P_6028.846945405997 has been executed and will be used
# Simulations_ph2_T_277.823_P_6028.846945405997 has been executed and will be used
# Simulations_ph1_T_276.323_P_6069.877020216848 has been executed and will be used
# Simulations_ph2_T_276.323_P_6069.877020216848 has been executed and will be used
# Simulations_ph1_T_276.323_P_6053.424868284001 has been executed and will be used
# Simulations_ph2_T_276.323_P_6053.424868284001 has been executed and will be used
# Simulations_ph1_T_274.823_P_6079.63824857018 has been executed and will be used
# Simulations_ph2_T_274.823_P_6079.63824857018 has been executed and will be used
# Simulations_ph1_T_274.823_P_6070.320124119901 has been executed and will be used
# Simulations_ph2_T_274.823_P_6070.320124119901 has been executed and will be used
# Simulations_ph1_T_273.323_P_6073.887167319349 has been executed and will be used
# Simulations_ph2_T_273.323_P_6073.887167319349 has been executed and will be used
# Simulations_ph1_T_273.323_P_6085.270903566461 has been executed and will be used
# Simulations_ph2_T_273.323_P_6085.270903566461 has been executed and will be used
# Simulations_ph1_T_271.823_P_6105.937717435643 has been executed and will be used
# Simulations_ph2_T_271.823_P_6105.937717435643 has been executed and will be used
# Simulations_ph1_T_271.823_P_6101.558516618898 has been executed and will be used
# Simulations_ph2_T_271.823_P_6101.558516618898 has been executed and will be used
# Simulations_ph1_T_270.323_P_6135.480661894463 has been executed and will be used
# Simulations_ph2_T_270.323_P_6135.480661894463 has been executed and will be used
# Simulations_ph1_T_270.323_P_6124.230321119832 has been executed and will be used
# Simulations_ph2_T_270.323_P_6124.230321119832 has been executed and will be used
# Simulations_ph1_T_268.823_P_6165.802212767285 has been executed and will be used
# Simulations_ph2_T_268.823_P_6165.802212767285 has been executed and will be used
# Simulations_ph1_T_268.823_P_6137.747915600027 has been executed and will be used
# Simulations_ph2_T_268.823_P_6137.747915600027 has been executed and will be used
# Simulations_ph1_T_267.323_P_6175.666471871785 has been executed and will be used
# Simulations_ph2_T_267.323_P_6175.666471871785 has been executed and will be used
# Simulations_ph1_T_267.323_P_6172.197806871877 has been executed and will be used
# Simulations_ph2_T_267.323_P_6172.197806871877 has been executed and will be used
# Simulations_ph1_T_265.823_P_6184.983010570792 has been executed and will be used
# Simulations_ph2_T_265.823_P_6184.983010570792 has been executed and will be used
# Simulations_ph1_T_265.823_P_6179.047903096019 has been executed and will be used
# Simulations_ph2_T_265.823_P_6179.047903096019 has been executed and will be used
# Simulations_ph1_T_264.323_P_6223.91773642336 has been executed and will be used
# Simulations_ph2_T_264.323_P_6223.91773642336 has been executed and will be used
# Simulations_ph1_T_264.323_P_6203.7735135170415 has been executed and will be used
# Simulations_ph2_T_264.323_P_6203.7735135170415 has been executed and will be used
# Simulations_ph1_T_262.823_P_6218.898839997944 has been executed and will be used
# Simulations_ph2_T_262.823_P_6218.898839997944 has been executed and will be used
# Simulations_ph1_T_262.823_P_6218.934404835436 has been executed and will be used
# Simulations_ph2_T_262.823_P_6218.934404835436 has been executed and will be used
# Simulations_ph1_T_261.323_P_6270.0413976126765 has been executed and will be used
# Simulations_ph2_T_261.323_P_6270.0413976126765 has been executed and will be used
# Simulations_ph1_T_261.323_P_6241.597695864097 has been executed and will be used
# Simulations_ph2_T_261.323_P_6241.597695864097 has been executed and will be used
# Simulations_ph1_T_259.823_P_6260.682512768855 has been executed and will be used
# Simulations_ph2_T_259.823_P_6260.682512768855 has been executed and will be used
# Simulations_ph1_T_259.823_P_6261.410065216056 has been executed and will be used
# Simulations_ph2_T_259.823_P_6261.410065216056 has been executed and will be used
# Simulations_ph1_T_258.323_P_6291.1783097118705 has been executed and will be used
# Simulations_ph2_T_258.323_P_6291.1783097118705 has been executed and will be used
# Simulations_ph1_T_258.323_P_6280.762807877834 has been executed and will be used
# Simulations_ph2_T_258.323_P_6280.762807877834 has been executed and will be used
# Simulations_ph1_T_256.823_P_6287.261686160357 has been executed and will be used
# Simulations_ph2_T_256.823_P_6287.261686160357 has been executed and will be used
# Simulations_ph1_T_256.823_P_6303.370595241465 has been executed and will be used
# Simulations_ph2_T_256.823_P_6303.370595241465 has been executed and will be used
# Simulations_ph1_T_255.32299999999998_P_6333.838645147124 has been executed and will be used
# Simulations_ph2_T_255.32299999999998_P_6333.838645147124 has been executed and will be used
# Simulations_ph1_T_255.32299999999998_P_6322.648853582601 has been executed and will be used
# Simulations_ph2_T_255.32299999999998_P_6322.648853582601 has been executed and will be used
# Simulations_ph1_T_253.82299999999998_P_6342.768194381688 has been executed and will be used
# Simulations_ph2_T_253.82299999999998_P_6342.768194381688 has been executed and will be used
# Simulations_ph1_T_253.82299999999998_P_6339.491338369161 has been executed and will be used
# Simulations_ph2_T_253.82299999999998_P_6339.491338369161 has been executed and will be used
# Simulations_ph1_T_252.32299999999998_P_6380.0477664339915 has been executed and will be used
# Simulations_ph2_T_252.32299999999998_P_6380.0477664339915 has been executed and will be used
# Simulations_ph1_T_252.32299999999998_P_6369.820973976523 has been executed and will be used
# Simulations_ph2_T_252.32299999999998_P_6369.820973976523 has been executed and will be used
# Simulations_ph1_T_250.82299999999998_P_6398.73530069412 has been executed and will be used
# Simulations_ph2_T_250.82299999999998_P_6398.73530069412 has been executed and will be used
# Simulations_ph1_T_250.82299999999998_P_6389.3650900623625 has been executed and will be used
# Simulations_ph2_T_250.82299999999998_P_6389.3650900623625 has been executed and will be used
# Simulations_ph1_T_249.32299999999998_P_6429.879794513283 has been executed and will be used
# Simulations_ph2_T_249.32299999999998_P_6429.879794513283 has been executed and will be used
# Simulations_ph1_T_249.32299999999998_P_6417.236552519374 has been executed and will be used
# Simulations_ph2_T_249.32299999999998_P_6417.236552519374 has been executed and will be used
# Simulations_ph1_T_247.82299999999998_P_6447.161397324248 has been executed and will be used
# Simulations_ph2_T_247.82299999999998_P_6447.161397324248 has been executed and will be used
# Simulations_ph1_T_247.82299999999998_P_6442.304348970527 has been executed and will be used
# Simulations_ph2_T_247.82299999999998_P_6442.304348970527 has been executed and will be used
# Simulations_ph1_T_246.32299999999998_P_6451.859316753079 has been executed and will be used
# Simulations_ph2_T_246.32299999999998_P_6451.859316753079 has been executed and will be used
# Simulations_ph1_T_246.32299999999998_P_6463.166697072782 has been executed and will be used
# Simulations_ph2_T_246.32299999999998_P_6463.166697072782 has been executed and will be used
# Simulations_ph1_T_244.82299999999998_P_6490.730715389549 has been executed and will be used
# Simulations_ph2_T_244.82299999999998_P_6490.730715389549 has been executed and will be used
# Simulations_ph1_T_244.82299999999998_P_6492.164058430691 has been executed and will be used
# Simulations_ph2_T_244.82299999999998_P_6492.164058430691 has been executed and will be used
# Simulations_ph1_T_243.32299999999998_P_6482.939737112678 has been executed and will be used
# Simulations_ph2_T_243.32299999999998_P_6482.939737112678 has been executed and will be used
# Simulations_ph1_T_243.32299999999998_P_6498.52399879346 has been executed and will be used
# Simulations_ph2_T_243.32299999999998_P_6498.52399879346 has been executed and will be used
# Simulations_ph1_T_241.82299999999998_P_6517.336896826934 has been executed and will be used
# Simulations_ph2_T_241.82299999999998_P_6517.336896826934 has been executed and will be used
# Simulations_ph1_T_241.82299999999998_P_6517.999228217078 has been executed and will be used
# Simulations_ph2_T_241.82299999999998_P_6517.999228217078 has been executed and will be used
# Simulations_ph1_T_240.32299999999998_P_6564.963185015902 has been executed and will be used
# Simulations_ph2_T_240.32299999999998_P_6564.963185015902 has been executed and will be used
# Simulations_ph1_T_240.32299999999998_P_6549.520016021454 has been executed and will be used
# Simulations_ph2_T_240.32299999999998_P_6549.520016021454 has been executed and will be used
# Simulations_ph1_T_238.82299999999998_P_6574.925518964491 has been executed and will be used
# Simulations_ph2_T_238.82299999999998_P_6574.925518964491 has been executed and will be used
# Simulations_ph1_T_238.82299999999998_P_6568.479194178124 has been executed and will be used
# Simulations_ph2_T_238.82299999999998_P_6568.479194178124 has been executed and will be used
# Simulations_ph1_T_237.32299999999998_P_6593.3002743074885 has been executed and will be used
# Simulations_ph2_T_237.32299999999998_P_6593.3002743074885 has been executed and will be used
# Simulations_ph1_T_237.32299999999998_P_6588.532640827427 has been executed and will be used
# Simulations_ph2_T_237.32299999999998_P_6588.532640827427 has been executed and will be used
# Simulations_ph1_T_235.82299999999998_P_6617.51487776385 has been executed and will be used
# Simulations_ph2_T_235.82299999999998_P_6617.51487776385 has been executed and will be used
# Simulations_ph1_T_235.82299999999998_P_6615.325571503877 has been executed and will be used
# Simulations_ph2_T_235.82299999999998_P_6615.325571503877 has been executed and will be used
# Simulations_ph1_T_234.32299999999998_P_6630.506026512138 has been executed and will be used
# Simulations_ph2_T_234.32299999999998_P_6630.506026512138 has been executed and will be used
# Simulations_ph1_T_234.32299999999998_P_6636.776173423268 has been executed and will be used
# Simulations_ph2_T_234.32299999999998_P_6636.776173423268 has been executed and will be used
# Simulations_ph1_T_232.82299999999998_P_6653.178766522434 has been executed and will be used
# Simulations_ph2_T_232.82299999999998_P_6653.178766522434 has been executed and will be used
# Simulations_ph1_T_232.82299999999998_P_6658.721330736623 has been executed and will be used
# Simulations_ph2_T_232.82299999999998_P_6658.721330736623 has been executed and will be used
# Simulations_ph1_T_231.32299999999998_P_6661.2884731980075 has been executed and will be used
# Simulations_ph2_T_231.32299999999998_P_6661.2884731980075 has been executed and will be used
# Simulations_ph1_T_231.32299999999998_P_6667.708298649992 has been executed and will be used
# Simulations_ph2_T_231.32299999999998_P_6667.708298649992 has been executed and will be used
# Simulations_ph1_T_229.82299999999998_P_6690.978917721691 has been executed and will be used
# Simulations_ph2_T_229.82299999999998_P_6690.978917721691 has been executed and will be used
# Simulations_ph1_T_229.82299999999998_P_6697.199678380274 has been executed and will be used
# Simulations_ph2_T_229.82299999999998_P_6697.199678380274 has been executed and will be used
# Simulations_ph1_T_228.32299999999998_P_6703.087447574667 has been executed and will be used
# Simulations_ph2_T_228.32299999999998_P_6703.087447574667 has been executed and will be used
# Simulations_ph1_T_228.32299999999998_P_6712.479913165591 has been executed and will be used
# Simulations_ph2_T_228.32299999999998_P_6712.479913165591 has been executed and will be used
# Simulations_ph1_T_226.82299999999998_P_6740.753281691356 has been executed and will be used
# Simulations_ph2_T_226.82299999999998_P_6740.753281691356 has been executed and will be used
# Simulations_ph1_T_226.82299999999998_P_6735.671511040717 has been executed and will be used
# Simulations_ph2_T_226.82299999999998_P_6735.671511040717 has been executed and will be used
# Simulations_ph1_T_225.32299999999998_P_6745.395322668701 has been executed and will be used
# Simulations_ph2_T_225.32299999999998_P_6745.395322668701 has been executed and will be used
# Simulations_ph1_T_225.32299999999998_P_6755.1703571525395 has been executed and will be used
# Simulations_ph2_T_225.32299999999998_P_6755.1703571525395 has been executed and will be used
# Simulations_ph1_T_223.82299999999998_P_6769.9590024712925 has been executed and will be used
# Simulations_ph2_T_223.82299999999998_P_6769.9590024712925 has been executed and will be used
# Simulations_ph1_T_223.82299999999998_P_6770.269049613287 has been executed and will be used
# Simulations_ph2_T_223.82299999999998_P_6770.269049613287 has been executed and will be used
# Simulations_ph1_T_222.32299999999998_P_6743.622241886776 has been executed and will be used
# Simulations_ph2_T_222.32299999999998_P_6743.622241886776 has been executed and will be used
# Simulations_ph1_T_222.32299999999998_P_6772.412229712886 has been executed and will be used
# Simulations_ph2_T_222.32299999999998_P_6772.412229712886 has been executed and will be used
# Simulations_ph1_T_220.82299999999998_P_6788.268276113409 has been executed and will be used
# Simulations_ph2_T_220.82299999999998_P_6788.268276113409 has been executed and will be used
# Simulations_ph1_T_220.82299999999998_P_6794.173000576833 has been executed and will be used
# Simulations_ph2_T_220.82299999999998_P_6794.173000576833 has been executed and will be used
# Simulations_ph1_T_219.32299999999998_P_6818.401596836291 has been executed and will be used
# Simulations_ph2_T_219.32299999999998_P_6818.401596836291 has been executed and will be used
# Simulations_ph1_T_219.32299999999998_P_6808.893870498032 has been executed and will be used
# Simulations_ph2_T_219.32299999999998_P_6808.893870498032 has been executed and will be used
# Simulations_ph1_T_217.82299999999998_P_6825.8528434730015 has been executed and will be used
# Simulations_ph2_T_217.82299999999998_P_6825.8528434730015 has been executed and will be used
# Simulations_ph1_T_217.82299999999998_P_6819.406557893216 has been executed and will be used
# Simulations_ph2_T_217.82299999999998_P_6819.406557893216 has been executed and will be used
# Simulations_ph1_T_216.32299999999998_P_6835.4106195634085 has been executed and will be used
# Simulations_ph2_T_216.32299999999998_P_6835.4106195634085 has been executed and will be used
# Simulations_ph1_T_216.32299999999998_P_6835.749783002505 has been executed and will be used
# Simulations_ph2_T_216.32299999999998_P_6835.749783002505 has been executed and will be used
# Simulations_ph1_T_214.82299999999998_P_6861.1849749105395 has been executed and will be used
# Simulations_ph2_T_214.82299999999998_P_6861.1849749105395 has been executed and will be used
# Simulations_ph1_T_214.82299999999998_P_6853.212430969773 has been executed and will be used
# Simulations_ph2_T_214.82299999999998_P_6853.212430969773 has been executed and will be used
# Simulations_ph1_T_213.32299999999998_P_6880.416316143488 has been executed and will be used
# Simulations_ph2_T_213.32299999999998_P_6880.416316143488 has been executed and will be used
# Simulations_ph1_T_213.32299999999998_P_6877.998427921817 has been executed and will be used
# Simulations_ph2_T_213.32299999999998_P_6877.998427921817 has been executed and will be used
# Simulations_ph1_T_211.82299999999998_P_6897.320386267948 has been executed and will be used
# Simulations_ph2_T_211.82299999999998_P_6897.320386267948 has been executed and will be used
# Simulations_ph1_T_211.82299999999998_P_6897.191829841748 has been executed and will be used
# Simulations_ph2_T_211.82299999999998_P_6897.191829841748 has been executed and will be used
# Simulations_ph1_T_210.32299999999998_P_6887.223713594696 has been executed and will be used
# Simulations_ph2_T_210.32299999999998_P_6887.223713594696 has been executed and will be used
# Simulations_ph1_T_210.32299999999998_P_6899.6184363263 has been executed and will be used
# Simulations_ph2_T_210.32299999999998_P_6899.6184363263 has been executed and will be used
# Simulations_ph1_T_208.82299999999998_P_6912.860616897774 has been executed and will be used
# Simulations_ph2_T_208.82299999999998_P_6912.860616897774 has been executed and will be used
# Simulations_ph1_T_208.82299999999998_P_6930.333077985581 has been executed and will be used
# Simulations_ph2_T_208.82299999999998_P_6930.333077985581 has been executed and will be used
# Simulations_ph1_T_207.32299999999998_P_6936.48637650844 has been executed and will be used
# Simulations_ph2_T_207.32299999999998_P_6936.48637650844 has been executed and will be used
# Simulations_ph1_T_207.32299999999998_P_6942.044610453149 has been executed and will be used
# Simulations_ph2_T_207.32299999999998_P_6942.044610453149 has been executed and will be used
# Simulations_ph1_T_205.82299999999998_P_6955.392200463553 has been executed and will be used
# Simulations_ph2_T_205.82299999999998_P_6955.392200463553 has been executed and will be used
# Simulations_ph1_T_205.82299999999998_P_6962.6276994132 has been executed and will be used
# Simulations_ph2_T_205.82299999999998_P_6962.6276994132 has been executed and will be used
# Simulations_ph1_T_204.32299999999998_P_6951.239347553694 has been executed and will be used
# Simulations_ph2_T_204.32299999999998_P_6951.239347553694 has been executed and will be used
# Simulations_ph1_T_204.32299999999998_P_6969.789873798189 has been executed and will be used
# Simulations_ph2_T_204.32299999999998_P_6969.789873798189 has been executed and will be used
# Simulations_ph1_T_202.82299999999998_P_6986.140131146632 has been executed and will be used
# Simulations_ph2_T_202.82299999999998_P_6986.140131146632 has been executed and will be used
# Simulations_ph1_T_202.82299999999998_P_6987.1997234346545 has been executed and will be used
# Simulations_ph2_T_202.82299999999998_P_6987.1997234346545 has been executed and will be used
# Simulations_ph1_T_201.32299999999998_P_6979.451118451055 has been executed and will be used
# Simulations_ph2_T_201.32299999999998_P_6979.451118451055 has been executed and will be used
# Simulations_ph1_T_201.32299999999998_P_6992.224084943751 has been executed and will be used
# Simulations_ph2_T_201.32299999999998_P_6992.224084943751 has been executed and will be used
# Simulations_ph1_T_199.82299999999998_P_7009.623387622498 has been executed and will be used
# Simulations_ph2_T_199.82299999999998_P_7009.623387622498 has been executed and will be used
# Simulations_ph1_T_199.82299999999998_P_7007.4615946212225 has been executed and will be used
# Simulations_ph2_T_199.82299999999998_P_7007.4615946212225 has been executed and will be used
# Simulations_ph1_T_198.32299999999998_P_6996.11622727065 has been executed and will be used
# Simulations_ph2_T_198.32299999999998_P_6996.11622727065 has been executed and will be used
# Simulations_ph1_T_198.32299999999998_P_7014.541506673457 has been executed and will be used
# Simulations_ph2_T_198.32299999999998_P_7014.541506673457 has been executed and will be used
# Simulations_ph1_T_196.82299999999998_P_7035.819549596955 has been executed and will be used
# Simulations_ph2_T_196.82299999999998_P_7035.819549596955 has been executed and will be used
# Simulations_ph1_T_196.82299999999998_P_7025.023821753157 has been executed and will be used
# Simulations_ph2_T_196.82299999999998_P_7025.023821753157 has been executed and will be used
# Simulations_ph1_T_195.32299999999998_P_7032.8336584079425 has been executed and will be used
# Simulations_ph2_T_195.32299999999998_P_7032.8336584079425 has been executed and will be used
# Simulations_ph1_T_195.32299999999998_P_7041.5587135914175 has been executed and will be used
# Simulations_ph2_T_195.32299999999998_P_7041.5587135914175 has been executed and will be used
# Simulations_ph1_T_193.82299999999998_P_7066.90595466724 has been executed and will be used
# Simulations_ph2_T_193.82299999999998_P_7066.90595466724 has been executed and will be used
# Simulations_ph1_T_193.82299999999998_P_7053.638231940239 has been executed and will be used
# Simulations_ph2_T_193.82299999999998_P_7053.638231940239 has been executed and will be used
# Simulations_ph1_T_192.32299999999998_P_7063.269893148944 has been executed and will be used
# Simulations_ph2_T_192.32299999999998_P_7063.269893148944 has been executed and will be used
# Simulations_ph1_T_192.32299999999998_P_7071.399877746304 has been executed and will be used
# Simulations_ph2_T_192.32299999999998_P_7071.399877746304 has been executed and will be used
# Simulations_ph1_T_190.82299999999998_P_7084.310540828072 has been executed and will be used
# Simulations_ph2_T_190.82299999999998_P_7084.310540828072 has been executed and will be used
# Simulations_ph1_T_190.82299999999998_P_7078.417401980096 has been executed and will be used
# Simulations_ph2_T_190.82299999999998_P_7078.417401980096 has been executed and will be used
# Simulations_ph1_T_189.32299999999998_P_7088.984776240819 has been executed and will be used
# Simulations_ph2_T_189.32299999999998_P_7088.984776240819 has been executed and will be used
# Simulations_ph1_T_189.32299999999998_P_7096.163560184223 has been executed and will be used
# Simulations_ph2_T_189.32299999999998_P_7096.163560184223 has been executed and will be used
# Simulations_ph1_T_187.82299999999998_P_7109.890830343632 has been executed and will be used
# Simulations_ph2_T_187.82299999999998_P_7109.890830343632 has been executed and will be used
# Simulations_ph1_T_187.82299999999998_P_7108.644378678274 has been executed and will be used
# Simulations_ph2_T_187.82299999999998_P_7108.644378678274 has been executed and will be used
# Simulations_ph1_T_186.32299999999998_P_7120.806316132575 has been executed and will be used
# Simulations_ph2_T_186.32299999999998_P_7120.806316132575 has been executed and will be used
# Simulations_ph1_T_186.32299999999998_P_7123.8223933844365 has been executed and will be used
# Simulations_ph2_T_186.32299999999998_P_7123.8223933844365 has been executed and will be used
# Simulations_ph1_T_184.82299999999998_P_7139.328175521962 has been executed and will be used
# Simulations_ph2_T_184.82299999999998_P_7139.328175521962 has been executed and will be used
# Simulations_ph1_T_184.82299999999998_P_7139.870125563325 has been executed and will be used
# Simulations_ph2_T_184.82299999999998_P_7139.870125563325 has been executed and will be used
# Simulations_ph1_T_183.32299999999998_P_7172.4169809321 has been executed and will be used
# Simulations_ph2_T_183.32299999999998_P_7172.4169809321 has been executed and will be used
# Simulations_ph1_T_183.32299999999998_P_7163.775450388877 has been executed and will be used
# Simulations_ph2_T_183.32299999999998_P_7163.775450388877 has been executed and will be used
# Simulations_ph1_T_181.82299999999998_P_7169.576477952405 has been executed and will be used
# Simulations_ph2_T_181.82299999999998_P_7169.576477952405 has been executed and will be used
# Simulations_ph1_T_181.82299999999998_P_7182.9409797875505 has been executed and will be used
# Simulations_ph2_T_181.82299999999998_P_7182.9409797875505 has been executed and will be used
# Simulations_ph1_T_180.32299999999998_P_7189.286219842411 has been executed and will be used
# Simulations_ph2_T_180.32299999999998_P_7189.286219842411 has been executed and will be used
# Simulations_ph1_T_180.32299999999998_P_7195.895949886324 has been executed and will be used
# Simulations_ph2_T_180.32299999999998_P_7195.895949886324 has been executed and will be used
# Simulations_ph1_T_178.82299999999998_P_7216.411194390777 has been executed and will be used
# Simulations_ph2_T_178.82299999999998_P_7216.411194390777 has been executed and will be used
# Simulations_ph1_T_178.82299999999998_P_7216.514359281722 has been executed and will be used
# Simulations_ph2_T_178.82299999999998_P_7216.514359281722 has been executed and will be used
# Simulations_ph1_T_177.32299999999998_P_7224.416637950429 has been executed and will be used
# Simulations_ph2_T_177.32299999999998_P_7224.416637950429 has been executed and will be used
# Simulations_ph1_T_177.32299999999998_P_7230.943728868064 has been executed and will be used
# Simulations_ph2_T_177.32299999999998_P_7230.943728868064 has been executed and will be used
# Simulations_ph1_T_175.82299999999998_P_7249.7276484164895 has been executed and will be used
# Simulations_ph2_T_175.82299999999998_P_7249.7276484164895 has been executed and will be used
# Simulations_ph1_T_175.82299999999998_P_7246.2401064756805 has been executed and will be used
# Simulations_ph2_T_175.82299999999998_P_7246.2401064756805 has been executed and will be used
# Simulations_ph1_T_174.32299999999998_P_7278.2387868641645 has been executed and will be used
# Simulations_ph2_T_174.32299999999998_P_7278.2387868641645 has been executed and will be used
# Simulations_ph1_T_174.32299999999998_P_7265.04041549585 has been executed and will be used
# Simulations_ph2_T_174.32299999999998_P_7265.04041549585 has been executed and will be used
# Simulations_ph1_T_172.82299999999998_P_7261.392390514983 has been executed and will be used
# Simulations_ph2_T_172.82299999999998_P_7261.392390514983 has been executed and will be used
# Simulations_ph1_T_172.82299999999998_P_7286.541320788071 has been executed and will be used
# Simulations_ph2_T_172.82299999999998_P_7286.541320788071 has been executed and will be used
# Simulations_ph1_T_171.32299999999998_P_7306.254958489647 has been executed and will be used
# Simulations_ph2_T_171.32299999999998_P_7306.254958489647 has been executed and will be used
# Simulations_ph1_T_171.32299999999998_P_7299.829769103821 has been executed and will be used
# Simulations_ph2_T_171.32299999999998_P_7299.829769103821 has been executed and will be used
# Simulations_ph1_T_169.82299999999998_P_7312.271357400629 has been executed and will be used
# Simulations_ph2_T_169.82299999999998_P_7312.271357400629 has been executed and will be used
# Simulations_ph1_T_169.82299999999998_P_7321.181555784359 has been executed and will be used
# Simulations_ph2_T_169.82299999999998_P_7321.181555784359 has been executed and will be used
# Simulations_ph1_T_168.32299999999998_P_7319.512353880899 has been executed and will be used
# Simulations_ph2_T_168.32299999999998_P_7319.512353880899 has been executed and will be used
# Simulations_ph1_T_168.32299999999998_P_7332.031459729054 has been executed and will be used
# Simulations_ph2_T_168.32299999999998_P_7332.031459729054 has been executed and will be used
# Simulations_ph1_T_166.82299999999998_P_7351.704859054935 has been executed and will be used
# Simulations_ph2_T_166.82299999999998_P_7351.704859054935 has been executed and will be used
# Simulations_ph1_T_166.82299999999998_P_7340.676855338785 has been executed and will be used
# Simulations_ph2_T_166.82299999999998_P_7340.676855338785 has been executed and will be used
# Simulations_ph1_T_165.32299999999998_P_7384.1305601025515 has been executed and will be used
# Simulations_ph2_T_165.32299999999998_P_7384.1305601025515 has been executed and will be used
# Simulations_ph1_T_165.32299999999998_P_7365.961176371931 has been executed and will be used
# Simulations_ph2_T_165.32299999999998_P_7365.961176371931 has been executed and will be used
# Simulations_ph1_T_163.82299999999998_P_7391.230163904361 has been executed and will be used
# Simulations_ph2_T_163.82299999999998_P_7391.230163904361 has been executed and will be used
# Simulations_ph1_T_163.82299999999998_P_7373.493749484202 has been executed and will be used
# Simulations_ph2_T_163.82299999999998_P_7373.493749484202 has been executed and will be used
# Simulations_ph1_T_162.32299999999998_P_7391.394498237601 has been executed and will be used
# Simulations_ph2_T_162.32299999999998_P_7391.394498237601 has been executed and will be used
# Simulations_ph1_T_162.32299999999998_P_7392.888898425495 has been executed and will be used
# Simulations_ph2_T_162.32299999999998_P_7392.888898425495 has been executed and will be used
# Simulations_ph1_T_160.82299999999998_P_7421.2986378672485 has been executed and will be used
# Simulations_ph2_T_160.82299999999998_P_7421.2986378672485 has been executed and will be used
# Simulations_ph1_T_160.82299999999998_P_7407.51676672316 has been executed and will be used
# Simulations_ph2_T_160.82299999999998_P_7407.51676672316 has been executed and will be used
# Simulations_ph1_T_159.32299999999998_P_7412.7314823656825 has been executed and will be used
# Simulations_ph2_T_159.32299999999998_P_7412.7314823656825 has been executed and will be used
# Simulations_ph1_T_159.32299999999998_P_7422.703653612881 has been executed and will be used
# Simulations_ph2_T_159.32299999999998_P_7422.703653612881 has been executed and will be used
# Simulations_ph1_T_157.82299999999998_P_7434.473745904796 has been executed and will be used
# Simulations_ph2_T_157.82299999999998_P_7434.473745904796 has been executed and will be used
# Simulations_ph1_T_157.82299999999998_P_7429.00753552209 has been executed and will be used
# Simulations_ph2_T_157.82299999999998_P_7429.00753552209 has been executed and will be used
# Simulations_ph1_T_156.32299999999998_P_7465.102379228017 has been executed and will be used
# Simulations_ph2_T_156.32299999999998_P_7465.102379228017 has been executed and will be used
# Simulations_ph1_T_156.32299999999998_P_7448.110632591185 has been executed and will be used
# Simulations_ph2_T_156.32299999999998_P_7448.110632591185 has been executed and will be used
# Simulations_ph1_T_154.82299999999998_P_7460.747386013368 has been executed and will be used
# Simulations_ph2_T_154.82299999999998_P_7460.747386013368 has been executed and will be used
# Simulations_ph1_T_154.82299999999998_P_7471.427058568012 has been executed and will be used
# Simulations_ph2_T_154.82299999999998_P_7471.427058568012 has been executed and will be used
# Simulations_ph1_T_153.32299999999998_P_7470.406877732805 has been executed and will be used
# Simulations_ph2_T_153.32299999999998_P_7470.406877732805 has been executed and will be used
# Simulations_ph1_T_153.32299999999998_P_7483.150136685117 has been executed and will be used
# Simulations_ph2_T_153.32299999999998_P_7483.150136685117 has been executed and will be used
# Simulations_ph1_T_151.82299999999998_P_7501.204949446566 has been executed and will be used
# Simulations_ph2_T_151.82299999999998_P_7501.204949446566 has been executed and will be used
# Simulations_ph1_T_151.82299999999998_P_7502.64664090374 has been executed and will be used
# Simulations_ph2_T_151.82299999999998_P_7502.64664090374 has been executed and will be used
# Simulations_ph1_T_150.32299999999998_P_7481.356924650235 has been executed and will be used
# Simulations_ph2_T_150.32299999999998_P_7481.356924650235 has been executed and will be used
# Simulations_ph1_T_150.32299999999998_P_7502.676653212085 has been executed and will be used
# Simulations_ph2_T_150.32299999999998_P_7502.676653212085 has been executed and will be used
# Simulations_ph1_T_148.82299999999998_P_7499.088541840839 has been executed and will be used
# Simulations_ph2_T_148.82299999999998_P_7499.088541840839 has been executed and will be used
# Simulations_ph1_T_148.82299999999998_P_7511.074478386243 has been executed and will be used
# Simulations_ph2_T_148.82299999999998_P_7511.074478386243 has been executed and will be used
# Simulations_ph1_T_147.32299999999998_P_7506.427916665163 has been executed and will be used
# Simulations_ph2_T_147.32299999999998_P_7506.427916665163 has been executed and will be used
# Simulations_ph1_T_147.32299999999998_P_7519.17511835248 has been executed and will be used
# Simulations_ph2_T_147.32299999999998_P_7519.17511835248 has been executed and will be used
# Simulations_ph1_T_145.82299999999998_P_7535.42355297771 has been executed and will be used
# Simulations_ph2_T_145.82299999999998_P_7535.42355297771 has been executed and will be used
# Simulations_ph1_T_145.82299999999998_P_7532.701483687202 has been executed and will be used
# Simulations_ph2_T_145.82299999999998_P_7532.701483687202 has been executed and will be used
# Simulations_ph1_T_144.32299999999998_P_7549.23118766688 has been executed and will be used
# Simulations_ph2_T_144.32299999999998_P_7549.23118766688 has been executed and will be used
# Simulations_ph1_T_144.32299999999998_P_7547.188994688028 has been executed and will be used
# Simulations_ph2_T_144.32299999999998_P_7547.188994688028 has been executed and will be used
# Simulations_ph1_T_142.82299999999998_P_7563.678768753943 has been executed and will be used
# Simulations_ph2_T_142.82299999999998_P_7563.678768753943 has been executed and will be used
# Simulations_ph1_T_142.82299999999998_P_7551.406143767805 has been executed and will be used
# Simulations_ph2_T_142.82299999999998_P_7551.406143767805 has been executed and will be used
# Simulations_ph1_T_141.32299999999998_P_7580.471210755615 has been executed and will be used
# Simulations_ph2_T_141.32299999999998_P_7580.471210755615 has been executed and will be used
# Simulations_ph1_T_141.32299999999998_P_7570.842101711942 has been executed and will be used
# Simulations_ph2_T_141.32299999999998_P_7570.842101711942 has been executed and will be used
# Simulations_ph1_T_139.82299999999998_P_7569.061927883205 has been executed and will be used
# Simulations_ph2_T_139.82299999999998_P_7569.061927883205 has been executed and will be used
# Simulations_ph1_T_139.82299999999998_P_7573.085450040145 has been executed and will be used
# Simulations_ph2_T_139.82299999999998_P_7573.085450040145 has been executed and will be used
# Simulations_ph1_T_138.32299999999998_P_7597.475543697283 has been executed and will be used
# Simulations_ph2_T_138.32299999999998_P_7597.475543697283 has been executed and will be used
# Simulations_ph1_T_138.32299999999998_P_7584.88341281283 has been done
# Simulations_ph2_T_138.32299999999998_P_7584.88341281283 has been done
# Simulations_ph1_T_136.82299999999998_P_7588.940090639787 has been done
# Simulations_ph2_T_136.82299999999998_P_7588.940090639787 has been done
# Simulations_ph1_T_136.82299999999998_P_7599.415088784184 has been done
# Simulations_ph2_T_136.82299999999998_P_7599.415088784184 has been done
# Simulations_ph1_T_135.32299999999998_P_7627.184557653286 has been done
# Simulations_ph2_T_135.32299999999998_P_7627.184557653286 has been done
# Simulations_ph1_T_135.32299999999998_P_7612.319993736206 has been done
# Simulations_ph2_T_135.32299999999998_P_7612.319993736206 has been done
# Simulations_ph1_T_133.82299999999998_P_7620.730691423109 has been done
# Simulations_ph2_T_133.82299999999998_P_7620.730691423109 has been done
# Simulations_ph1_T_133.82299999999998_P_7634.233334378308 has been done
# Simulations_ph2_T_133.82299999999998_P_7634.233334378308 has been done
# Simulations_ph1_T_132.32299999999998_P_7614.356609826575 has been done
# Simulations_ph2_T_132.32299999999998_P_7614.356609826575 has been done
# Simulations_ph1_T_132.32299999999998_P_7636.2892264808215 has been done
# Simulations_ph2_T_132.32299999999998_P_7636.2892264808215 has been done
# Simulations_ph1_T_130.82299999999998_P_7647.157123692991 has been done
# Simulations_ph2_T_130.82299999999998_P_7647.157123692991 has been done
# Simulations_ph1_T_130.82299999999998_P_7650.4527016660495 has been done
# Simulations_ph2_T_130.82299999999998_P_7650.4527016660495 has been done
# Simulations_ph1_T_129.32299999999998_P_7663.46740994779 has been done
# Simulations_ph2_T_129.32299999999998_P_7663.46740994779 has been done
# Simulations_ph1_T_129.32299999999998_P_7662.337313882342 has been done
# Simulations_ph2_T_129.32299999999998_P_7662.337313882342 has been done
# Simulations_ph1_T_127.82299999999998_P_7666.720437048895 has been done
# Simulations_ph2_T_127.82299999999998_P_7666.720437048895 has been done
# Simulations_ph1_T_127.82299999999998_P_7676.1040819172895 has been done
# Simulations_ph2_T_127.82299999999998_P_7676.1040819172895 has been done
# Simulations_ph1_T_126.32299999999998_P_7690.953913478095 has been done
# Simulations_ph2_T_126.32299999999998_P_7690.953913478095 has been done
# Simulations_ph1_T_126.32299999999998_P_7690.700567761069 has been done
# Simulations_ph2_T_126.32299999999998_P_7690.700567761069 has been done
# Simulations_ph1_T_124.82299999999998_P_7704.430654524343 has been done
# Simulations_ph2_T_124.82299999999998_P_7704.430654524343 has been done
# Simulations_ph1_T_124.82299999999998_P_7704.2111153286 has been done
# Simulations_ph2_T_124.82299999999998_P_7704.2111153286 has been done
# Simulations_ph1_T_123.32299999999998_P_7706.34433380921 has been done

# %%
plt.plot(T_lst, P_lst)

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/v_vi.dat',[T_lst,np.array(P_lst)*1e-4])

# %%
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)

alpha = 0.8
skip=100

for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/v-vi/vi_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='vi')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/v-vi/v_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='v')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
