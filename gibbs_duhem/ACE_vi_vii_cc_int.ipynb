# %%
import os

# %%
from tqdm import tqdm

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
from ase import io
from ase.visualize import view
from ase.build import sort, molecule
from ase.optimize import QuasiNewton, FIRE

# %%
from helpers import validate
from helpers import read_metrics

# %%
from pyace import PyACECalculator

# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
# mpl.rcParams['font.family'] = 'Times'

mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.width'] = 1.5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['xtick.minor.size'] = 3.
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.top']=True

mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['ytick.minor.width'] = 1.5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['ytick.minor.size'] = 3.
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.right']=True

# %%
calc = PyACECalculator('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.yaml',
    keep_extrapolative_structures=True,
    gamma_lower_bound=1.2,
    gamma_upper_bound=10,
    stop_at_large_extrapolation=False)
calc.set_active_set('../../upfit/10000_ladder/asi/interim_potential_ladder_step_1.asi')

# %%
def linear_fn(x, a, b):
    return a*x + b

# %%
import os
import warnings
def read_log(path):
    os.system(f'cat {path}/lmp.out | grep -e Step -e Loop -n > read_log')
    file = open('read_log').readlines()
    os.system('rm read_log')
    log_lst = list()
    for i in range(0,len(file),2):
        try:
                n1 = int(file[i].replace(':',' ').split()[0])
                n2 = int(file[i+1].replace(':',' ').split()[0])
                log_lst.append(pd.read_csv(f'{path}/lmp.out',
                                   skiprows=n1-1, nrows=n2-n1-1, sep= '\s+'))
        except:
            break

    if(len(file)%2 ==0):
        return log_lst
    else:
        warnings.warn('Last run is not finished')            
        n = int(file[-1].replace(':',' ').split()[0])
        log_lst.append(pd.read_csv(f'{path}/lmp.out', skiprows=n-1, sep= '\s+'))

    return log_lst

# %%
def write_lmp_file(P, T, path, pot_dir, barostat='iso', n_steps_eq = 2*10**3, n_steps_pr = 2*10**7):
    s= np.random.randint(99999)
    lines= ['\n',
 'units\t\tmetal\t\t\t\t\t\t## E in [eV], t in [ps], P in [10000 Pa], l in [A]\n',
 'atom_style\tatomic\t\t\t\t\t\t## mass x y z vx vy vz \n',
 '\n',
 'neighbor\t0.5 bin\t\t\t\t\t\t## neighbor list, skin = 0.5 Angstrom\n',
 'neigh_modify\tevery 2 delay 10 check yes\t\t\t## update of neighbor list\n',
 '\n',
 '############################## main variables\n',
f'variable        seed equal {s}\n',
 '\n',
f'variable\ttemperature equal {T}\n',
 'variable\ttempDamp equal 0.1\n',
 '\n',
f'variable        pressure equal {P}\n',
 'variable        pressureDamp equal 1.0 \t\t\t\t# This is 1 ps\n',
 '\n',
 '##############################\n',
 '\n',
 'read_data water.dat\n',
 '\n',
 'mass\t\t1 1.008    # H\n',
 'mass\t\t2 15.9994  # O\n',
 '\n',
 '\n',
 'pair_style\tpace/extrapolation\n',
 f'pair_coeff\t* * {pot_dir}/interim_potential_ladder_step_1.yaml\
 {pot_dir}/interim_potential_ladder_step_1.asi H O\n',
 '\n',
 'fix pace_gamma all pair 1000 pace/extrapolation gamma 1\n',
 'compute max_pace_gamma all reduce max f_pace_gamma\n',
 'variable dump_skip equal "c_max_pace_gamma < 10"\n',
 '\n',
 'dump pace_dump all custom 1000 extrapolative_structures.dump id type x y z f_pace_gamma\n',
 'dump_modify pace_dump skip v_dump_skip\n',
 'dump_modify pace_dump element H O\n',
 '\n',
 'variable max_pace_gamma equal c_max_pace_gamma',
 '\n',
 '\n',
 'timestep\t0.0005\t\t\t\t\t\t## timestep = 0.0005*ps = 0.5 fs\n',
 '\n',
 'thermo\t\t100\n',
 'thermo_style custom step etotal pe ke press temp vol enthalpy density c_max_pace_gamma\n',
 '\n',
 '\n',
 'min_style cg\n',
 'minimize 0.0 5.0e-4 10000 100000\n'
 '\n',
 '################## equilibration of main calculation\n',
 '# Equilibrate to specified number of ice\n',
 '\n',
f'fix             3 all nph {barostat} '+' ${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run {n_steps_eq} \n',
 '\n',
 'unfix 3\n',
 'unfix 4\n',
 '\n',
 '################## main calculation\n',
 '\n',
 '#dump \t\t3 all custom 1000 traj.lammpstrj id type element x y z\n',
 '#dump_modify     3 element H O\n',
 '\n',
 '\n',
f'fix             3 all nph {barostat} '+'${pressure} ${pressure} ${pressureDamp}\n',
 'fix             4 all temp/csvr ${temperature} ${temperature} ${tempDamp} ${seed}\n',
 'velocity \tall create ${temperature} ${seed} dist gaussian\n',
 '\n',
f'run             {n_steps_pr}\n',
 '\n',
 'unfix\t\t3\n',
 'unfix\t\t4\n',
 'write_data data.data']
    fr = open(f'{path}/in.lammps', 'w')
    fr.writelines(lines)
    fr.close()
    return

# %%
def plot_stats_eq(path):
    #Read the data from the path
    
    data = np.loadtxt(f'{path}/COLVAR-EQUILIBRATE')
    log = read_log(f'{path}/')[0]
    
    fig, ax = plt.subplots(figsize=(16,5), ncols=3)
    
    ax[0].plot(data[:,2], alpha=1.0, c='C0')
    ax[0].axhline(np.average(data[:,2]), ls='--', color='C0', lw=2)
    # ax[0].set_xlabel('Time [ps]')
    # ax[0].set_ylabel('A $\mathrm{[\AA^{2}]}$')
    ax[0].set_title('$\mathrm{n_{ice}}$')

    ax[1].plot(log.Temp, alpha=1.0, c='k')
    ax[1].axhline(log.Temp.mean(), ls='--', color='k', lw=2)
    # ax[1].set_xlabel('Time [ps]')
    ax[1].set_title('Temperature')

    ax[2].plot(log.Press, alpha=1.0, c='k')
    ax[2].axhline(log.Press.mean(), ls='--', color='k', lw=2)
    # ax[2].set_xlabel('Time [ps]')
    ax[2].set_title('Pressure')
    
def plot_stats(path, skip=0):
    #Read the data from the path
    
    log = read_log(f'{path}/')[-1]
        
    fig, ax = plt.subplots(figsize=(16,4), ncols=3)
    
    ax[0].plot(log.Step[skip:]*5e-7, log.Enthalpy[skip:], alpha=1., c='k')
    ax[0].axhline(log.Enthalpy[skip:].mean(), ls='--', color='w', lw=2)
    ax[0].set_xlabel('Time [ns]')
    ax[0].set_title('H')

    ax[1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=1., c='k')
    ax[1].axhline(log.Temp[skip:].mean(), ls='--', color='w', lw=2)
    ax[1].set_xlabel('Time [ns]')
    ax[1].set_title('T [K]')

    ax[2].plot(log.Step[skip:]*5e-7,log.Press[skip:], alpha=1., c='k')
    ax[2].axhline(log.Press[skip:].mean(), ls='--', color='w', lw=2)
    ax[2].set_xlabel('Time [ns]')
    ax[2].set_title('P [bar]')

# %%
path = '/home/users/saadie5f/piaggi/phase_diagram/TIP4P-Ice-Phase-Diagram/GibbsDuhemSimulations\
/IceII_IceVI/Initial/IceVI/iceVI.data'
ph_1 = io.read(f'{path}',
                format='lammps-data')
ph_1.set_chemical_symbols(list(map(lambda s: 'O' if s == 'He' else s, ph_1.get_chemical_symbols())))
np.unique(ph_1.get_chemical_symbols())
ph_1.wrap()
view(ph_1, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'H'), value='All'…

# %%
ph_1.set_calculator(calc)
opt_ph_1 = QuasiNewton(ph_1)
opt_ph_1.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 19:52:36    -9202.841374*       2.2703
# BFGSLineSearch:    1[  2] 19:52:40    -9235.610513*       1.0207
# BFGSLineSearch:    2[  3] 19:52:43    -9256.268794*       2.4291
# BFGSLineSearch:    3[  5] 19:52:48    -9263.766116*       0.7261
# True

# %%
atoms_ice = io.read('../vii/30000_bar/1-bulk/450/traj.lammpstrj', index=':')
ph_2 = atoms_ice[-1]
ph_2.wrap()
view(ph_2, viewer='nglview')
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'H'), value='All'…

# %%
ph_2.set_calculator(calc)
opt_ph_2 = QuasiNewton(ph_2)
opt_ph_2.run(fmax=1)
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 20:08:25    -6176.928188*       4.7116
# BFGSLineSearch:    1[  2] 20:08:27    -6199.598384*       2.1300
# BFGSLineSearch:    2[  4] 20:08:30    -6208.224742*       3.4353
# BFGSLineSearch:    3[  6] 20:08:33    -6220.486110*       3.1778
# BFGSLineSearch:    4[  8] 20:08:36    -6224.494949*       1.8871
# BFGSLineSearch:    5[  9] 20:08:38    -6236.505488*       3.9368
# BFGSLineSearch:    6[ 11] 20:08:41    -6240.398581*       2.1386
# BFGSLineSearch:    7[ 13] 20:08:43    -6242.119187*       1.7823
# BFGSLineSearch:    8[ 15] 20:08:46    -6246.438049*       5.8739
# BFGSLineSearch:    9[ 17] 20:08:49    -6247.968454*       2.2803
# BFGSLineSearch:   10[ 19] 20:08:52    -6249.325297*       3.7498
# BFGSLineSearch:   11[ 21] 20:08:55    -6250.873187*       2.0118
# BFGSLineSearch:   12[ 23] 20:08:58    -6251.329191*       2.3190
# BFGSLineSearch:   13[ 24] 20:09:00    -6253.106802*       1.6106
# BFGSLineSearch:   14[ 26] 20:09:02    -6253.467956*       0.5436
# True

# %%
def run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2, 
           n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip=0):
    try:
        os.mkdir(path_ph1+f'_T_{T}_P_{P}')
        os.chdir(path_ph1+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_1, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph1+f'_T_{T}_P_{P}', pot_dir, barostat_ph1, n_steps_eq_ph1, n_steps_pr_ph1)
        os.system('nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph1_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph1_T_{T}_P_{P} has been executed and will be used')
    
    try:
        os.mkdir(path_ph2+f'_T_{T}_P_{P}')
        os.chdir(path_ph2+f'_T_{T}_P_{P}')
        io.write('water.dat', ph_2, format='lammps-data', specorder=['H', 'O'])
        write_lmp_file(P, T, path_ph2+f'_T_{T}_P_{P}', pot_dir, barostat_ph2, n_steps_eq_ph2, n_steps_pr_ph2)
        os.system('nohup lmp_volta -k on g 1  -sf kk -pk kokkos newton on neigh half -in in.lammps > lmp.out')
        print(f'Simulations_ph2_T_{T}_P_{P} has been done')
    except:
        print(f'Simulations_ph2_T_{T}_P_{P} has been executed and will be used')
    
    n_mols_ph1 = int(len(ph_1)/3)
    n_mols_ph2 = int(len(ph_2)/3)
    
    log_ph1 = read_log(path_ph1+f'_T_{T}_P_{P}')[-1]
    log_ph2 = read_log(path_ph2+f'_T_{T}_P_{P}')[-1]

    h_ph1=np.mean(log_ph1.Enthalpy[skip:],axis=0)/n_mols_ph1
    vol_ph1=np.mean(log_ph1.Volume[skip:],axis=0)/n_mols_ph1

    h_ph2=np.mean(log_ph2.Enthalpy[skip:],axis=0)/n_mols_ph2
    vol_ph2=np.mean(log_ph2.Volume[skip:],axis=0)/n_mols_ph2
    
    
    c_bar_eV_Acube=6.241509e-7
    return 1/(T*(vol_ph1-vol_ph2)*c_bar_eV_Acube/(h_ph1-h_ph2))

# %%
pot_dir = '/home/users/saadie5f/piaggi/phase_diagram/upfit/10000_ladder/asi'

path_ph1 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/vi-vii/vi'
path_ph2 = '/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/vi-vii/vii'

T = 330.40961326777926; P = 12509.012794530714; T_step = -3
n_steps_eq_ph1 = 2*10**4; n_steps_pr_ph1 = 2*10**5
n_steps_eq_ph2 = 2*10**4; n_steps_pr_ph2 = 2*10**5
barostat_ph1 = 'aniso'; barostat_ph2 = 'aniso'

skip = 100
n_pnts = 50

T_lst = list();
P_lst = list();
for i in range(n_pnts):
    T_lst.append(T); P_lst.append(P)
    
    k1 = run_md(P, T, ph_1, ph_2, path_ph1, path_ph2, barostat_ph1, barostat_ph2,
                    n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k2 = run_md(P + 0.5 * T_step * k1, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2,
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k3 = run_md(P + 0.5 * T_step * k2, T + 0.5 * T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    k4 = run_md(P + T_step * k3, T + T_step, ph_1, ph_2, path_ph1, path_ph2, 
                barostat_ph1, barostat_ph2,
                n_steps_eq_ph1, n_steps_pr_ph1, n_steps_eq_ph2, n_steps_pr_ph2, skip)

    P += (1./6.) * T_step * (k1 + 2*k2 + 2*k3 + k4)
    T += T_step
# Out:
# Simulations_ph1_T_330.40961326777926_P_12509.012794530714 has been executed and will be used
# Simulations_ph2_T_330.40961326777926_P_12509.012794530714 has been executed and will be used
# Simulations_ph1_T_328.90961326777926_P_12476.629821556646 has been executed and will be used
# Simulations_ph2_T_328.90961326777926_P_12476.629821556646 has been executed and will be used
# Simulations_ph1_T_328.90961326777926_P_12475.469007662166 has been executed and will be used
# Simulations_ph2_T_328.90961326777926_P_12475.469007662166 has been executed and will be used
# Simulations_ph1_T_327.40961326777926_P_12449.857064983966 has been executed and will be used
# Simulations_ph2_T_327.40961326777926_P_12449.857064983966 has been executed and will be used
# Simulations_ph1_T_327.40961326777926_P_12444.758479995942 has been executed and will be used
# Simulations_ph2_T_327.40961326777926_P_12444.758479995942 has been executed and will be used
# Simulations_ph1_T_325.90961326777926_P_12412.632600205648 has been executed and will be used
# Simulations_ph2_T_325.90961326777926_P_12412.632600205648 has been executed and will be used
# Simulations_ph1_T_325.90961326777926_P_12405.560187827978 has been executed and will be used
# Simulations_ph2_T_325.90961326777926_P_12405.560187827978 has been executed and will be used
# Simulations_ph1_T_324.40961326777926_P_12392.572964175932 has been executed and will be used
# Simulations_ph2_T_324.40961326777926_P_12392.572964175932 has been executed and will be used
# Simulations_ph1_T_324.40961326777926_P_12382.452584421828 has been executed and will be used
# Simulations_ph2_T_324.40961326777926_P_12382.452584421828 has been executed and will be used
# Simulations_ph1_T_322.90961326777926_P_12347.130510066945 has been executed and will be used
# Simulations_ph2_T_322.90961326777926_P_12347.130510066945 has been executed and will be used
# Simulations_ph1_T_322.90961326777926_P_12350.04078514811 has been executed and will be used
# Simulations_ph2_T_322.90961326777926_P_12350.04078514811 has been executed and will be used
# Simulations_ph1_T_321.40961326777926_P_12324.645048704751 has been executed and will be used
# Simulations_ph2_T_321.40961326777926_P_12324.645048704751 has been executed and will be used
# Simulations_ph1_T_321.40961326777926_P_12316.086032562655 has been executed and will be used
# Simulations_ph2_T_321.40961326777926_P_12316.086032562655 has been executed and will be used
# Simulations_ph1_T_319.90961326777926_P_12290.809859908702 has been executed and will be used
# Simulations_ph2_T_319.90961326777926_P_12290.809859908702 has been executed and will be used
# Simulations_ph1_T_319.90961326777926_P_12286.205971570376 has been executed and will be used
# Simulations_ph2_T_319.90961326777926_P_12286.205971570376 has been executed and will be used
# Simulations_ph1_T_318.40961326777926_P_12242.474035932015 has been executed and will be used
# Simulations_ph2_T_318.40961326777926_P_12242.474035932015 has been executed and will be used
# Simulations_ph1_T_318.40961326777926_P_12252.425043975536 has been executed and will be used
# Simulations_ph2_T_318.40961326777926_P_12252.425043975536 has been executed and will be used
# Simulations_ph1_T_316.90961326777926_P_12222.453261054834 has been executed and will be used
# Simulations_ph2_T_316.90961326777926_P_12222.453261054834 has been executed and will be used
# Simulations_ph1_T_316.90961326777926_P_12216.208820879958 has been executed and will be used
# Simulations_ph2_T_316.90961326777926_P_12216.208820879958 has been executed and will be used
# Simulations_ph1_T_315.40961326777926_P_12177.554108821663 has been executed and will be used
# Simulations_ph2_T_315.40961326777926_P_12177.554108821663 has been executed and will be used
# Simulations_ph1_T_315.40961326777926_P_12181.740182850035 has been executed and will be used
# Simulations_ph2_T_315.40961326777926_P_12181.740182850035 has been executed and will be used
# Simulations_ph1_T_313.90961326777926_P_12153.358407650063 has been executed and will be used
# Simulations_ph2_T_313.90961326777926_P_12153.358407650063 has been executed and will be used
# Simulations_ph1_T_313.90961326777926_P_12156.542488128393 has been executed and will be used
# Simulations_ph2_T_313.90961326777926_P_12156.542488128393 has been executed and will be used
# Simulations_ph1_T_312.40961326777926_P_12122.48409869761 has been executed and will be used
# Simulations_ph2_T_312.40961326777926_P_12122.48409869761 has been executed and will be used
# Simulations_ph1_T_312.40961326777926_P_12124.90253310901 has been executed and will be used
# Simulations_ph2_T_312.40961326777926_P_12124.90253310901 has been executed and will be used
# Simulations_ph1_T_310.90961326777926_P_12092.082354340768 has been executed and will be used
# Simulations_ph2_T_310.90961326777926_P_12092.082354340768 has been executed and will be used
# Simulations_ph1_T_310.90961326777926_P_12099.284421706534 has been executed and will be used
# Simulations_ph2_T_310.90961326777926_P_12099.284421706534 has been executed and will be used
# Simulations_ph1_T_309.40961326777926_P_12059.693255203156 has been executed and will be used
# Simulations_ph2_T_309.40961326777926_P_12059.693255203156 has been executed and will be used
# Simulations_ph1_T_309.40961326777926_P_12065.078427164193 has been executed and will be used
# Simulations_ph2_T_309.40961326777926_P_12065.078427164193 has been executed and will be used
# Simulations_ph1_T_307.90961326777926_P_12022.34640318676 has been executed and will be used
# Simulations_ph2_T_307.90961326777926_P_12022.34640318676 has been executed and will be used
# Simulations_ph1_T_307.90961326777926_P_12033.230162503192 has been executed and will be used
# Simulations_ph2_T_307.90961326777926_P_12033.230162503192 has been executed and will be used
# Simulations_ph1_T_306.40961326777926_P_12013.81527196067 has been executed and will be used
# Simulations_ph2_T_306.40961326777926_P_12013.81527196067 has been executed and will be used
# Simulations_ph1_T_306.40961326777926_P_12001.979640274829 has been executed and will be used
# Simulations_ph2_T_306.40961326777926_P_12001.979640274829 has been executed and will be used
# Simulations_ph1_T_304.90961326777926_P_11969.099424767212 has been executed and will be used
# Simulations_ph2_T_304.90961326777926_P_11969.099424767212 has been executed and will be used
# Simulations_ph1_T_304.90961326777926_P_11967.467150702905 has been executed and will be used
# Simulations_ph2_T_304.90961326777926_P_11967.467150702905 has been executed and will be used
# Simulations_ph1_T_303.40961326777926_P_11948.740618340371 has been executed and will be used
# Simulations_ph2_T_303.40961326777926_P_11948.740618340371 has been executed and will be used
# Simulations_ph1_T_303.40961326777926_P_11940.279731393477 has been executed and will be used
# Simulations_ph2_T_303.40961326777926_P_11940.279731393477 has been executed and will be used
# Simulations_ph1_T_301.90961326777926_P_11905.728019037966 has been executed and will be used
# Simulations_ph2_T_301.90961326777926_P_11905.728019037966 has been executed and will be used
# Simulations_ph1_T_301.90961326777926_P_11912.283761175138 has been executed and will be used
# Simulations_ph2_T_301.90961326777926_P_11912.283761175138 has been executed and will be used
# Simulations_ph1_T_300.40961326777926_P_11880.968443547874 has been executed and will be used
# Simulations_ph2_T_300.40961326777926_P_11880.968443547874 has been executed and will be used
# Simulations_ph1_T_300.40961326777926_P_11880.654281722005 has been executed and will be used
# Simulations_ph2_T_300.40961326777926_P_11880.654281722005 has been executed and will be used
# Simulations_ph1_T_298.90961326777926_P_11858.257802005372 has been executed and will be used
# Simulations_ph2_T_298.90961326777926_P_11858.257802005372 has been executed and will be used
# Simulations_ph1_T_298.90961326777926_P_11838.983866381393 has been executed and will be used
# Simulations_ph2_T_298.90961326777926_P_11838.983866381393 has been executed and will be used
# Simulations_ph1_T_297.40961326777926_P_11813.480298370388 has been executed and will be used
# Simulations_ph2_T_297.40961326777926_P_11813.480298370388 has been executed and will be used
# Simulations_ph1_T_297.40961326777926_P_11813.60690126299 has been executed and will be used
# Simulations_ph2_T_297.40961326777926_P_11813.60690126299 has been executed and will be used
# Simulations_ph1_T_295.90961326777926_P_11784.001531513186 has been executed and will be used
# Simulations_ph2_T_295.90961326777926_P_11784.001531513186 has been executed and will be used
# Simulations_ph1_T_295.90961326777926_P_11786.355263619702 has been executed and will be used
# Simulations_ph2_T_295.90961326777926_P_11786.355263619702 has been executed and will be used
# Simulations_ph1_T_294.40961326777926_P_11754.729582321104 has been executed and will be used
# Simulations_ph2_T_294.40961326777926_P_11754.729582321104 has been executed and will be used
# Simulations_ph1_T_294.40961326777926_P_11756.409147865817 has been executed and will be used
# Simulations_ph2_T_294.40961326777926_P_11756.409147865817 has been executed and will be used
# Simulations_ph1_T_292.90961326777926_P_11729.16507244459 has been executed and will be used
# Simulations_ph2_T_292.90961326777926_P_11729.16507244459 has been executed and will be used
# Simulations_ph1_T_292.90961326777926_P_11724.228763635048 has been executed and will be used
# Simulations_ph2_T_292.90961326777926_P_11724.228763635048 has been executed and will be used
# Simulations_ph1_T_291.40961326777926_P_11693.482594461164 has been executed and will be used
# Simulations_ph2_T_291.40961326777926_P_11693.482594461164 has been executed and will be used
# Simulations_ph1_T_291.40961326777926_P_11694.300599045087 has been executed and will be used
# Simulations_ph2_T_291.40961326777926_P_11694.300599045087 has been executed and will be used
# Simulations_ph1_T_289.90961326777926_P_11665.342624860987 has been executed and will be used
# Simulations_ph2_T_289.90961326777926_P_11665.342624860987 has been executed and will be used
# Simulations_ph1_T_289.90961326777926_P_11659.557407518616 has been executed and will be used
# Simulations_ph2_T_289.90961326777926_P_11659.557407518616 has been executed and will be used
# Simulations_ph1_T_288.40961326777926_P_11633.123626108958 has been executed and will be used
# Simulations_ph2_T_288.40961326777926_P_11633.123626108958 has been executed and will be used
# Simulations_ph1_T_288.40961326777926_P_11632.190361484376 has been executed and will be used
# Simulations_ph2_T_288.40961326777926_P_11632.190361484376 has been executed and will be used
# Simulations_ph1_T_286.90961326777926_P_11610.277005671518 has been executed and will be used
# Simulations_ph2_T_286.90961326777926_P_11610.277005671518 has been executed and will be used
# Simulations_ph1_T_286.90961326777926_P_11592.201332102915 has been executed and will be used
# Simulations_ph2_T_286.90961326777926_P_11592.201332102915 has been executed and will be used
# Simulations_ph1_T_285.40961326777926_P_11578.724674016694 has been executed and will be used
# Simulations_ph2_T_285.40961326777926_P_11578.724674016694 has been executed and will be used
# Simulations_ph1_T_285.40961326777926_P_11565.47658417636 has been executed and will be used
# Simulations_ph2_T_285.40961326777926_P_11565.47658417636 has been executed and will be used
# Simulations_ph1_T_283.90961326777926_P_11522.779359554597 has been executed and will be used
# Simulations_ph2_T_283.90961326777926_P_11522.779359554597 has been executed and will be used
# Simulations_ph1_T_283.90961326777926_P_11527.761064935852 has been executed and will be used
# Simulations_ph2_T_283.90961326777926_P_11527.761064935852 has been executed and will be used
# Simulations_ph1_T_282.40961326777926_P_11485.517529947372 has been executed and will be used
# Simulations_ph2_T_282.40961326777926_P_11485.517529947372 has been executed and will be used
# Simulations_ph1_T_282.40961326777926_P_11491.201414198125 has been executed and will be used
# Simulations_ph2_T_282.40961326777926_P_11491.201414198125 has been executed and will be used
# Simulations_ph1_T_280.90961326777926_P_11467.224022372206 has been executed and will be used
# Simulations_ph2_T_280.90961326777926_P_11467.224022372206 has been executed and will be used
# Simulations_ph1_T_280.90961326777926_P_11458.308539916725 has been executed and will be used
# Simulations_ph2_T_280.90961326777926_P_11458.308539916725 has been executed and will be used
# Simulations_ph1_T_279.40961326777926_P_11438.73365811964 has been executed and will be used
# Simulations_ph2_T_279.40961326777926_P_11438.73365811964 has been executed and will be used
# Simulations_ph1_T_279.40961326777926_P_11433.334349262146 has been executed and will be used
# Simulations_ph2_T_279.40961326777926_P_11433.334349262146 has been executed and will be used
# Simulations_ph1_T_277.90961326777926_P_11408.232275701606 has been executed and will be used
# Simulations_ph2_T_277.90961326777926_P_11408.232275701606 has been executed and will be used
# Simulations_ph1_T_277.90961326777926_P_11405.063564580822 has been executed and will be used
# Simulations_ph2_T_277.90961326777926_P_11405.063564580822 has been executed and will be used
# Simulations_ph1_T_276.40961326777926_P_11374.724773781685 has been executed and will be used
# Simulations_ph2_T_276.40961326777926_P_11374.724773781685 has been executed and will be used
# Simulations_ph1_T_276.40961326777926_P_11375.971830044959 has been executed and will be used
# Simulations_ph2_T_276.40961326777926_P_11375.971830044959 has been executed and will be used
# Simulations_ph1_T_274.90961326777926_P_11345.74416809523 has been executed and will be used
# Simulations_ph2_T_274.90961326777926_P_11345.74416809523 has been executed and will be used
# Simulations_ph1_T_274.90961326777926_P_11338.964732645589 has been executed and will be used
# Simulations_ph2_T_274.90961326777926_P_11338.964732645589 has been executed and will be used
# Simulations_ph1_T_273.40961326777926_P_11312.070831664825 has been executed and will be used
# Simulations_ph2_T_273.40961326777926_P_11312.070831664825 has been executed and will be used
# Simulations_ph1_T_273.40961326777926_P_11310.320255863706 has been executed and will be used
# Simulations_ph2_T_273.40961326777926_P_11310.320255863706 has been executed and will be used
# Simulations_ph1_T_271.90961326777926_P_11280.561369133726 has been executed and will be used
# Simulations_ph2_T_271.90961326777926_P_11280.561369133726 has been executed and will be used
# Simulations_ph1_T_271.90961326777926_P_11276.997897404726 has been executed and will be used
# Simulations_ph2_T_271.90961326777926_P_11276.997897404726 has been executed and will be used
# Simulations_ph1_T_270.40961326777926_P_11254.330018353347 has been executed and will be used
# Simulations_ph2_T_270.40961326777926_P_11254.330018353347 has been executed and will be used
# Simulations_ph1_T_270.40961326777926_P_11248.987755335702 has been executed and will be used
# Simulations_ph2_T_270.40961326777926_P_11248.987755335702 has been executed and will be used
# Simulations_ph1_T_268.90961326777926_P_11224.196236199801 has been executed and will be used
# Simulations_ph2_T_268.90961326777926_P_11224.196236199801 has been executed and will be used
# Simulations_ph1_T_268.90961326777926_P_11212.291880732157 has been executed and will be used
# Simulations_ph2_T_268.90961326777926_P_11212.291880732157 has been executed and will be used
# Simulations_ph1_T_267.40961326777926_P_11181.349729889072 has been executed and will be used
# Simulations_ph2_T_267.40961326777926_P_11181.349729889072 has been executed and will be used
# Simulations_ph1_T_267.40961326777926_P_11183.338200939603 has been executed and will be used
# Simulations_ph2_T_267.40961326777926_P_11183.338200939603 has been executed and will be used
# Simulations_ph1_T_265.90961326777926_P_11160.2475589784 has been executed and will be used
# Simulations_ph2_T_265.90961326777926_P_11160.2475589784 has been executed and will be used
# Simulations_ph1_T_265.90961326777926_P_11151.79018722126 has been executed and will be used
# Simulations_ph2_T_265.90961326777926_P_11151.79018722126 has been executed and will be used
# Simulations_ph1_T_264.40961326777926_P_11122.480972492951 has been executed and will be used
# Simulations_ph2_T_264.40961326777926_P_11122.480972492951 has been executed and will be used
# Simulations_ph1_T_264.40961326777926_P_11121.540758850577 has been executed and will be used
# Simulations_ph2_T_264.40961326777926_P_11121.540758850577 has been executed and will be used
# Simulations_ph1_T_262.90961326777926_P_11090.015792003265 has been executed and will be used
# Simulations_ph2_T_262.90961326777926_P_11090.015792003265 has been executed and will be used
# Simulations_ph1_T_262.90961326777926_P_11091.543012236096 has been executed and will be used
# Simulations_ph2_T_262.90961326777926_P_11091.543012236096 has been executed and will be used
# Simulations_ph1_T_261.40961326777926_P_11063.484553475211 has been executed and will be used
# Simulations_ph2_T_261.40961326777926_P_11063.484553475211 has been executed and will be used
# Simulations_ph1_T_261.40961326777926_P_11059.999188613352 has been executed and will be used
# Simulations_ph2_T_261.40961326777926_P_11059.999188613352 has been executed and will be used
# Simulations_ph1_T_259.90961326777926_P_11026.199914294197 has been executed and will be used
# Simulations_ph2_T_259.90961326777926_P_11026.199914294197 has been executed and will be used
# Simulations_ph1_T_259.90961326777926_P_11030.378358495254 has been executed and will be used
# Simulations_ph2_T_259.90961326777926_P_11030.378358495254 has been executed and will be used
# Simulations_ph1_T_258.40961326777926_P_11003.429472684005 has been executed and will be used
# Simulations_ph2_T_258.40961326777926_P_11003.429472684005 has been executed and will be used
# Simulations_ph1_T_258.40961326777926_P_11000.639134459929 has been executed and will be used
# Simulations_ph2_T_258.40961326777926_P_11000.639134459929 has been executed and will be used
# Simulations_ph1_T_256.90961326777926_P_10970.471822597194 has been executed and will be used
# Simulations_ph2_T_256.90961326777926_P_10970.471822597194 has been executed and will be used
# Simulations_ph1_T_256.90961326777926_P_10977.166772831215 has been executed and will be used
# Simulations_ph2_T_256.90961326777926_P_10977.166772831215 has been executed and will be used
# Simulations_ph1_T_255.40961326777926_P_10938.420372677245 has been executed and will be used
# Simulations_ph2_T_255.40961326777926_P_10938.420372677245 has been executed and will be used
# Simulations_ph1_T_255.40961326777926_P_10944.94838189712 has been executed and will be used
# Simulations_ph2_T_255.40961326777926_P_10944.94838189712 has been executed and will be used
# Simulations_ph1_T_253.90961326777926_P_10919.722178162363 has been executed and will be used
# Simulations_ph2_T_253.90961326777926_P_10919.722178162363 has been executed and will be used
# Simulations_ph1_T_253.90961326777926_P_10914.514933591283 has been executed and will be used
# Simulations_ph2_T_253.90961326777926_P_10914.514933591283 has been executed and will be used
# Simulations_ph1_T_252.40961326777926_P_10898.035566294007 has been executed and will be used
# Simulations_ph2_T_252.40961326777926_P_10898.035566294007 has been executed and will be used
# Simulations_ph1_T_252.40961326777926_P_10892.533075866204 has been executed and will be used
# Simulations_ph2_T_252.40961326777926_P_10892.533075866204 has been executed and will be used
# Simulations_ph1_T_250.90961326777926_P_10858.644327579139 has been executed and will be used
# Simulations_ph2_T_250.90961326777926_P_10858.644327579139 has been executed and will be used
# Simulations_ph1_T_250.90961326777926_P_10859.946358954392 has been executed and will be used
# Simulations_ph2_T_250.90961326777926_P_10859.946358954392 has been executed and will be used
# Simulations_ph1_T_249.40961326777926_P_10827.708244369696 has been executed and will be used
# Simulations_ph2_T_249.40961326777926_P_10827.708244369696 has been executed and will be used
# Simulations_ph1_T_249.40961326777926_P_10825.16552720058 has been executed and will be used
# Simulations_ph2_T_249.40961326777926_P_10825.16552720058 has been executed and will be used
# Simulations_ph1_T_247.90961326777926_P_10800.85293147914 has been executed and will be used
# Simulations_ph2_T_247.90961326777926_P_10800.85293147914 has been executed and will be used
# Simulations_ph1_T_247.90961326777926_P_10791.664646286368 has been executed and will be used
# Simulations_ph2_T_247.90961326777926_P_10791.664646286368 has been executed and will be used
# Simulations_ph1_T_246.40961326777926_P_10750.458416686808 has been executed and will be used
# Simulations_ph2_T_246.40961326777926_P_10750.458416686808 has been executed and will be used
# Simulations_ph1_T_246.40961326777926_P_10758.268783419675 has been executed and will be used
# Simulations_ph2_T_246.40961326777926_P_10758.268783419675 has been executed and will be used
# Simulations_ph1_T_244.90961326777926_P_10721.37143741674 has been executed and will be used
# Simulations_ph2_T_244.90961326777926_P_10721.37143741674 has been executed and will be used
# Simulations_ph1_T_244.90961326777926_P_10726.741423557678 has been executed and will be used
# Simulations_ph2_T_244.90961326777926_P_10726.741423557678 has been executed and will be used
# Simulations_ph1_T_243.40961326777926_P_10687.987442333786 has been executed and will be used
# Simulations_ph2_T_243.40961326777926_P_10687.987442333786 has been executed and will be used
# Simulations_ph1_T_243.40961326777926_P_10692.417190611148 has been executed and will be used
# Simulations_ph2_T_243.40961326777926_P_10692.417190611148 has been executed and will be used
# Simulations_ph1_T_241.90961326777926_P_10666.762725187667 has been executed and will be used
# Simulations_ph2_T_241.90961326777926_P_10666.762725187667 has been executed and will be used
# Simulations_ph1_T_241.90961326777926_P_10661.78731243079 has been executed and will be used
# Simulations_ph2_T_241.90961326777926_P_10661.78731243079 has been executed and will be used
# Simulations_ph1_T_240.40961326777926_P_10609.786735691534 has been executed and will be used
# Simulations_ph2_T_240.40961326777926_P_10609.786735691534 has been executed and will be used
# Simulations_ph1_T_240.40961326777926_P_10623.490218342948 has been executed and will be used
# Simulations_ph2_T_240.40961326777926_P_10623.490218342948 has been executed and will be used
# Simulations_ph1_T_238.90961326777926_P_10593.71399437202 has been executed and will be used
# Simulations_ph2_T_238.90961326777926_P_10593.71399437202 has been executed and will be used
# Simulations_ph1_T_238.90961326777926_P_10579.27267777766 has been executed and will be used
# Simulations_ph2_T_238.90961326777926_P_10579.27267777766 has been executed and will be used
# Simulations_ph1_T_237.40961326777926_P_10566.832173436082 has been executed and will be used
# Simulations_ph2_T_237.40961326777926_P_10566.832173436082 has been executed and will be used
# Simulations_ph1_T_237.40961326777926_P_10552.255464818178 has been executed and will be used
# Simulations_ph2_T_237.40961326777926_P_10552.255464818178 has been executed and will be used
# Simulations_ph1_T_235.90961326777926_P_10516.35612257774 has been executed and will be used
# Simulations_ph2_T_235.90961326777926_P_10516.35612257774 has been executed and will be used
# Simulations_ph1_T_235.90961326777926_P_10517.058561643767 has been executed and will be used
# Simulations_ph2_T_235.90961326777926_P_10517.058561643767 has been executed and will be used
# Simulations_ph1_T_234.40961326777926_P_10470.646729769123 has been executed and will be used
# Simulations_ph2_T_234.40961326777926_P_10470.646729769123 has been executed and will be used
# Simulations_ph1_T_234.40961326777926_P_10480.134963388024 has been executed and will be used
# Simulations_ph2_T_234.40961326777926_P_10480.134963388024 has been executed and will be used
# Simulations_ph1_T_232.90961326777926_P_10453.328841611285 has been executed and will be used
# Simulations_ph2_T_232.90961326777926_P_10453.328841611285 has been executed and will be used
# Simulations_ph1_T_232.90961326777926_P_10454.513246047873 has been executed and will be used
# Simulations_ph2_T_232.90961326777926_P_10454.513246047873 has been executed and will be used
# Simulations_ph1_T_231.40961326777926_P_10428.403545248191 has been executed and will be used
# Simulations_ph2_T_231.40961326777926_P_10428.403545248191 has been executed and will be used
# Simulations_ph1_T_231.40961326777926_P_10427.931198303926 has been executed and will be used
# Simulations_ph2_T_231.40961326777926_P_10427.931198303926 has been executed and will be used
# Simulations_ph1_T_229.90961326777926_P_10398.434965113622 has been executed and will be used
# Simulations_ph2_T_229.90961326777926_P_10398.434965113622 has been executed and will be used
# Simulations_ph1_T_229.90961326777926_P_10401.483718293799 has been executed and will be used
# Simulations_ph2_T_229.90961326777926_P_10401.483718293799 has been executed and will be used
# Simulations_ph1_T_228.40961326777926_P_10373.642186451742 has been executed and will be used
# Simulations_ph2_T_228.40961326777926_P_10373.642186451742 has been executed and will be used
# Simulations_ph1_T_228.40961326777926_P_10371.716152314833 has been executed and will be used
# Simulations_ph2_T_228.40961326777926_P_10371.716152314833 has been executed and will be used
# Simulations_ph1_T_226.90961326777926_P_10340.973458657603 has been executed and will be used
# Simulations_ph2_T_226.90961326777926_P_10340.973458657603 has been executed and will be used
# Simulations_ph1_T_226.90961326777926_P_10342.112194214667 has been executed and will be used
# Simulations_ph2_T_226.90961326777926_P_10342.112194214667 has been executed and will be used
# Simulations_ph1_T_225.40961326777926_P_10315.354393636948 has been executed and will be used
# Simulations_ph2_T_225.40961326777926_P_10315.354393636948 has been executed and will be used
# Simulations_ph1_T_225.40961326777926_P_10311.112578353608 has been executed and will be used
# Simulations_ph2_T_225.40961326777926_P_10311.112578353608 has been executed and will be used
# Simulations_ph1_T_223.90961326777926_P_10283.288323392675 has been executed and will be used
# Simulations_ph2_T_223.90961326777926_P_10283.288323392675 has been executed and will be used
# Simulations_ph1_T_223.90961326777926_P_10289.010019500301 has been executed and will be used
# Simulations_ph2_T_223.90961326777926_P_10289.010019500301 has been executed and will be used
# Simulations_ph1_T_222.40961326777926_P_10248.524527898826 has been executed and will be used
# Simulations_ph2_T_222.40961326777926_P_10248.524527898826 has been executed and will be used
# Simulations_ph1_T_222.40961326777926_P_10257.200315630305 has been executed and will be used
# Simulations_ph2_T_222.40961326777926_P_10257.200315630305 has been executed and will be used
# Simulations_ph1_T_220.90961326777926_P_10234.334373208767 has been executed and will be used
# Simulations_ph2_T_220.90961326777926_P_10234.334373208767 has been executed and will be used
# Simulations_ph1_T_220.90961326777926_P_10223.055298873076 has been executed and will be used
# Simulations_ph2_T_220.90961326777926_P_10223.055298873076 has been executed and will be used
# Simulations_ph1_T_219.40961326777926_P_10184.28341262385 has been executed and will be used
# Simulations_ph2_T_219.40961326777926_P_10184.28341262385 has been executed and will be used
# Simulations_ph1_T_219.40961326777926_P_10191.27909164618 has been executed and will be used
# Simulations_ph2_T_219.40961326777926_P_10191.27909164618 has been executed and will be used
# Simulations_ph1_T_217.90961326777926_P_10165.38245844739 has been executed and will be used
# Simulations_ph2_T_217.90961326777926_P_10165.38245844739 has been executed and will be used
# Simulations_ph1_T_217.90961326777926_P_10159.259945071712 has been executed and will be used
# Simulations_ph2_T_217.90961326777926_P_10159.259945071712 has been executed and will be used
# Simulations_ph1_T_216.40961326777926_P_10150.494048131082 has been executed and will be used
# Simulations_ph2_T_216.40961326777926_P_10150.494048131082 has been executed and will be used
# Simulations_ph1_T_216.40961326777926_P_10133.972520936291 has been executed and will be used
# Simulations_ph2_T_216.40961326777926_P_10133.972520936291 has been executed and will be used
# Simulations_ph1_T_214.90961326777926_P_10110.996697015655 has been executed and will be used
# Simulations_ph2_T_214.90961326777926_P_10110.996697015655 has been executed and will be used
# Simulations_ph1_T_214.90961326777926_P_10099.742772738622 has been executed and will be used
# Simulations_ph2_T_214.90961326777926_P_10099.742772738622 has been executed and will be used
# Simulations_ph1_T_213.40961326777926_P_10067.089938261113 has been executed and will be used
# Simulations_ph2_T_213.40961326777926_P_10067.089938261113 has been executed and will be used
# Simulations_ph1_T_213.40961326777926_P_10068.881781030357 has been executed and will be used
# Simulations_ph2_T_213.40961326777926_P_10068.881781030357 has been executed and will be used
# Simulations_ph1_T_211.90961326777926_P_10039.085440330007 has been executed and will be used
# Simulations_ph2_T_211.90961326777926_P_10039.085440330007 has been executed and will be used
# Simulations_ph1_T_211.90961326777926_P_10030.065442399302 has been executed and will be used
# Simulations_ph2_T_211.90961326777926_P_10030.065442399302 has been executed and will be used
# Simulations_ph1_T_210.40961326777926_P_9990.847674623845 has been executed and will be used
# Simulations_ph2_T_210.40961326777926_P_9990.847674623845 has been executed and will be used
# Simulations_ph1_T_210.40961326777926_P_9995.413406270758 has been executed and will be used
# Simulations_ph2_T_210.40961326777926_P_9995.413406270758 has been executed and will be used
# Simulations_ph1_T_208.90961326777926_P_9965.426984777503 has been executed and will be used
# Simulations_ph2_T_208.90961326777926_P_9965.426984777503 has been executed and will be used
# Simulations_ph1_T_208.90961326777926_P_9965.140932560307 has been executed and will be used
# Simulations_ph2_T_208.90961326777926_P_9965.140932560307 has been executed and will be used
# Simulations_ph1_T_207.40961326777926_P_9940.318505241781 has been executed and will be used
# Simulations_ph2_T_207.40961326777926_P_9940.318505241781 has been executed and will be used
# Simulations_ph1_T_207.40961326777926_P_9936.609755366782 has been executed and will be used
# Simulations_ph2_T_207.40961326777926_P_9936.609755366782 has been executed and will be used
# Simulations_ph1_T_205.90961326777926_P_9905.073940456554 has been executed and will be used
# Simulations_ph2_T_205.90961326777926_P_9905.073940456554 has been executed and will be used
# Simulations_ph1_T_205.90961326777926_P_9900.509337383259 has been executed and will be used
# Simulations_ph2_T_205.90961326777926_P_9900.509337383259 has been executed and will be used
# Simulations_ph1_T_204.40961326777926_P_9881.055736881894 has been executed and will be used
# Simulations_ph2_T_204.40961326777926_P_9881.055736881894 has been executed and will be used
# Simulations_ph1_T_204.40961326777926_P_9872.881869657895 has been executed and will be used
# Simulations_ph2_T_204.40961326777926_P_9872.881869657895 has been executed and will be used
# Simulations_ph1_T_202.90961326777926_P_9828.553228972432 has been executed and will be used
# Simulations_ph2_T_202.90961326777926_P_9828.553228972432 has been executed and will be used
# Simulations_ph1_T_202.90961326777926_P_9842.006259496457 has been executed and will be used
# Simulations_ph2_T_202.90961326777926_P_9842.006259496457 has been executed and will be used
# Simulations_ph1_T_201.40961326777926_P_9804.253565801857 has been executed and will be used
# Simulations_ph2_T_201.40961326777926_P_9804.253565801857 has been executed and will be used
# Simulations_ph1_T_201.40961326777926_P_9806.880226232715 has been executed and will be used
# Simulations_ph2_T_201.40961326777926_P_9806.880226232715 has been executed and will be used
# Simulations_ph1_T_199.90961326777926_P_9763.916227815465 has been executed and will be used
# Simulations_ph2_T_199.90961326777926_P_9763.916227815465 has been executed and will be used
# Simulations_ph1_T_199.90961326777926_P_9775.73917152745 has been executed and will be used
# Simulations_ph2_T_199.90961326777926_P_9775.73917152745 has been executed and will be used
# Simulations_ph1_T_198.40961326777926_P_9722.863255289436 has been executed and will be used
# Simulations_ph2_T_198.40961326777926_P_9722.863255289436 has been executed and will be used
# Simulations_ph1_T_198.40961326777926_P_9736.135245087553 has been executed and will be used
# Simulations_ph2_T_198.40961326777926_P_9736.135245087553 has been executed and will be used
# Simulations_ph1_T_196.90961326777926_P_9718.744969507687 has been executed and will be used
# Simulations_ph2_T_196.90961326777926_P_9718.744969507687 has been executed and will be used
# Simulations_ph1_T_196.90961326777926_P_9701.66650667629 has been executed and will be used
# Simulations_ph2_T_196.90961326777926_P_9701.66650667629 has been executed and will be used
# Simulations_ph1_T_195.40961326777926_P_9683.614046395234 has been executed and will be used
# Simulations_ph2_T_195.40961326777926_P_9683.614046395234 has been executed and will be used
# Simulations_ph1_T_195.40961326777926_P_9680.939934252723 has been executed and will be used
# Simulations_ph2_T_195.40961326777926_P_9680.939934252723 has been executed and will be used
# Simulations_ph1_T_193.90961326777926_P_9648.842868435004 has been executed and will be used
# Simulations_ph2_T_193.90961326777926_P_9648.842868435004 has been executed and will be used
# Simulations_ph1_T_193.90961326777926_P_9651.41453868711 has been executed and will be used
# Simulations_ph2_T_193.90961326777926_P_9651.41453868711 has been executed and will be used
# Simulations_ph1_T_192.40961326777926_P_9607.174376629171 has been executed and will be used
# Simulations_ph2_T_192.40961326777926_P_9607.174376629171 has been executed and will be used
# Simulations_ph1_T_192.40961326777926_P_9617.768946399086 has been executed and will be used
# Simulations_ph2_T_192.40961326777926_P_9617.768946399086 has been executed and will be used
# Simulations_ph1_T_190.90961326777926_P_9587.945002556115 has been executed and will be used
# Simulations_ph2_T_190.90961326777926_P_9587.945002556115 has been executed and will be used
# Simulations_ph1_T_190.90961326777926_P_9595.319462274663 has been executed and will be used
# Simulations_ph2_T_190.90961326777926_P_9595.319462274663 has been executed and will be used
# Simulations_ph1_T_189.40961326777926_P_9528.002144380747 has been executed and will be used
# Simulations_ph2_T_189.40961326777926_P_9528.002144380747 has been executed and will be used
# Simulations_ph1_T_189.40961326777926_P_9552.750698299611 has been executed and will be used
# Simulations_ph2_T_189.40961326777926_P_9552.750698299611 has been executed and will be used
# Simulations_ph1_T_187.90961326777926_P_9523.626168871035 has been executed and will be used
# Simulations_ph2_T_187.90961326777926_P_9523.626168871035 has been executed and will be used
# Simulations_ph1_T_187.90961326777926_P_9522.869459923482 has been executed and will be used
# Simulations_ph2_T_187.90961326777926_P_9522.869459923482 has been executed and will be used
# Simulations_ph1_T_186.40961326777926_P_9501.369127366921 has been executed and will be used
# Simulations_ph2_T_186.40961326777926_P_9501.369127366921 has been executed and will be used
# Simulations_ph1_T_186.40961326777926_P_9499.152970775405 has been executed and will be used
# Simulations_ph2_T_186.40961326777926_P_9499.152970775405 has been executed and will be used
# Simulations_ph1_T_184.90961326777926_P_9466.877631815305 has been executed and will be used
# Simulations_ph2_T_184.90961326777926_P_9466.877631815305 has been executed and will be used
# Simulations_ph1_T_184.90961326777926_P_9477.756816865865 has been executed and will be used
# Simulations_ph2_T_184.90961326777926_P_9477.756816865865 has been executed and will be used
# Simulations_ph1_T_183.40961326777926_P_9416.244726131468 has been executed and will be used
# Simulations_ph2_T_183.40961326777926_P_9416.244726131468 has been executed and will be used
# Simulations_ph1_T_183.40961326777926_P_9437.103391193838 has been executed and will be used
# Simulations_ph2_T_183.40961326777926_P_9437.103391193838 has been executed and will be used
# Simulations_ph1_T_181.90961326777926_P_9402.794936530405 has been executed and will be used
# Simulations_ph2_T_181.90961326777926_P_9402.794936530405 has been executed and will be used
# Simulations_ph1_T_181.90961326777926_P_9418.087174297358 has been executed and will be used
# Simulations_ph2_T_181.90961326777926_P_9418.087174297358 has been executed and will be used
# Simulations_ph1_T_180.40961326777926_P_9363.127401399755 has been executed and will be used
# Simulations_ph2_T_180.40961326777926_P_9363.127401399755 has been executed and will be used

# %%
log = read_log()

# %%
pd_scan_vi_vii = pd.read_csv('/home/users/saadie5f/piaggi/phase_diagram/ref_data/vi_vii_scan.dat',
                             names=['T','P'], sep=',')
plt.scatter(pd_scan_vi_vii['T'], pd_scan_vi_vii['P']*1e4)
plt.scatter(T_lst, P_lst)

# %%
plt.plot(pd_scan_vi_vii['T'], np.gradient(pd_scan_vi_vii['P']*1e4,pd_scan_vi_vii['T']))
plt.plot(T_lst, np.gradient(P_lstt,T_lst))

# %%
np.average(log.Press)-9991
# Out:
# 112.4930180819174

# %%
plt.scatter(log.Step,log.Press)

# %%
skip = 0
fig, ax = plt.subplots(figsize=(19,40), ncols=3, nrows=n_pnts)
fig.subplots_adjust(hspace=0)
alpha = 0.8
skip=100
for i in range(n_pnts):
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/vi-vii/vi_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_2)/3), alpha=alpha, c='C0', label='vi')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_2)/3), ls='--', color='C0', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C0')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C0', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_2)/3, alpha=alpha, c='C0')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_2)/3, ls='--', color='C0', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_2)/3)
    
    path = f'/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/vi-vii/vii_T_{T_lst[i]}_P_{P_lst[i]}'
    log = read_log(f'{path}')[-1]
        
    
    ax[i,0].plot(log.Step[skip:]*5e-7, log.Volume[skip:]/(len(ph_1)/3), alpha=alpha, c='C3', label='vii')
    ax[i,0].axhline(log.Volume[skip:].mean()/(len(ph_1)/3), ls='--', color='C3', lw=2)
    
    ax[i,1].plot(log.Step[skip:]*5e-7, log.Temp[skip:], alpha=alpha, c='C3')
    ax[i,1].axhline(log.Temp[skip:].mean(), ls='--', color='C3', lw=2)

    ax[i,2].plot(log.Step[skip:]*5e-7,log.Enthalpy[skip:]/len(ph_1)/3, alpha=alpha, c='C3')
    ax[i,2].axhline(log.Enthalpy[skip:].mean()/len(ph_1)/3, ls='--', color='C3', lw=2)
#     print(log.Enthalpy[skip:].mean()/len(ph_1)/3)


ax[i,0].set_xlabel('Time [ns]')
ax[0,0].set_title('V [$\mathrm{\AA^{3}}$]')

ax[i,1].set_xlabel('Time [ns]')
ax[0,1].set_title('T [K]')

ax[i,2].set_xlabel('Time [ns]')
ax[0,2].set_title('H [eV]')
ax[0,0].legend()

# %%
np.savetxt('/home/users/saadie5f/piaggi/phase_diagram/full/cc_int/data/vi_vii.dat',
           [T_lst,np.array(P_lst)*1e-4])

# %%
from functools import partial
from scipy.optimize import brentq
from scipy.interpolate import interp1d

# %%
def delta_P(T, P1, P2):
    return P1(T) - P2(T)

# %%
P_1 = ih_liq[1,:]; T_1 = ih_liq[0,:]
P_2 = v_liq[1,:];  T_2 = v_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_ih_liq = brentq(delta_func, T_guess_min, T_guess_max)
P_triple_ih_liq = P_1_interp(T_triple_ih_liq)
T_triple_ih_liq,P_triple_ih_liq
# Out:
# (273.8824525143863, array(0.34786539))

# %%
P_1 = v_liq[1,:]; T_1 = v_liq[0,:]
P_2 = vi_liq[1,:];  T_2 = vi_liq[0,:]

T_1_unique, idx_1 = np.unique(T_1, return_index=True)
P_1_unique = P_1[idx_1]

T_2_unique, idx_2 = np.unique(T_2, return_index=True)
P_2_unique = P_2[idx_2]

P_1_interp = interp1d(T_1_unique, P_1_unique, kind='cubic')
P_2_interp = interp1d(T_2_unique, P_2_unique, kind='cubic')

T_guess_min = max(min(T_1_unique), min(T_2_unique))
T_guess_max = min(max(T_1_unique), max(T_2_unique))

delta_func = partial(delta_P, P1=P_1_interp, P2=P_2_interp)
T_triple_v_vi = np.round(brentq(delta_func, T_guess_min, T_guess_max),3)
P_triple_v_vi = np.round(P_1_interp(T_triple_v_vi)*1e4,0)
T_triple_v_vi,P_triple_v_vi
# Out:
# (288.323, 5888.0)
